# %% [markdown]
# # Daily Digest for the Energy - Gas and Power

# %% [markdown]
# ## Why It Matters
# In commodity markets like Energy - Gas and Power, timely awareness of trending news can directly influence trading strategies, hedging decisions, and market forecasts. As news cycles accelerate, being able to identify not just what is being talked about but also its potential market impact is essential for staying ahead of price-moving developments.
#
#
# ## What It Does
# This workflow identifies, verifies, clusters, and summarizes the most relevant and impactful news trends in the Energy - Gas and Power using the Bigdata API for retrieval and large language models for topic analysis. It produces both daily market reports and structured datasets that can be used for monitoring or backtesting.
#
# ## How It Works
# The notebook implements a four-step agentic workflow built on Bigdata API:
#
# - **Lexicon Generation** of industry-specific jargon to maximize recall in news retrieval.
#
# - **Content Retrieval** via the Bigdata API, splitting searches into daily windows and parallelizing keyword lookups for speed.
#
# - **Topic Clustering & Selection** to verify, group, and summarize news into ranked trending topics, scoring each for trendiness, novelty, impact, and magnitude.
#
# - **Custom Report Generation** in the form of a daily digest with a configurable ranking system, supported by granular news sources for verification.
#
# ## A Real-World Use Case
# This cookbook illustrates the full workflow through a practical example: tracking daily stories in the Energy - Gas and Power during the Israel-Iran tensions of June 2025. You'll learn how to transform unstructured news into structured, ranked insights on market-moving narratives.

# %% [markdown]
# ## Setup and Imports

# %% [markdown]
# ## Async Compatibility Setup
#
# **Run this cell first** - Required for Google Colab, Jupyter Notebooks, and VS Code with Jupyter extension:
#
# ### Why is this needed?
#
# Interactive environments (Colab, Jupyter) already have an asyncio event loop running. When bigdata-research-tools makes async API calls (like to OpenAI), you'll get this error without nest_asyncio:
#
# ```
# RuntimeError: asyncio.run() cannot be called from a running event loop
# ```
#
# The `nest_asyncio.apply()` command patches this to allow nested event loops.
#
# 💡 **Tip**: If you're unsure which environment you're in, just run the cell below - it won't hurt in any environment!

# %%
import datetime
start = datetime.datetime.now()

try:
    import asyncio
    asyncio.get_running_loop()
    import nest_asyncio; nest_asyncio.apply()
    print("✅ nest_asyncio applied")
except (RuntimeError, ImportError):
    print("✅ nest_asyncio not needed or not available")
# Out:
# ✅ nest_asyncio applied

# %% [markdown]
# ## Environment Setup
#
# The following cell configures the necessary path for the analysis

# %%
import os
import sys


current_dir = os.getcwd()
if current_dir not in sys.path:
    sys.path.append(current_dir)
print(f"✅ Local environment setup complete")
# Out:
# ✅ Local environment setup complete

# %% [markdown]
# ## Load Credentials

# %%
from dotenv import load_dotenv
from pathlib import Path

script_dir = Path(__file__).parent if '__file__' in globals() else Path.cwd()
load_dotenv(script_dir / '.env')

BIGDATA_API_KEY = os.getenv('BIGDATA_API_KEY')
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

if not all([BIGDATA_API_KEY, OPENAI_API_KEY]):
    print("❌ Missing required environment variables")
    raise ValueError("Missing required environment variables. Check your .env file.")
else:
    print("✅ Credentials loaded from .env file")
# Out:
# ✅ Credentials loaded from .env file

# %% [markdown]
# ## Import Required Libraries
#
# Import the core libraries needed for trending topics analysis, including the lexicon generation classes and data processing tools.

# %%
from bigdata_client import Bigdata
from bigdata_client.models.search import DocumentType
from src.lexicon_generator import LexiconGenerator
from src.search_topics import search_by_keywords
from src.topics_extractor import (process_all_reports,
                                run_add_advanced_novelty_scores,
                                add_market_impact_to_df,
                                phase1_extract_topics,
                                phase2_flatten_topics,
                                phase3_consolidate_topics,
                                phase4_summarize_topics,
                                phase5_generate_titles,
                                phase6_postprocess,
                                )
from src.report_generator import(prepare_data_for_report, generate_html_report,
                                save_html_report, display_html_report_as_image)

# %% [markdown]
# ## Connecting to Bigdata
#
# Create a Bigdata object with your credentials.

# %%
bigdata = Bigdata(api_key = BIGDATA_API_KEY)

# %% [markdown]
# ## Defining Your Daily Digest Context and Parameters

# %% [markdown]
# To perform a trending topics analysis, we need to define a few key parameters:
#
# - **Main Theme** (`main_theme`): The main topic, asset class, or context to analyze (e.g. Gas and Power)
#
# - **Point of View** (`point_of_view`): The additional instructions to the LLM-based Impact and Magnitude generation. Use this parameter to add your domain expertise and contextualize your own definition of **Financial Materiality**.
#
# - **Time Period** (`start_date` and `end_date`): The date range over which to run the search
#
# - **Document Type** (`document_type`): Specify which documents to search over (transcripts, filings, news)
#
# - **Model Selection** (`llm_model`): The AI model used for semantic analysis and topic classification

# %%
# ===== Context Definition =====
main_theme = 'Energy - Gas and Power'

point_of_view = "a Gas and Power Commodity trader, where price is influenced by supply-demand dynamics, geopolitical events, and market sentiment. \
As a trader, you focus on changes in production, inventories, and economic indicators from key markets."

# ===== Specify Time Range =====
start_query = '2025-11-05'
end_query = '2025-11-12'

# ===== Query Configuration =====
document_type = DocumentType.NEWS

# ===== LLM Specification =====
llm_model = "gpt-4o-mini"

# %% [markdown]
# ## Define Output Paths
#
# We define the output paths for our results.

# %%
print(main_theme)
# Out:
# Energy - Gas and Power

# %%
# Define output file paths for our report
output_dir = "report"
os.makedirs(output_dir, exist_ok=True)

export_path = f"{output_dir}/daily_digest_{main_theme.lower().replace(' ', '_')}.csv"
print(export_path)
# Out:
# report/daily_digest_energy_-_gas_and_power.csv

# %% [markdown]
# ## Instantiating the Lexicon Generator

# %% [markdown]
# In this step, we identify the specialized industry-specific jargon relevant to the Energy - Gas and Power to ensure a high recall in the content retrieval.

# %%
lexicongenerator = LexiconGenerator(openai_key=OPENAI_API_KEY, model="gpt-4o", seeds=[123, 123456, 123456789, 456789, 789])

# %%
keywords = lexicongenerator.generate(theme=main_theme)
print(keywords)
# Out:
# [LexiconGenerator] Using seeds: [123, 123456, 123456789, 456789, 789]
# [LexiconGenerator] Raw response for seed 123: {
#     "keywords": [
#         "Energy - Gas and Power",
#         "Natural Gas",
#         "Liquefied Natural Gas",
#         "LNG",
#         "Pipeline",
#         "Transmission Grid",
#         "Distribution Network",
#         "Smart Grid",
#         "Load Balancing",
#         "Peak Demand",
#         "Base Load",
#         "Renewable Energy",
#         "Wind Power",
#         "Solar Power",
#         "Hydropower",
#         "Nuclear Energy",
#         "Fossil Fuels",
#         "Carbon Capture and Storage",
#         "CCS",
#         "Energy Efficiency",
#         "Demand Response",
#         "Capacity Market",
#         "Ancillary Services",
#         "Grid Reliability",
#         "Energy Storage",
#         "Battery Storage",
#         "Interconnection",
#         "Power Purchase Agreement",
#         "PPA",
#         "Independent System Operator",
#         "ISO",
#         "Regional Transmission Organization",
#         "RTO",
#         "Electricity Market",
#         "Wholesale Electricity Market",
#         "Retail Electricity Market",
#         "Energy Trading",
#         "Spot Market",
#         "Day-Ahead Market",
#         "Balancing Market",
#         "Grid Integration",
#         "Decentralized Energy",
#         "Microgrid",
#         "Distributed Generation",
#         "Energy Transition",
#         "Decarbonization",
#         "Electrification",
#         "Smart Metering",
#         "Load Shedding",
#         "Grid Resilience",
#         "Energy Policy",
#         "Regulatory Compliance",
#         "Emission Trading System",
#         "ETS",
#         "Renewable Portfolio Standard",
#         "RPS",
#         "Feed-in Tariff",
#         "FiT",
#         "Net Metering",
#         "Energy Security",
#         "Energy Independence",
#         "Energy Subsidy",
#         "Energy Tariff",
#         "Grid Parity",
#         "Levelized Cost of Energy",
#         "LCOE"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123: {'keywords': ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Peak Demand', 'Base Load', 'Renewable Energy', 'Wind Power', 'Solar Power', 'Hydropower', 'Nuclear Energy', 'Fossil Fuels', 'Carbon Capture and Storage', 'CCS', 'Energy Efficiency', 'Demand Response', 'Capacity Market', 'Ancillary Services', 'Grid Reliability', 'Energy Storage', 'Battery Storage', 'Interconnection', 'Power Purchase Agreement', 'PPA', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Electricity Market', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Trading', 'Spot Market', 'Day-Ahead Market', 'Balancing Market', 'Grid Integration', 'Decentralized Energy', 'Microgrid', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Electrification', 'Smart Metering', 'Load Shedding', 'Grid Resilience', 'Energy Policy', 'Regulatory Compliance', 'Emission Trading System', 'ETS', 'Renewable Portfolio Standard', 'RPS', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Energy Security', 'Energy Independence', 'Energy Subsidy', 'Energy Tariff', 'Grid Parity', 'Levelized Cost of Energy', 'LCOE']}
# [LexiconGenerator] Raw response for seed 123456: {
#     "keywords": [
#         "Energy - Gas and Power",
#         "Natural Gas",
#         "Liquefied Natural Gas",
#         "LNG",
#         "Pipeline",
#         "Transmission Grid",
#         "Distribution Network",
#         "Smart Grid",
#         "Load Balancing",
#         "Capacity Market",
#         "Power Purchase Agreement",
#         "PPA",
#         "Renewable Energy Certificates",
#         "REC",
#         "Combined Cycle Gas Turbine",
#         "CCGT",
#         "Gasification",
#         "Shale Gas",
#         "Hydraulic Fracturing",
#         "Fracking",
#         "Gas Storage",
#         "Interconnection",
#         "Baseload Power",
#         "Peaking Power Plant",
#         "Cogeneration",
#         "Energy Mix",
#         "Grid Reliability",
#         "Demand Response",
#         "Energy Efficiency",
#         "Carbon Capture and Storage",
#         "CCS",
#         "Decarbonization",
#         "Energy Transition",
#         "Feed-in Tariff",
#         "FiT",
#         "Net Metering",
#         "Offshore Wind",
#         "Onshore Wind",
#         "Solar Photovoltaic",
#         "PV",
#         "Hydropower",
#         "Biogas",
#         "Geothermal Energy",
#         "Energy Storage",
#         "Battery Storage",
#         "Smart Metering",
#         "Load Shedding",
#         "Energy Security",
#         "Energy Policy",
#         "Regulatory Framework",
#         "Wholesale Electricity Market",
#         "Retail Electricity Market",
#         "Independent System Operator",
#         "ISO",
#         "Regional Transmission Organization",
#         "RTO",
#         "Grid Integration",
#         "Energy Trading",
#         "Gas Turbine",
#         "Thermal Power Plant",
#         "Nuclear Power",
#         "Fossil Fuels",
#         "Renewable Portfolio Standard",
#         "RPS",
#         "Energy Subsidies",
#         "Carbon Trading",
#         "Emissions Trading System",
#         "ETS",
#         "Peak Demand",
#         "Load Forecasting",
#         "Energy Audit",
#         "Power Outage",
#         "Blackout",
#         "Brownout"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123456: {'keywords': ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Capacity Market', 'Power Purchase Agreement', 'PPA', 'Renewable Energy Certificates', 'REC', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Storage', 'Interconnection', 'Baseload Power', 'Peaking Power Plant', 'Cogeneration', 'Energy Mix', 'Grid Reliability', 'Demand Response', 'Energy Efficiency', 'Carbon Capture and Storage', 'CCS', 'Decarbonization', 'Energy Transition', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Offshore Wind', 'Onshore Wind', 'Solar Photovoltaic', 'PV', 'Hydropower', 'Biogas', 'Geothermal Energy', 'Energy Storage', 'Battery Storage', 'Smart Metering', 'Load Shedding', 'Energy Security', 'Energy Policy', 'Regulatory Framework', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Grid Integration', 'Energy Trading', 'Gas Turbine', 'Thermal Power Plant', 'Nuclear Power', 'Fossil Fuels', 'Renewable Portfolio Standard', 'RPS', 'Energy Subsidies', 'Carbon Trading', 'Emissions Trading System', 'ETS', 'Peak Demand', 'Load Forecasting', 'Energy Audit', 'Power Outage', 'Blackout', 'Brownout']}
# [LexiconGenerator] Raw response for seed 123456789: {
#     "keywords": [
#         "Energy - Gas and Power",
#         "Natural Gas",
#         "Liquefied Natural Gas",
#         "LNG",
#         "Pipeline",
#         "Shale Gas",
#         "Hydraulic Fracturing",
#         "Fracking",
#         "Gas Turbine",
#         "Combined Cycle Gas Turbine",
#         "CCGT",
#         "Gasification",
#         "Regasification",
#         "Gas Storage",
#         "Gas Distribution",
#         "Gas Transmission",
#         "Power Grid",
#         "Electricity Generation",
#         "Load Balancing",
#         "Smart Grid",
#         "Renewable Energy Integration",
#         "Capacity Market",
#         "Energy Mix",
#         "Base Load",
#         "Peak Load",
#         "Demand Response",
#         "Grid Reliability",
#         "Interconnection",
#         "Transmission Line",
#         "Distribution Network",
#         "Power Plant",
#         "Cogeneration",
#         "CHP",
#         "Energy Efficiency",
#         "Carbon Capture and Storage",
#         "CCS",
#         "Emissions Trading System",
#         "ETS",
#         "Feed-in Tariff",
#         "FiT",
#         "Power Purchase Agreement",
#         "PPA",
#         "Wholesale Electricity Market",
#         "Retail Electricity Market",
#         "Energy Policy",
#         "Energy Security",
#         "Decarbonization",
#         "Electrification",
#         "Smart Meter"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123456789: {'keywords': ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Regasification', 'Gas Storage', 'Gas Distribution', 'Gas Transmission', 'Power Grid', 'Electricity Generation', 'Load Balancing', 'Smart Grid', 'Renewable Energy Integration', 'Capacity Market', 'Energy Mix', 'Base Load', 'Peak Load', 'Demand Response', 'Grid Reliability', 'Interconnection', 'Transmission Line', 'Distribution Network', 'Power Plant', 'Cogeneration', 'CHP', 'Energy Efficiency', 'Carbon Capture and Storage', 'CCS', 'Emissions Trading System', 'ETS', 'Feed-in Tariff', 'FiT', 'Power Purchase Agreement', 'PPA', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Policy', 'Energy Security', 'Decarbonization', 'Electrification', 'Smart Meter']}
# [LexiconGenerator] Raw response for seed 456789: {
#     "keywords": [
#         "Energy - Gas and Power",
#         "Natural Gas",
#         "Liquefied Natural Gas",
#         "LNG",
#         "Pipeline",
#         "Gas Turbine",
#         "Combined Cycle Gas Turbine",
#         "CCGT",
#         "Power Grid",
#         "Smart Grid",
#         "Load Balancing",
#         "Capacity Market",
#         "Renewable Energy Integration",
#         "Gas Storage",
#         "Shale Gas",
#         "Hydraulic Fracturing",
#         "Fracking",
#         "Gasification",
#         "Cogeneration",
#         "Distributed Generation",
#         "Energy Transition",
#         "Decarbonization",
#         "Carbon Capture and Storage",
#         "CCS",
#         "Baseload Power",
#         "Peak Load",
#         "Intermittent Energy",
#         "Energy Efficiency",
#         "Demand Response",
#         "Grid Reliability",
#         "Energy Security",
#         "Energy Policy",
#         "Regasification",
#         "Liquefaction",
#         "Gas Distribution Network",
#         "Energy Trading",
#         "Spot Market",
#         "Day-Ahead Market",
#         "Ancillary Services",
#         "Power Purchase Agreement",
#         "PPA",
#         "Feed-in Tariff",
#         "FiT",
#         "Net Metering",
#         "Energy Subsidy",
#         "Grid Parity",
#         "Energy Mix",
#         "Gas Flaring",
#         "Methane Emissions",
#         "Energy Storage",
#         "Battery Storage",
#         "Hydropower",
#         "Nuclear Power",
#         "Thermal Power",
#         "Offshore Wind",
#         "Onshore Wind",
#         "Solar Power",
#         "Photovoltaic",
#         "PV",
#         "Biomass Energy",
#         "Geothermal Energy"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 456789: {'keywords': ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Power Grid', 'Smart Grid', 'Load Balancing', 'Capacity Market', 'Renewable Energy Integration', 'Gas Storage', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gasification', 'Cogeneration', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Carbon Capture and Storage', 'CCS', 'Baseload Power', 'Peak Load', 'Intermittent Energy', 'Energy Efficiency', 'Demand Response', 'Grid Reliability', 'Energy Security', 'Energy Policy', 'Regasification', 'Liquefaction', 'Gas Distribution Network', 'Energy Trading', 'Spot Market', 'Day-Ahead Market', 'Ancillary Services', 'Power Purchase Agreement', 'PPA', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Energy Subsidy', 'Grid Parity', 'Energy Mix', 'Gas Flaring', 'Methane Emissions', 'Energy Storage', 'Battery Storage', 'Hydropower', 'Nuclear Power', 'Thermal Power', 'Offshore Wind', 'Onshore Wind', 'Solar Power', 'Photovoltaic', 'PV', 'Biomass Energy', 'Geothermal Energy']}
# [LexiconGenerator] Raw response for seed 789: {
#     "keywords": [
#         "Energy - Gas and Power",
#         "Natural Gas",
#         "Liquefied Natural Gas",
#         "LNG",
#         "Pipeline",
#         "Gas Turbine",
#         "Combined Cycle Gas Turbine",
#         "CCGT",
#         "Shale Gas",
#         "Hydraulic Fracturing",
#         "Fracking",
#         "Gas Storage",
#         "Gasification",
#         "Regasification",
#         "Gas Distribution",
#         "Gas Transmission",
#         "Gas Processing",
#         "Gas Market",
#         "Gas Trading",
#         "Gas Hub",
#         "Henry Hub",
#         "Gas Balancing",
#         "Gas Supply",
#         "Gas Demand",
#         "Gas Reserves",
#         "Gas Exploration",
#         "Gas Production",
#         "Gas Consumption",
#         "Gas Infrastructure",
#         "Gas Regulation",
#         "Gas Pricing",
#         "Gas Contract",
#         "Power Generation",
#         "Electric Grid",
#         "Load Balancing",
#         "Power Plant",
#         "Renewable Energy",
#         "Wind Power",
#         "Solar Power",
#         "Hydropower",
#         "Nuclear Power",
#         "Coal Power",
#         "Energy Transition",
#         "Decarbonization",
#         "Energy Efficiency",
#         "Smart Grid",
#         "Demand Response",
#         "Capacity Market",
#         "Ancillary Services",
#         "Interconnection",
#         "Transmission Network",
#         "Distribution Network",
#         "Grid Stability",
#         "Grid Reliability",
#         "Energy Storage",
#         "Battery Storage",
#         "Pumped Hydro Storage",
#         "Energy Policy",
#         "Energy Security",
#         "Energy Independence",
#         "Carbon Capture",
#         "Carbon Trading",
#         "Emissions Trading System",
#         "ETS",
#         "Renewable Portfolio Standard",
#         "RPS",
#         "Feed-in Tariff",
#         "FiT",
#         "Power Purchase Agreement",
#         "PPA",
#         "Independent Power Producer",
#         "IPP",
#         "Distributed Generation",
#         "Microgrid",
#         "Net Metering",
#         "Energy Audit",
#         "Energy Management System",
#         "EMS",
#         "Load Shedding",
#         "Peak Load",
#         "Base Load",
#         "Energy Mix",
#         "Energy Intensity"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 789: {'keywords': ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Storage', 'Gasification', 'Regasification', 'Gas Distribution', 'Gas Transmission', 'Gas Processing', 'Gas Market', 'Gas Trading', 'Gas Hub', 'Henry Hub', 'Gas Balancing', 'Gas Supply', 'Gas Demand', 'Gas Reserves', 'Gas Exploration', 'Gas Production', 'Gas Consumption', 'Gas Infrastructure', 'Gas Regulation', 'Gas Pricing', 'Gas Contract', 'Power Generation', 'Electric Grid', 'Load Balancing', 'Power Plant', 'Renewable Energy', 'Wind Power', 'Solar Power', 'Hydropower', 'Nuclear Power', 'Coal Power', 'Energy Transition', 'Decarbonization', 'Energy Efficiency', 'Smart Grid', 'Demand Response', 'Capacity Market', 'Ancillary Services', 'Interconnection', 'Transmission Network', 'Distribution Network', 'Grid Stability', 'Grid Reliability', 'Energy Storage', 'Battery Storage', 'Pumped Hydro Storage', 'Energy Policy', 'Energy Security', 'Energy Independence', 'Carbon Capture', 'Carbon Trading', 'Emissions Trading System', 'ETS', 'Renewable Portfolio Standard', 'RPS', 'Feed-in Tariff', 'FiT', 'Power Purchase Agreement', 'PPA', 'Independent Power Producer', 'IPP', 'Distributed Generation', 'Microgrid', 'Net Metering', 'Energy Audit', 'Energy Management System', 'EMS', 'Load Shedding', 'Peak Load', 'Base Load', 'Energy Mix', 'Energy Intensity']}
# [LexiconGenerator] Combined keywords dict: {'keywords': ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Peak Demand', 'Base Load', 'Renewable Energy', 'Wind Power', 'Solar Power', 'Hydropower', 'Nuclear Energy', 'Fossil Fuels', 'Carbon Capture and Storage', 'CCS', 'Energy Efficiency', 'Demand Response', 'Capacity Market', 'Ancillary Services', 'Grid Reliability', 'Energy Storage', 'Battery Storage', 'Interconnection', 'Power Purchase Agreement', 'PPA', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Electricity Market', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Trading', 'Spot Market', 'Day-Ahead Market', 'Balancing Market', 'Grid Integration', 'Decentralized Energy', 'Microgrid', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Electrification', 'Smart Metering', 'Load Shedding', 'Grid Resilience', 'Energy Policy', 'Regulatory Compliance', 'Emission Trading System', 'ETS', 'Renewable Portfolio Standard', 'RPS', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Energy Security', 'Energy Independence', 'Energy Subsidy', 'Energy Tariff', 'Grid Parity', 'Levelized Cost of Energy', 'LCOE', 'Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Capacity Market', 'Power Purchase Agreement', 'PPA', 'Renewable Energy Certificates', 'REC', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Storage', 'Interconnection', 'Baseload Power', 'Peaking Power Plant', 'Cogeneration', 'Energy Mix', 'Grid Reliability', 'Demand Response', 'Energy Efficiency', 'Carbon Capture and Storage', 'CCS', 'Decarbonization', 'Energy Transition', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Offshore Wind', 'Onshore Wind', 'Solar Photovoltaic', 'PV', 'Hydropower', 'Biogas', 'Geothermal Energy', 'Energy Storage', 'Battery Storage', 'Smart Metering', 'Load Shedding', 'Energy Security', 'Energy Policy', 'Regulatory Framework', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Grid Integration', 'Energy Trading', 'Gas Turbine', 'Thermal Power Plant', 'Nuclear Power', 'Fossil Fuels', 'Renewable Portfolio Standard', 'RPS', 'Energy Subsidies', 'Carbon Trading', 'Emissions Trading System', 'ETS', 'Peak Demand', 'Load Forecasting', 'Energy Audit', 'Power Outage', 'Blackout', 'Brownout', 'Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Regasification', 'Gas Storage', 'Gas Distribution', 'Gas Transmission', 'Power Grid', 'Electricity Generation', 'Load Balancing', 'Smart Grid', 'Renewable Energy Integration', 'Capacity Market', 'Energy Mix', 'Base Load', 'Peak Load', 'Demand Response', 'Grid Reliability', 'Interconnection', 'Transmission Line', 'Distribution Network', 'Power Plant', 'Cogeneration', 'CHP', 'Energy Efficiency', 'Carbon Capture and Storage', 'CCS', 'Emissions Trading System', 'ETS', 'Feed-in Tariff', 'FiT', 'Power Purchase Agreement', 'PPA', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Policy', 'Energy Security', 'Decarbonization', 'Electrification', 'Smart Meter', 'Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Power Grid', 'Smart Grid', 'Load Balancing', 'Capacity Market', 'Renewable Energy Integration', 'Gas Storage', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gasification', 'Cogeneration', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Carbon Capture and Storage', 'CCS', 'Baseload Power', 'Peak Load', 'Intermittent Energy', ' ...
# [LexiconGenerator] All keywords before deduplication: ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Peak Demand', 'Base Load', 'Renewable Energy', 'Wind Power', 'Solar Power', 'Hydropower', 'Nuclear Energy', 'Fossil Fuels', 'Carbon Capture and Storage', 'CCS', 'Energy Efficiency', 'Demand Response', 'Capacity Market', 'Ancillary Services', 'Grid Reliability', 'Energy Storage', 'Battery Storage', 'Interconnection', 'Power Purchase Agreement', 'PPA', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Electricity Market', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Trading', 'Spot Market', 'Day-Ahead Market', 'Balancing Market', 'Grid Integration', 'Decentralized Energy', 'Microgrid', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Electrification', 'Smart Metering', 'Load Shedding', 'Grid Resilience', 'Energy Policy', 'Regulatory Compliance', 'Emission Trading System', 'ETS', 'Renewable Portfolio Standard', 'RPS', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Energy Security', 'Energy Independence', 'Energy Subsidy', 'Energy Tariff', 'Grid Parity', 'Levelized Cost of Energy', 'LCOE', 'Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Capacity Market', 'Power Purchase Agreement', 'PPA', 'Renewable Energy Certificates', 'REC', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Storage', 'Interconnection', 'Baseload Power', 'Peaking Power Plant', 'Cogeneration', 'Energy Mix', 'Grid Reliability', 'Demand Response', 'Energy Efficiency', 'Carbon Capture and Storage', 'CCS', 'Decarbonization', 'Energy Transition', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Offshore Wind', 'Onshore Wind', 'Solar Photovoltaic', 'PV', 'Hydropower', 'Biogas', 'Geothermal Energy', 'Energy Storage', 'Battery Storage', 'Smart Metering', 'Load Shedding', 'Energy Security', 'Energy Policy', 'Regulatory Framework', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Grid Integration', 'Energy Trading', 'Gas Turbine', 'Thermal Power Plant', 'Nuclear Power', 'Fossil Fuels', 'Renewable Portfolio Standard', 'RPS', 'Energy Subsidies', 'Carbon Trading', 'Emissions Trading System', 'ETS', 'Peak Demand', 'Load Forecasting', 'Energy Audit', 'Power Outage', 'Blackout', 'Brownout', 'Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Regasification', 'Gas Storage', 'Gas Distribution', 'Gas Transmission', 'Power Grid', 'Electricity Generation', 'Load Balancing', 'Smart Grid', 'Renewable Energy Integration', 'Capacity Market', 'Energy Mix', 'Base Load', 'Peak Load', 'Demand Response', 'Grid Reliability', 'Interconnection', 'Transmission Line', 'Distribution Network', 'Power Plant', 'Cogeneration', 'CHP', 'Energy Efficiency', 'Carbon Capture and Storage', 'CCS', 'Emissions Trading System', 'ETS', 'Feed-in Tariff', 'FiT', 'Power Purchase Agreement', 'PPA', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Policy', 'Energy Security', 'Decarbonization', 'Electrification', 'Smart Meter', 'Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Gas Turbine', 'Combined Cycle Gas Turbine', 'CCGT', 'Power Grid', 'Smart Grid', 'Load Balancing', 'Capacity Market', 'Renewable Energy Integration', 'Gas Storage', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gasification', 'Cogeneration', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Carbon Capture and Storage', 'CCS', 'Baseload Power', 'Peak Load', 'Intermittent Energy', 'En ...
# [LexiconGenerator] Unique keywords after deduplication: ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Peak Demand', 'Base Load', 'Renewable Energy', 'Wind Power', 'Solar Power', 'Hydropower', 'Nuclear Energy', 'Fossil Fuels', 'Carbon Capture and Storage', 'CCS', 'Energy Efficiency', 'Demand Response', 'Capacity Market', 'Ancillary Services', 'Grid Reliability', 'Energy Storage', 'Battery Storage', 'Interconnection', 'Power Purchase Agreement', 'PPA', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Electricity Market', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Trading', 'Spot Market', 'Day-Ahead Market', 'Balancing Market', 'Grid Integration', 'Decentralized Energy', 'Microgrid', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Electrification', 'Smart Metering', 'Load Shedding', 'Grid Resilience', 'Energy Policy', 'Regulatory Compliance', 'Emission Trading System', 'ETS', 'Renewable Portfolio Standard', 'RPS', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Energy Security', 'Energy Independence', 'Energy Subsidy', 'Energy Tariff', 'Grid Parity', 'Levelized Cost of Energy', 'LCOE', 'Renewable Energy Certificates', 'REC', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Storage', 'Baseload Power', 'Peaking Power Plant', 'Cogeneration', 'Energy Mix', 'Offshore Wind', 'Onshore Wind', 'Solar Photovoltaic', 'PV', 'Biogas', 'Geothermal Energy', 'Regulatory Framework', 'Gas Turbine', 'Thermal Power Plant', 'Nuclear Power', 'Energy Subsidies', 'Carbon Trading', 'Emissions Trading System', 'Load Forecasting', 'Energy Audit', 'Power Outage', 'Blackout', 'Brownout', 'Regasification', 'Gas Distribution', 'Gas Transmission', 'Power Grid', 'Electricity Generation', 'Renewable Energy Integration', 'Peak Load', 'Transmission Line', 'Power Plant', 'CHP', 'Smart Meter', 'Intermittent Energy', 'Liquefaction', 'Gas Distribution Network', 'Gas Flaring', 'Methane Emissions', 'Thermal Power', 'Photovoltaic', 'Biomass Energy', 'Gas Processing', 'Gas Market', 'Gas Trading', 'Gas Hub', 'Henry Hub', 'Gas Balancing', 'Gas Supply', 'Gas Demand', 'Gas Reserves', 'Gas Exploration', 'Gas Production', 'Gas Consumption', 'Gas Infrastructure', 'Gas Regulation', 'Gas Pricing', 'Gas Contract', 'Power Generation', 'Electric Grid', 'Coal Power', 'Transmission Network', 'Grid Stability', 'Pumped Hydro Storage', 'Carbon Capture', 'Independent Power Producer', 'IPP', 'Energy Management System', 'EMS', 'Energy Intensity']
# ['Energy - Gas and Power', 'Natural Gas', 'Liquefied Natural Gas', 'LNG', 'Pipeline', 'Transmission Grid', 'Distribution Network', 'Smart Grid', 'Load Balancing', 'Peak Demand', 'Base Load', 'Renewable Energy', 'Wind Power', 'Solar Power', 'Hydropower', 'Nuclear Energy', 'Fossil Fuels', 'Carbon Capture and Storage', 'CCS', 'Energy Efficiency', 'Demand Response', 'Capacity Market', 'Ancillary Services', 'Grid Reliability', 'Energy Storage', 'Battery Storage', 'Interconnection', 'Power Purchase Agreement', 'PPA', 'Independent System Operator', 'ISO', 'Regional Transmission Organization', 'RTO', 'Electricity Market', 'Wholesale Electricity Market', 'Retail Electricity Market', 'Energy Trading', 'Spot Market', 'Day-Ahead Market', 'Balancing Market', 'Grid Integration', 'Decentralized Energy', 'Microgrid', 'Distributed Generation', 'Energy Transition', 'Decarbonization', 'Electrification', 'Smart Metering', 'Load Shedding', 'Grid Resilience', 'Energy Policy', 'Regulatory Compliance', 'Emission Trading System', 'ETS', 'Renewable Portfolio Standard', 'RPS', 'Feed-in Tariff', 'FiT', 'Net Metering', 'Energy Security', 'Energy Independence', 'Energy Subsidy', 'Energy Tariff', 'Grid Parity', 'Levelized Cost of Energy', 'LCOE', 'Renewable Energy Certificates', 'REC', 'Combined Cycle Gas Turbine', 'CCGT', 'Gasification', 'Shale Gas', 'Hydraulic Fracturing', 'Fracking', 'Gas Storage', 'Baseload Power', 'Peaking Power Plant', 'Cogeneration', 'Energy Mix', 'Offshore Wind', 'Onshore Wind', 'Solar Photovoltaic', 'PV', 'Biogas', 'Geothermal Energy', 'Regulatory Framework', 'Gas Turbine', 'Thermal Power Plant', 'Nuclear Power', 'Energy Subsidies', 'Carbon Trading', 'Emissions Trading System', 'Load Forecasting', 'Energy Audit', 'Power Outage', 'Blackout', 'Brownout', 'Regasification', 'Gas Distribution', 'Gas Transmission', 'Power Grid', 'Electricity Generation', 'Renewable Energy Integration', 'Peak Load', 'Transmission Line', 'Power Plant', 'CHP', 'Smart Meter', 'Intermittent Energy', 'Liquefaction', 'Gas Distribution Network', 'Gas Flaring', 'Methane Emissions', 'Thermal Power', 'Photovoltaic', 'Biomass Energy', 'Gas Processing', 'Gas Market', 'Gas Trading', 'Gas Hub', 'Henry Hub', 'Gas Balancing', 'Gas Supply', 'Gas Demand', 'Gas Reserves', 'Gas Exploration', 'Gas Production', 'Gas Consumption', 'Gas Infrastructure', 'Gas Regulation', 'Gas Pricing', 'Gas Contract', 'Power Generation', 'Electric Grid', 'Coal Power', 'Transmission Network', 'Grid Stability', 'Pumped Hydro Storage', 'Carbon Capture', 'Independent Power Producer', 'IPP', 'Energy Management System', 'EMS', 'Energy Intensity']

# %% [markdown]
# ## Content Retrieval from Bigdata Search API

# %% [markdown]
# In this section, we perform a keyword search on the news content with the Bigdata API to retrieve documents, splitting the search over daily timeframes and multi-threading the content search on the individual keywords for speed purpose. The user can define the time range below to generate daily reports between the start and end dates.

# %% [markdown]
# With the list of market-specific keywords parameters, you can leverage the Search functionalities in bigdata-research-tools, built with Bigdata API, to run search at scale against news documents. We need to define 2 more parameters for search:
#
# - **Frequency** (`freq`): The frequency of the date ranges to search over. It should at least match the frequency of your daily digest. Supported values:
#     - `Y`: Yearly intervals.
#     - `M`: Monthly intervals.
#     - `W`: Weekly intervals.
#     - `D`: Daily intervals. Defaults to `D`.
# - **Document Limit** (`document_limit`): The maximum number of documents to return per query to Bigdata API.

# %%
# ===== Query Configuration =====
document_limit = 10 # Maximum number of documents to retrieve per query
frequency = 'D'  # Query frequency

# %%
results, daily_keyword_count = search_by_keywords(
    keywords=keywords,
    start_date=start_query,
    end_date=end_query,
    scope = document_type,
    freq=frequency,
    document_limit=document_limit)
# Out:
# About to run 1144 queries
# Example Query: Keyword('Energy - Gas and Power') over date range: AbsoluteDateRange('2025-11-05T00:00:00', '2025-11-05T23:59:59')
# Querying Bigdata...: 100%|██████████| 1144/1144 [04:02<00:00,  4.71it/s]

# %% [markdown]
# ## Topic Clustering and Summarization

# %% [markdown]
# In this step, we perform topic modelling using a large language model to verify and cluster the news. Then, the summarization ensures topic selection identifying the top trending news for Gas and Power, while deriving advanced analytics to quantify the trendiness (based on news volume), novelty (based on daily changes in summaries), impact and magnitude (based on the financial materiality on Gas and Power prices) of the trending topics.

# %% [markdown]
# Before performing the topic clustering, we apply a verification layer to remove the news that are not relative to the oil market

# %%
semaphore_size = 500 # Maximum number of concurrent requests to Openai API

# Assuming unique_reports is your DataFrame
filtered_reports = process_all_reports(results, llm_model, OPENAI_API_KEY, main_theme, semaphore_size)
# Out:
# Filtering News:   0%|          | 0/24483 [00:00<?, ?it/s]
# /home/fricigliano/git/bigdata/github/bigdata-cookbook/Daily_Digest_Crude_Oil/src/topics_extractor.py:1619: UserWarning: Error in fetch_relevance for model gpt-4o-mini: invalid syntax (<unknown>, line 1). Returning None (will be filtered out).
#   warnings.warn(f"Error in fetch_relevance for model {model}: {str(e)}. Returning None (will be filtered out).")
# 📊 Filtering Summary:
#    Total records: 24483
#    Relevant: 13882
#    Irrelevant: 10173
#    ⚠️  Errors (filtered out): 428
#    💡 Tip: Check model name and API key if error count is high

# %% [markdown]
# In this cell, we leverage LLMs to perform topic modeling, identifying and clustering the key topics from the news reports.

# %%
# Phase 1: Extraction
all_results, trending_topics_df, unique_reports = await phase1_extract_topics(
    unique_reports=filtered_reports,
    start_query=start_query,
    end_query=end_query,
    main_theme=main_theme,
    model=llm_model,
    api_key=OPENAI_API_KEY,
    batches=20
)

# Phase 2: Flattening  
flattened_df, total_cited = phase2_flatten_topics(
    trending_topics_df=trending_topics_df,
    unique_reports=unique_reports
)

# Phase 3: Consolidation
flattened_consolidated, mapping, stats = await phase3_consolidate_topics(
    flattened_raw_topics_df=flattened_df,
    model=llm_model,
    api_key=OPENAI_API_KEY,
    main_theme=main_theme,
    consolidation_round_batch_size= 100
)

# Phase 4: Summarization
flattened_with_summaries = await phase4_summarize_topics(
    flattened_df=flattened_consolidated,
    model=llm_model,
    api_key=OPENAI_API_KEY,
    main_theme=main_theme,
)

# Phase 5: Generate Titles
flattened_with_titles = await phase5_generate_titles(
    flattened_df=flattened_with_summaries,
    model=llm_model,
    api_key=OPENAI_API_KEY
)

# Phase 6: Postprocessing
final_df = await phase6_postprocess(
    flattened_df=flattened_with_titles,
    api_key=OPENAI_API_KEY,
    main_theme=main_theme,
    total_cited_for_summary=0,
    unique_reports=unique_reports
)
# Out:
# Extracting Topics for 2025-11-05:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-06:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-07:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-08:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-09:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-10:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-11:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-11-12:   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ## Topic Scoring

# %% [markdown]
# **Trendiness and Novelty Scores**: We derive analytics related to the trendiness of the topic based on the news volume, and the novelty of the topic based on the changes in daily summaries, evaluating the uniqueness and freshness of each topic.

# %%
filtered_df = final_df[final_df['Volume_Score'] >= 2]
flattened_trending_topics_df = filtered_df.copy()
# Calculate trendiness and novelty scores, assessing the uniqueness and freshness of each topic
flattened_trending_topics_df = run_add_advanced_novelty_scores(flattened_trending_topics_df, api_key = os.environ['OPENAI_API_KEY'], main_theme = main_theme)
# Out:
# Calculating Novelty Scores:   0%|          | 0/510 [00:00<?, ?it/s]

# %% [markdown]
# **Financial Materiality**: We derive analytics related to the impact (Positive, Negative) and magnitude (High, Medium, Low) of the topics, inferring their  market impact on gas and power prices. The inference is based on the price mechanisms involving supply and demand dynamics, geopolitical factors among others.

# %%
flattened_trending_topics_df = add_market_impact_to_df(flattened_trending_topics_df, api_key = os.environ['OPENAI_API_KEY'], main_theme = main_theme, point_of_view = point_of_view)

# %% [markdown]
# We display the results of topic modeling and summarization. The **Topic** column represents the themes inferred through topic clustering using a LLM, which groups the news articles based on their content and underlying themes. The **Summary** provides a synthesized overview of all news articles within the same topic, offering a high-level view of the key messages for each cluster. The **Topic** is then rephrased into a concise form based on the summary. The **Text_Summary** provides a detailed summary of each individualchunk, capturing its core message.

# %% [markdown]
# For verification purpose, this actionable timestamped dataframe contains the granular news clustered into relevant topics, and also the advanced analytics of trendiness, novelty, impact, and magnitude scores to be potentially used for backtesting.

# %%
flattened_trending_topics_df.to_csv(export_path, index=False)

# %% [markdown]
# ## Generate a Custom Daily Digest

# %% [markdown]
# In this step, we rank the topics, allowing the user to customize the ranking system to reindex the news, based on their trendiness, novelty, and financial materiality on gas and power prices. We finally display a daily market update, supported by the corresponding granular news and sources for verification purpose.

# %% [markdown]
# The user selects the date for the report summarizing the top trending topics, and customizes the ranking system to prioritize the topics based on volume (trendiness and media attention), novelty (based on the emergence of new daily news), impact direction (positive or negative), and magnitude (financial materiality). The ranking system prioritizes the criteria in the order specified by the user, allowing for a tailored focus on the most relevant aspects of the data.

# %% [markdown]
# The order in which the criteria are listed in user_selected_ranking determines their priority for ranking the topics within the report. The first criterion in the list has the highest priority, followed by the second, and then the third. The user can customize the ranking by choosing to prioritize impact direction (positive or negative), novelty, magnitude, or volume, and has the flexibility to select 1, 2, or all 3 criteria based on their specific needs.

# %%
specific_date = '2025-11-12'  # Example date, can be modified as needed (must match dates in your data: 2025-11-11 to 2025-11-12)

user_selected_ranking = ['novelty', 'volume', 'magnitude']  # User can modify this list to change the ranking order
#impact_filter = 'positive_impact' #User can use the impact_filter to filter out the report

# %%
prepared_reports = prepare_data_for_report(flattened_trending_topics_df, user_selected_ranking, impact_filter = None, report_date = specific_date)

# %%
print(prepared_reports)
# Out:
# [{'date': '2025-11-12', 'day_in_review': ["<b>India's Energy Transition</b>: Achieved 50% non-fossil fuel electricity capacity ahead of 2030 target; significant investments in renewable projects and energy storage technologies.", '<b>UK Decarbonization Strategy</b>: Integrating Carbon Capture and Storage (CCS) with offshore wind to enhance energy security and meet net-zero targets.', '<b>Philippines Electricity Prices</b>: Surge of 49.4% due to natural disasters impacting supply, highlighting vulnerabilities in energy pricing.', '<b>U.S. LNG Exports</b>: Surge driven by regulatory reforms and high international demand, reshaping global energy dynamics, particularly in Europe and Asia.', "<b>Japan's Energy Security</b>: Long-term LNG agreements and offshore wind challenges amid rising project costs and regulatory hurdles.", '<b>Natural Gas Demand</b>: Increased globally as countries transition to cleaner energy; significant investments in LNG infrastructure and projects like the Alaska LNG Project.', "<b>Nigeria's Energy Independence</b>: Introduction of a 15% levy on fuel imports and initiatives to boost local gas production amid ongoing energy poverty challenges.", '<b>Ukraine Conflict Impact</b>: Ongoing military actions disrupt energy infrastructure, prompting diversification of energy sources and increased LNG imports from the U.S.', "<b>Azerbaijan's Gas Exports</b>: Surge in exports to Europe as part of efforts to reduce reliance on Russian gas amid geopolitical tensions.", '<b>Energy Storage Innovations</b>: Growth in Battery Energy Storage Systems (BESS) critical for renewable energy integration and grid stability.', '<b>Regulatory Changes</b>: U.S. and UK regulatory reforms aimed at enhancing energy market competitiveness and addressing energy security concerns.', '<b>Natural Gas Pricing Volatility</b>: European market facing tight supply and potential price spikes due to low storage levels and geopolitical tensions.', '<b>Biogas Initiatives</b>: Global momentum in biogas production as a sustainable energy solution, despite local opposition to some projects.', '<b>Smart Meter Adoption</b>: Expected to surpass 3 billion units by 2030, enhancing energy management and efficiency.', '<b>Carbon Capture Technologies</b>: Increasing focus on CCUS initiatives as essential for achieving carbon neutrality and reducing emissions.', "<b>Legal Disputes in LNG Market</b>: Shell and BP's arbitration claims against Venture Global LNG highlight complexities in long-term contracts amid soaring prices."], 'topics': [{'topic': 'U.S. LNG Exports Surge Amid Regulatory Reforms and Global Energy Security Shift', 'summary': "Recent developments in energy regulatory and policy frameworks have significantly influenced the global energy landscape, particularly in the context of natural gas and liquefied natural gas (LNG). In the U.S., regulatory changes by the Federal Energy Regulatory Commission (FERC) aim to streamline regulations and enhance market competitiveness, promoting investment in the natural gas and electric sectors. The surge in U.S. LNG exports, driven by high international demand, is reshaping energy dynamics, especially in Europe and Asia, as countries seek alternatives to Russian gas amid geopolitical tensions. The U.S. is positioning itself as a key supplier to Europe, with agreements to increase LNG imports, reflecting a strategic shift towards energy security. Concurrently, the UK has implemented a ban on Russian LNG exports, reinforcing its commitment to reducing dependency on Russian energy sources. In Australia, regulatory reforms are enhancing the independence of the Australian Energy Regulator (AER) to better manage the complexities of the energy market. Meanwhile, the UAE's Unified Gas Code and the U.S. Department of Energy's proposed rules are establishing comprehensive safety standards and accommodating growing energy demands. These regulatory frameworks are essential for fostering a stable investment environment and e ...

# %%
# Generate and display the HTML report for each date
for report in prepared_reports:
    html_content = generate_html_report(
        report['date'],
        report['day_in_review'],
        report['topics'],
        f'Daily {main_theme} market update'  # Pass the main theme to dynamically generate the title
    )
    save_html_report(html_content, report['date'], main_theme)
    display_html_report_as_image(report['date'], main_theme)
    print("")
    print("")
    print("")
# Out:
# Report saved to ./report/2025-11-12_Energy_-_Gas_and_Power.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <style>
#     html, body { overflow: hidden !important; }
#     ::-webkit-scrollbar { display: none; }
#     </style>
#
#     <meta charset="UTF-8">
#     <title>Daily Energy - Gas and Power market update - 2025-11-12</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #121212;
#             color: #E0E0E0;
#             margin: 20px;
#             padding: 0;
#             line-height: 1.6;
#         }
#         .container {
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#             background-color: #1E1E1E;
#             border-radius: 10px;
#             box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.4);
#             position: relative;  /* For positioning the logo */
#         }
#         .container h1, .container h2, .container h3 {
#             color: #0080BF;
#         }
#         .title {
#             text-align: center;
#             font-size: 1.4em;
#             margin-bottom: 20px;
#             color: #00BFFF; /* Dynamic blue color for the title */
#             text-transform: uppercase;
#             letter-spacing: 2px;
#             white-space: nowrap; /* Prevent text wrapping */
#         }
#         .logo {
#             position: absolute;
#             top: 20px;
#             left: 20px; /* Positioned to the left */
#             width: 180px;  /* Adjust the size as needed */
#             height: auto;
#         }
#         .content {
#             display: flex;
#         }
#         .left-column {
#             flex: 1;
#             max-width: 300px;
#             margin-right: 20px;
#         }
#         .right-column {
#             flex: 3;
#         }
#         .separator {
#             width: 2px;
#             background-color: #00BFFF; /* Dynamic blue color for the separator */
#             margin-right: 20px;
#         }
#         .section-title {
#             font-size: 1.5em;
#             margin-bottom: 15px;
#             color: #0080BF; /* Darker blue color for section titles */
#             text-transform: uppercase;
#         }
#         .bullet-points {
#             list-style-type: disc;
#             margin-left: 20px;
#             color: #E0E0E0; /* White color for bullet points */
#         }
#         .topic-section {
#             margin-bottom: 40px;  /* Increased space between updates */
#             padding: 20px;
#             background-color: #2A2A2A;
#             border-radius: 10px;
#             box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.3);
#             position: relative;  /* To position the counters */
#         }
#         .topic-title {
#             font-size: 1.7em;
#             padding-top: 40px; /* Increase space above the title */
#             color: #0080BF; /* Darker blue color for topic titles */
#             text-transform: uppercase;
#         }
#         .counter-container {
#             position: absolute;
#             top: 20px;
#             right: 20px;
#             display: flex;
#             align-items: center;
#             justify-content: flex-start; /* Align content to the left */
#             gap: 20px; /* Space between each counter */
#             margin-bottom: 60px; /* Increased space between the title and counters */
#         }
#         .news-counter, .novelty-counter, .impact-counter, .magnitude-counter {
#             background-color: #00BFFF; /* Dynamic blue color for counters */
#             color: #121212; /* Black text color for counters */
#             padding: 5px 10px;
#             border-radius: 15px;
#             font-weight: bold;
#             font-size: 1em;
#             box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.2);
#             display: flex;
#             align-items: center;  /* Align text and icon vertically */
#         }
#         .novelty-counter {
#             background-color: transparent;
#             color: #FFA500;  /* Orange color for the flame icon and text */
#         }
#         .flame-icon {
#             vertical-align: middle;
#             margin-right: 5px;
#             width: 24px;  /* Adjusted width of the flame icon */
#             height: 24px; /* Adjusted height of the flame icon */
#         }
#         .impact-counter {
#             color: #121212; /* Black text color for impact */
#         }
#         .impact-counter.positive {
#             background-color: #4CAF50; /* Green for positive impact */
#         }
#         .impact-counter.negative {
#             background-color: #F44336; /* Red for negative impact */
#         }
#         .impact-counter.neutral {
#             background-color: transparent; /* Transparent for neutral impact */
#             color: #00BFFF; /* Dynamic blue for neutral impact text */
#         }
#         .magnitude-counter {
#             background-color: transparent; /* Transparent for the magnitude box */
#             color: #00BFFF; /* Dynamic blue for magnitude text */
#         }
#         .magnitude-counter.high {
#             color: #F44336; /* Red for high magnitude */
#         }
#         .magnitude-counter.medium {
#             color: #FFD700; /* Yellow for medium magnitude */
#         }
#         .magnitude-counter.low {
#             color: #FFFFFF; /* White for low magnitude */
#         }
#         .impact-icon, .intensity-arrow {
#             vertical-align: middle;
#             margin-right: 5px;
#             width: 24px;  /* Adjusted width of the icons */
#             height: 24px; /* Adjusted height of the icons */
#         }
#         .counter-label {
#             font-size: 0.8em;
#             color: #E0E0E0; /* White color for the counter labels */
#             margin-right: 5px;
#             text-transform: uppercase;
#             letter-spacing: 1px;
#         }
#         .description {
#             font-size: 1.1em;
#             margin-bottom: 15px;
#             color: #E0E0E0; /* White color for description */
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <!-- Logo Section -->
#         <img src="data:image/svg+xml;base64,..." alt="Big Data Logo" class="logo">
#
#         <!-- Title Section -->
#         <div class="title">Daily Energy - Gas and Power market update - 2025-11-12</div>
#
#         <!-- Content Section -->
#         <div class="content">
#             <!-- Left Column -->
#             <div class="left-column">
#                 <h2 class="section-title">The Day in Review</h2>
#                 <ul class="bullet-points">
#
#                     <li><b>India's Energy Transition</b>: Achieved 50% non-fossil fuel electricity capacity ahead of 2030 target; significant investments in renewable projects and energy storage technologies.</li>
#
#                     <li><b>UK Decarbonization Strategy</b>: Integrating Carbon Capture and Storage (CCS) with offshore wind to enhance energy security and meet net-zero targets.</li>
#
#                     <li><b>Philippines Electricity Prices</b>: Surge of 49.4% due to natural disasters impacting supply, highlighting vulnerabilities in energy pricing.</li>
#
#                     <li><b>U.S. LNG Exports</b>: Surge driven by regulatory reforms and high international demand, reshaping global energy dynamics, particularly in Europe and Asia.</li>
#
#                     <li><b>Japan's Energy Security</b>: Long-term LNG agreements and offshore wind challenges amid rising project costs and regulatory hurdles.</li>
#
#                     <li><b>Natural Gas Demand</b>: Increased globally as countries transition to cleaner energy; significant investments in LNG infrastructure and projects like the Alaska LNG Project.</li>
#
#                     <li><b>Nigeria's Energy Independence</b>: Introduction of a 15% levy on fuel imports and initiatives to boost local gas production amid ongoing energy poverty challenges.</li>
#
#                     <li><b>Ukraine Conflict Impact</b>: Ongoing military actions disrupt energy infrastructure, prompting diversification of energy sources and increased LNG imports from the U.S.</li>
#
#                     <li><b>
