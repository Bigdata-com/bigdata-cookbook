# %% [markdown]
# <img src="https://bigdata.com/assets/notebooks/bigdata-by-ravenpack-logo.png" width="300" align="center">
# <br>
# <br>
#
# # **Daily Top Trending Topics for Crude Oil**
#
# This Jupyter notebook implements an **agentic workflow** based on the content retrieval from BigData API to **identify, verifiy, reindex, and summarize** the specialized news that are **trending topics** for the crude oil market.
#
# The workflow is structured as follows:
#
# **Step 1- Generation of the Lexicon**: Identify the specialized industry-specific jargon relevant to the crude oil market to ensure a high recall in the content retrieval.
#
# **Step 2- Content Retrieval Based on BigData**: Perform a keyword search on the news content with the Bigdata API to retrieve documents, splitting the search over daily timeframes and multi-threading the content search on the individual keywords for speed purpose.
#
# **Step 3- Topic Clustering and Selection**: Perform topic modelling using a large language model to verify and cluster the news. Then, the summarization ensures topic selection identifying the top trending news for crude oil, while deriving advanced analytics to quantify the trendiness (based on news volume), novelty (based on daily changes in summaries), impact and magnitude (based on the financial materiality on crude oil prices) of the trending topics.
#
# **Step 4- Customized Report Generation**: Customize the ranking system of the summarized topics based on their trendiness, novelty, and financial materiality on crude oil prices, and display a daily market update. For verification purpose, the reports are supported by the granular news and sources.
#
# **Output**
#
# 1. **Daily Market Reports**: A detailed and visually appealing report summarizing the top trending topics for crude oil, with a customizable ranking system to reindex the news.
# 2. **Actionable Dataframe**: A timestamped dataframe containing the granular news clustered into relevant topics, and the advanced analytics of trendiness, novelty, impact, and magnitude scores to be potentially used for backtesting purpose.
#
# **Requirements**
#
# - Credentials for the Bigdata API to perform keyword and document searches on news content.
# - Credentials for the OpenAI API used in the notebook, this could be substituted with any other LLM.
# - A `tools` folder in the same directory as this notebook, containing a Python file named `utils_reports.py` with all required functionalities.
# - A `requirements.txt` file listing all the necessary Python libraries and dependencies. We recommend installing these packages in a virtual environment.

# %% [markdown]
# # Set-Up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.lexicon_generator import LexiconGenerator

# %%
import os
from dotenv import load_dotenv

load_dotenv(os.path.abspath("/home/abouchs/.python_env_var/.env"))
# Out:
# True

# %%
BIGDATA_USERNAME = os.getenv("BIGDATA_USERNAME")
BIGDATA_PASSWORD = os.getenv("BIGDATA_PASSWORD")

# %%
from bigdata_client import Bigdata
bigdata_cred = Bigdata(BIGDATA_USERNAME, BIGDATA_PASSWORD)

# %%
output_dir = f"//home/abouchs/shared/OutputData/abouchs/Bigdata_cookbook/trending_topics/"

# %% [markdown]
# # Step 1- Generation of the Lexicon

# %% [markdown]
# In this step, we identify the specialized industry-specific jargon relevant to the crude oil market to ensure a high recall in the content retrieval.

# %%
main_theme = "Crude Oil"
system_prompt = (
    f"""You are an expert tasked with generating a lexicon of the most important and relevant keywords specific to the given main theme and its related market.

    Your goal is to compile a list of terms that are critical for understanding and analyzing the main theme's market. This lexicon should include only the most essential keywords, phrases, and abbreviations that are directly associated with trading, analysis, logistics, and industry reporting related to the main theme.

    Guidelines:

    1. **Focus on relevance:** Include only the most important and commonly used keywords that are uniquely tied to main theme and its market. These should reflect key concepts, market mechanisms, pricing benchmarks, logistical aspects, and industry-specific terminology.
    2. **Avoid redundancy:** Do not repeat the word of the main theme or its components, such as "Crude" or "Oil" in multiple phrases. Include the main theme only as a standalone term, and focus on other specific terms without redundant repetition.
    3. **Strict exclusion of generic terms:** Exclude any terms that are generic or broadly used in other markets, such as "Arbitrage," "Hedge," "Liquidity," "Spot Price," "Futures Contract," "Backwardation," or "Contango," even if they have a specific meaning in the main theme market. Only include terms that are uniquely relevant to the main theme market and cannot be applied broadly.
    4. **Include specific variations:** Where applicable, provide both the full form and common abbreviations as SEPARATE keywords (e.g., "West Texas Intermediate" and "WTI" or variations like "Brent" and "Brent Crude").
    5. **Ensure clarity:** Each keyword should be concise, clear, and directly relevant to the main theme's market, avoiding any ambiguity.
    6. **Select only the most critical:** There is no need to reach a specific number of keywords. Focus solely on the most crucial terms without padding the list. If fewer keywords meet the criteria, that is acceptable.

    The output should be a lexicon of only the most critical and uniquely relevant keywords related to the main theme market, formatted as a JSON list.
    """
)

# %%
try:
    import asyncio
    asyncio.get_running_loop()
    import nest_asyncio; nest_asyncio.apply()
    print("✅ nest_asyncio applied")
except (RuntimeError, ImportError):
    print("✅ nest_asyncio not needed")
# Out:
# ✅ nest_asyncio applied

# %%
LexiconGenerator = LexiconGenerator(openai_key=os.getenv("OPENAI_API_KEY"), model="gpt-4o", seeds=[123, 123456, 123456789, 456789, 789])

# %%
keywords_lex = LexiconGenerator.generate(theme=main_theme, system_prompt=system_prompt)
# Out:
# [LexiconGenerator] Using seeds: [123, 123456, 123456789, 456789, 789]
# [LexiconGenerator] Raw response for seed 123: {
#     "keywords": [
#         "Brent",
#         "Brent Crude",
#         "WTI",
#         "West Texas Intermediate",
#         "OPEC",
#         "Organization of the Petroleum Exporting Countries",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Crack Spread",
#         "Refinery Margin",
#         "Barrel",
#         "Light Crude",
#         "Heavy Crude",
#         "ULSD",
#         "Ultra-Low Sulfur Diesel",
#         "EIA",
#         "Energy Information Administration",
#         "DOE",
#         "Department of Energy",
#         "Cushing",
#         "Strategic Petroleum Reserve",
#         "Bakken",
#         "Permian Basin",
#         "North Sea Oil",
#         "Middle East Crude",
#         "Asian Crude",
#         "Crude Assay",
#         "Tanker Rates",
#         "Pipeline Tariff",
#         "Floating Storage",
#         "Seaborne Crude",
#         "Crude Export Ban",
#         "Shale Oil",
#         "Bitumen",
#         "Oil Sands",
#         "Fracking",
#         "Hydraulic Fracturing",
#         "Oil Rig Count",
#         "Drilling Rig",
#         "Offshore Drilling",
#         "Onshore Drilling",
#         "Oilfield Services",
#         "Upstream",
#         "Midstream",
#         "Downstream",
#         "Petrochemicals",
#         "Refinery Capacity",
#         "Oil Benchmark",
#         "Crude Oil Inventory"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123: {'keywords': ['Brent', 'Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'Organization of the Petroleum Exporting Countries', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Ultra-Low Sulfur Diesel', 'EIA', 'Energy Information Administration', 'DOE', 'Department of Energy', 'Cushing', 'Strategic Petroleum Reserve', 'Bakken', 'Permian Basin', 'North Sea Oil', 'Middle East Crude', 'Asian Crude', 'Crude Assay', 'Tanker Rates', 'Pipeline Tariff', 'Floating Storage', 'Seaborne Crude', 'Crude Export Ban', 'Shale Oil', 'Bitumen', 'Oil Sands', 'Fracking', 'Hydraulic Fracturing', 'Oil Rig Count', 'Drilling Rig', 'Offshore Drilling', 'Onshore Drilling', 'Oilfield Services', 'Upstream', 'Midstream', 'Downstream', 'Petrochemicals', 'Refinery Capacity', 'Oil Benchmark', 'Crude Oil Inventory']}
# [LexiconGenerator] Raw response for seed 123456: {
#     "keywords": [
#         "Brent Crude",
#         "WTI",
#         "West Texas Intermediate",
#         "OPEC",
#         "OPEC+",
#         "API Gravity",
#         "Sulfur Content",
#         "Sweet Crude",
#         "Sour Crude",
#         "Light Crude",
#         "Heavy Crude",
#         "Crude Oil Benchmarks",
#         "Crude Oil Refining",
#         "Crude Oil Reserves",
#         "Crude Oil Production",
#         "Crude Oil Export",
#         "Crude Oil Import",
#         "Crude Oil Inventory",
#         "Crude Oil Pipeline",
#         "Crude Oil Tanker",
#         "Crude Oil Storage",
#         "Crude Oil Distillation",
#         "Crude Oil Blending",
#         "Crude Oil Cracking",
#         "Crude Oil Fractionation",
#         "Crude Oil Trading",
#         "Crude Oil Market",
#         "Crude Oil Price Differential",
#         "Crude Oil Supply Chain",
#         "Crude Oil Demand",
#         "Crude Oil Exploration",
#         "Crude Oil Drilling",
#         "Crude Oil Refinery",
#         "Crude Oil Spot Market",
#         "Crude Oil Futures Market",
#         "Crude Oil Hedging",
#         "Crude Oil Swaps",
#         "Crude Oil Options",
#         "Crude Oil Contracts",
#         "Crude Oil Volatility",
#         "Crude Oil Geopolitics",
#         "Crude Oil Speculation",
#         "Crude Oil Consumption",
#         "Crude Oil Transportation",
#         "Crude Oil Shipping Routes",
#         "Crude Oil Price Index",
#         "Crude Oil Market Analysis",
#         "Crude Oil Economic Impact",
#         "Crude Oil Environmental Impact",
#         "Crude Oil Regulatory Framework"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123456: {'keywords': ['Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'OPEC+', 'API Gravity', 'Sulfur Content', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crude Oil Benchmarks', 'Crude Oil Refining', 'Crude Oil Reserves', 'Crude Oil Production', 'Crude Oil Export', 'Crude Oil Import', 'Crude Oil Inventory', 'Crude Oil Pipeline', 'Crude Oil Tanker', 'Crude Oil Storage', 'Crude Oil Distillation', 'Crude Oil Blending', 'Crude Oil Cracking', 'Crude Oil Fractionation', 'Crude Oil Trading', 'Crude Oil Market', 'Crude Oil Price Differential', 'Crude Oil Supply Chain', 'Crude Oil Demand', 'Crude Oil Exploration', 'Crude Oil Drilling', 'Crude Oil Refinery', 'Crude Oil Spot Market', 'Crude Oil Futures Market', 'Crude Oil Hedging', 'Crude Oil Swaps', 'Crude Oil Options', 'Crude Oil Contracts', 'Crude Oil Volatility', 'Crude Oil Geopolitics', 'Crude Oil Speculation', 'Crude Oil Consumption', 'Crude Oil Transportation', 'Crude Oil Shipping Routes', 'Crude Oil Price Index', 'Crude Oil Market Analysis', 'Crude Oil Economic Impact', 'Crude Oil Environmental Impact', 'Crude Oil Regulatory Framework']}
# [LexiconGenerator] Raw response for seed 123456789: {
#     "keywords": [
#         "Brent",
#         "Brent Crude",
#         "West Texas Intermediate",
#         "WTI",
#         "OPEC",
#         "OPEC+",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Light Crude",
#         "Heavy Crude",
#         "Crack Spread",
#         "Refinery Utilization",
#         "Strategic Petroleum Reserve",
#         "SPRO",
#         "Barrel",
#         "Barrel of Oil Equivalent",
#         "BOE",
#         "EIA",
#         "Energy Information Administration",
#         "IEA",
#         "International Energy Agency",
#         "Petrochemicals",
#         "Upstream",
#         "Midstream",
#         "Downstream",
#         "Offshore Drilling",
#         "Onshore Drilling",
#         "Fracking",
#         "Hydraulic Fracturing",
#         "Oil Sands",
#         "Tar Sands",
#         "Shale Oil",
#         "Oil Rig",
#         "Oilfield Services",
#         "Exploration and Production",
#         "E&P",
#         "Refining Margin",
#         "Oil Benchmark",
#         "Oil Reserves",
#         "Production Quota",
#         "Oil Export",
#         "Oil Import",
#         "Pipeline",
#         "Tanker",
#         "Floating Storage",
#         "Oil Spill",
#         "Carbon Emissions",
#         "Carbon Capture"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123456789: {'keywords': ['Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPRO', 'Barrel', 'Barrel of Oil Equivalent', 'BOE', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Petrochemicals', 'Upstream', 'Midstream', 'Downstream', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Hydraulic Fracturing', 'Oil Sands', 'Tar Sands', 'Shale Oil', 'Oil Rig', 'Oilfield Services', 'Exploration and Production', 'E&P', 'Refining Margin', 'Oil Benchmark', 'Oil Reserves', 'Production Quota', 'Oil Export', 'Oil Import', 'Pipeline', 'Tanker', 'Floating Storage', 'Oil Spill', 'Carbon Emissions', 'Carbon Capture']}
# [LexiconGenerator] Raw response for seed 456789: {
#     "keywords": [
#         "Brent",
#         "WTI",
#         "OPEC",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Light Crude",
#         "Heavy Crude",
#         "Crack Spread",
#         "Refinery Margin",
#         "Barrel",
#         "Strategic Petroleum Reserve",
#         "Tanker Rates",
#         "Pipeline Capacity",
#         "Offshore Drilling",
#         "Onshore Drilling",
#         "Fracking",
#         "Shale Oil",
#         "Oil Sands",
#         "Upstream",
#         "Midstream",
#         "Downstream",
#         "EIA",
#         "IEA",
#         "Non-OPEC",
#         "Oil Rig Count",
#         "Production Quota",
#         "Oil Benchmark",
#         "Spot Market",
#         "Petrochemicals",
#         "Oilfield Services",
#         "Seismic Survey"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 456789: {'keywords': ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Strategic Petroleum Reserve', 'Tanker Rates', 'Pipeline Capacity', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Shale Oil', 'Oil Sands', 'Upstream', 'Midstream', 'Downstream', 'EIA', 'IEA', 'Non-OPEC', 'Oil Rig Count', 'Production Quota', 'Oil Benchmark', 'Spot Market', 'Petrochemicals', 'Oilfield Services', 'Seismic Survey']}
# [LexiconGenerator] Raw response for seed 789: {
#     "keywords": [
#         "Brent",
#         "Brent Crude",
#         "West Texas Intermediate",
#         "WTI",
#         "OPEC",
#         "OPEC+",
#         "API Gravity",
#         "Sulfur Content",
#         "Sweet Crude",
#         "Sour Crude",
#         "Light Crude",
#         "Heavy Crude",
#         "Crack Spread",
#         "Refinery Utilization",
#         "Strategic Petroleum Reserve",
#         "SPRO",
#         "Barrel",
#         "Barrels per Day",
#         "BPD",
#         "EIA",
#         "Energy Information Administration",
#         "IEA",
#         "International Energy Agency",
#         "Crude Oil Inventory",
#         "Tanker Rates",
#         "Pipeline Capacity",
#         "Seaborne Crude",
#         "Fracking",
#         "Shale Oil",
#         "Oil Sands",
#         "Offshore Drilling",
#         "Upstream",
#         "Midstream",
#         "Downstream",
#         "Oil Rig Count",
#         "Petrochemicals"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 789: {'keywords': ['Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sulfur Content', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPRO', 'Barrel', 'Barrels per Day', 'BPD', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Crude Oil Inventory', 'Tanker Rates', 'Pipeline Capacity', 'Seaborne Crude', 'Fracking', 'Shale Oil', 'Oil Sands', 'Offshore Drilling', 'Upstream', 'Midstream', 'Downstream', 'Oil Rig Count', 'Petrochemicals']}
# [LexiconGenerator] Combined keywords dict: {'keywords': ['Brent', 'Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'Organization of the Petroleum Exporting Countries', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Ultra-Low Sulfur Diesel', 'EIA', 'Energy Information Administration', 'DOE', 'Department of Energy', 'Cushing', 'Strategic Petroleum Reserve', 'Bakken', 'Permian Basin', 'North Sea Oil', 'Middle East Crude', 'Asian Crude', 'Crude Assay', 'Tanker Rates', 'Pipeline Tariff', 'Floating Storage', 'Seaborne Crude', 'Crude Export Ban', 'Shale Oil', 'Bitumen', 'Oil Sands', 'Fracking', 'Hydraulic Fracturing', 'Oil Rig Count', 'Drilling Rig', 'Offshore Drilling', 'Onshore Drilling', 'Oilfield Services', 'Upstream', 'Midstream', 'Downstream', 'Petrochemicals', 'Refinery Capacity', 'Oil Benchmark', 'Crude Oil Inventory', 'Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'OPEC+', 'API Gravity', 'Sulfur Content', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crude Oil Benchmarks', 'Crude Oil Refining', 'Crude Oil Reserves', 'Crude Oil Production', 'Crude Oil Export', 'Crude Oil Import', 'Crude Oil Inventory', 'Crude Oil Pipeline', 'Crude Oil Tanker', 'Crude Oil Storage', 'Crude Oil Distillation', 'Crude Oil Blending', 'Crude Oil Cracking', 'Crude Oil Fractionation', 'Crude Oil Trading', 'Crude Oil Market', 'Crude Oil Price Differential', 'Crude Oil Supply Chain', 'Crude Oil Demand', 'Crude Oil Exploration', 'Crude Oil Drilling', 'Crude Oil Refinery', 'Crude Oil Spot Market', 'Crude Oil Futures Market', 'Crude Oil Hedging', 'Crude Oil Swaps', 'Crude Oil Options', 'Crude Oil Contracts', 'Crude Oil Volatility', 'Crude Oil Geopolitics', 'Crude Oil Speculation', 'Crude Oil Consumption', 'Crude Oil Transportation', 'Crude Oil Shipping Routes', 'Crude Oil Price Index', 'Crude Oil Market Analysis', 'Crude Oil Economic Impact', 'Crude Oil Environmental Impact', 'Crude Oil Regulatory Framework', 'Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPRO', 'Barrel', 'Barrel of Oil Equivalent', 'BOE', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Petrochemicals', 'Upstream', 'Midstream', 'Downstream', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Hydraulic Fracturing', 'Oil Sands', 'Tar Sands', 'Shale Oil', 'Oil Rig', 'Oilfield Services', 'Exploration and Production', 'E&P', 'Refining Margin', 'Oil Benchmark', 'Oil Reserves', 'Production Quota', 'Oil Export', 'Oil Import', 'Pipeline', 'Tanker', 'Floating Storage', 'Oil Spill', 'Carbon Emissions', 'Carbon Capture', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Strategic Petroleum Reserve', 'Tanker Rates', 'Pipeline Capacity', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Shale Oil', 'Oil Sands', 'Upstream', 'Midstream', 'Downstream', 'EIA', 'IEA', 'Non-OPEC', 'Oil Rig Count', 'Production Quota', 'Oil Benchmark', 'Spot Market', 'Petrochemicals', 'Oilfield Services', 'Seismic Survey', 'Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sulfur Content', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPRO', 'Barrel', 'Barrels per Day', 'BPD', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Crude Oil Inventory', 'Tanker Rates', 'Pipeline Capacity', 'Seaborne Crude', 'Fracking', 'Shale Oil', 'Oil Sands', 'Offshore Drilling', 'Upstream', 'Midstream', 'Downstream', 'Oil Rig Count', 'Petrochemicals']}
# [LexiconGenerator] All keywords before deduplication: ['Brent', 'Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'Organization of the Petroleum Exporting Countries', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Ultra-Low Sulfur Diesel', 'EIA', 'Energy Information Administration', 'DOE', 'Department of Energy', 'Cushing', 'Strategic Petroleum Reserve', 'Bakken', 'Permian Basin', 'North Sea Oil', 'Middle East Crude', 'Asian Crude', 'Crude Assay', 'Tanker Rates', 'Pipeline Tariff', 'Floating Storage', 'Seaborne Crude', 'Crude Export Ban', 'Shale Oil', 'Bitumen', 'Oil Sands', 'Fracking', 'Hydraulic Fracturing', 'Oil Rig Count', 'Drilling Rig', 'Offshore Drilling', 'Onshore Drilling', 'Oilfield Services', 'Upstream', 'Midstream', 'Downstream', 'Petrochemicals', 'Refinery Capacity', 'Oil Benchmark', 'Crude Oil Inventory', 'Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'OPEC+', 'API Gravity', 'Sulfur Content', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crude Oil Benchmarks', 'Crude Oil Refining', 'Crude Oil Reserves', 'Crude Oil Production', 'Crude Oil Export', 'Crude Oil Import', 'Crude Oil Inventory', 'Crude Oil Pipeline', 'Crude Oil Tanker', 'Crude Oil Storage', 'Crude Oil Distillation', 'Crude Oil Blending', 'Crude Oil Cracking', 'Crude Oil Fractionation', 'Crude Oil Trading', 'Crude Oil Market', 'Crude Oil Price Differential', 'Crude Oil Supply Chain', 'Crude Oil Demand', 'Crude Oil Exploration', 'Crude Oil Drilling', 'Crude Oil Refinery', 'Crude Oil Spot Market', 'Crude Oil Futures Market', 'Crude Oil Hedging', 'Crude Oil Swaps', 'Crude Oil Options', 'Crude Oil Contracts', 'Crude Oil Volatility', 'Crude Oil Geopolitics', 'Crude Oil Speculation', 'Crude Oil Consumption', 'Crude Oil Transportation', 'Crude Oil Shipping Routes', 'Crude Oil Price Index', 'Crude Oil Market Analysis', 'Crude Oil Economic Impact', 'Crude Oil Environmental Impact', 'Crude Oil Regulatory Framework', 'Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPRO', 'Barrel', 'Barrel of Oil Equivalent', 'BOE', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Petrochemicals', 'Upstream', 'Midstream', 'Downstream', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Hydraulic Fracturing', 'Oil Sands', 'Tar Sands', 'Shale Oil', 'Oil Rig', 'Oilfield Services', 'Exploration and Production', 'E&P', 'Refining Margin', 'Oil Benchmark', 'Oil Reserves', 'Production Quota', 'Oil Export', 'Oil Import', 'Pipeline', 'Tanker', 'Floating Storage', 'Oil Spill', 'Carbon Emissions', 'Carbon Capture', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Strategic Petroleum Reserve', 'Tanker Rates', 'Pipeline Capacity', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Shale Oil', 'Oil Sands', 'Upstream', 'Midstream', 'Downstream', 'EIA', 'IEA', 'Non-OPEC', 'Oil Rig Count', 'Production Quota', 'Oil Benchmark', 'Spot Market', 'Petrochemicals', 'Oilfield Services', 'Seismic Survey', 'Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sulfur Content', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPRO', 'Barrel', 'Barrels per Day', 'BPD', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Crude Oil Inventory', 'Tanker Rates', 'Pipeline Capacity', 'Seaborne Crude', 'Fracking', 'Shale Oil', 'Oil Sands', 'Offshore Drilling', 'Upstream', 'Midstream', 'Downstream', 'Oil Rig Count', 'Petrochemicals']
# [LexiconGenerator] Unique keywords after deduplication: ['Brent', 'Brent Crude', 'WTI', 'West Texas Intermediate', 'OPEC', 'Organization of the Petroleum Exporting Countries', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Ultra-Low Sulfur Diesel', 'EIA', 'Energy Information Administration', 'DOE', 'Department of Energy', 'Cushing', 'Strategic Petroleum Reserve', 'Bakken', 'Permian Basin', 'North Sea Oil', 'Middle East Crude', 'Asian Crude', 'Crude Assay', 'Tanker Rates', 'Pipeline Tariff', 'Floating Storage', 'Seaborne Crude', 'Crude Export Ban', 'Shale Oil', 'Bitumen', 'Oil Sands', 'Fracking', 'Hydraulic Fracturing', 'Oil Rig Count', 'Drilling Rig', 'Offshore Drilling', 'Onshore Drilling', 'Oilfield Services', 'Upstream', 'Midstream', 'Downstream', 'Petrochemicals', 'Refinery Capacity', 'Oil Benchmark', 'Crude Oil Inventory', 'OPEC+', 'Sulfur Content', 'Crude Oil Benchmarks', 'Crude Oil Refining', 'Crude Oil Reserves', 'Crude Oil Production', 'Crude Oil Export', 'Crude Oil Import', 'Crude Oil Pipeline', 'Crude Oil Tanker', 'Crude Oil Storage', 'Crude Oil Distillation', 'Crude Oil Blending', 'Crude Oil Cracking', 'Crude Oil Fractionation', 'Crude Oil Trading', 'Crude Oil Market', 'Crude Oil Price Differential', 'Crude Oil Supply Chain', 'Crude Oil Demand', 'Crude Oil Exploration', 'Crude Oil Drilling', 'Crude Oil Refinery', 'Crude Oil Spot Market', 'Crude Oil Futures Market', 'Crude Oil Hedging', 'Crude Oil Swaps', 'Crude Oil Options', 'Crude Oil Contracts', 'Crude Oil Volatility', 'Crude Oil Geopolitics', 'Crude Oil Speculation', 'Crude Oil Consumption', 'Crude Oil Transportation', 'Crude Oil Shipping Routes', 'Crude Oil Price Index', 'Crude Oil Market Analysis', 'Crude Oil Economic Impact', 'Crude Oil Environmental Impact', 'Crude Oil Regulatory Framework', 'Refinery Utilization', 'SPRO', 'Barrel of Oil Equivalent', 'BOE', 'IEA', 'International Energy Agency', 'Tar Sands', 'Oil Rig', 'Exploration and Production', 'E&P', 'Refining Margin', 'Oil Reserves', 'Production Quota', 'Oil Export', 'Oil Import', 'Pipeline', 'Tanker', 'Oil Spill', 'Carbon Emissions', 'Carbon Capture', 'Pipeline Capacity', 'Non-OPEC', 'Spot Market', 'Seismic Survey', 'Barrels per Day', 'BPD']

# %%
keywords_lex
# Out:
# ['Brent',
#  'Brent Crude',
#  'WTI',
#  'West Texas Intermediate',
#  'OPEC',
#  'Organization of the Petroleum Exporting Countries',
#  'API Gravity',
#  'Sweet Crude',
#  'Sour Crude',
#  'Crack Spread',
#  'Refinery Margin',
#  'Barrel',
#  'Light Crude',
#  'Heavy Crude',
#  'ULSD',
#  'Ultra-Low Sulfur Diesel',
#  'EIA',
#  'Energy Information Administration',
#  'DOE',
#  'Department of Energy',
#  'Cushing',
#  'Strategic Petroleum Reserve',
#  'Bakken',
#  'Permian Basin',
#  'North Sea Oil',
#  'Middle East Crude',
#  'Asian Crude',
#  'Crude Assay',
#  'Tanker Rates',
#  'Pipeline Tariff',
#  'Floating Storage',
#  'Seaborne Crude',
#  'Crude Export Ban',
#  'Shale Oil',
#  'Bitumen',
#  'Oil Sands',
#  'Fracking',
#  'Hydraulic Fracturing',
#  'Oil Rig Count',
#  'Drilling Rig',
#  'Offshore Drilling',
#  'Onshore Drilling',
#  'Oilfield Services',
#  'Upstream',
#  'Midstream',
#  'Downstream',
#  'Petrochemicals',
#  'Refinery Capacity',
#  'Oil Benchmark',
#  'Crude Oil Inventory',
#  'OPEC+',
#  'Sulfur Content',
#  'Crude Oil Benchmarks',
#  'Crude Oil Refining',
#  'Crude Oil Reserves',
#  'Crude Oil Production',
#  'Crude Oil Export',
#  'Crude Oil Import',
#  'Crude Oil Pipeline',
#  'Crude Oil Tanker',
#  'Crude Oil Storage',
#  'Crude Oil Distillation',
#  'Crude Oil Blending',
#  'Crude Oil Cracking',
#  'Crude Oil Fractionation',
#  'Crude Oil Trading',
#  'Crude Oil Market',
#  'Crude Oil Price Differential',
#  'Crude Oil Supply Chain',
#  'Crude Oil Demand',
#  'Crude Oil Exploration',
#  'Crude Oil Drilling',
#  'Crude Oil Refinery',
#  'Crude Oil Spot Market',
#  'Crude Oil Futures Market',
#  'Crude Oil Hedging',
#  'Crude Oil Swaps',
#  'Crude Oil Options',
#  'Crude Oil Contracts',
#  'Crude Oil Volatility',
#  'Crude Oil Geopolitics',
#  'Crude Oil Speculation',
#  'Crude Oil Consumption',
#  'Crude Oil Transportation',
#  'Crude Oil Shipping Routes',
#  'Crude Oil Price Index',
#  'Crude Oil Market Analysis',
#  'Crude Oil Economic Impact',
#  'Crude Oil Environmental Impact',
#  'Crude Oil Regulatory Framework',
#  'Refinery Utilization',
#  'SPRO',
#  'Barrel of Oil Equivalent',
#  'BOE',
#  'IEA',
#  'International Energy Agency',
#  'Tar Sands',
#  'Oil Rig',
#  'Exploration and Production',
#  'E&P',
#  'Refining Margin',
#  'Oil Reserves',
#  'Production Quota',
#  'Oil Export',
#  'Oil Import',
#  'Pipeline',
#  'Tanker',
#  'Oil Spill',
#  'Carbon Emissions',
#  'Carbon Capture',
#  'Pipeline Capacity',
#  'Non-OPEC',
#  'Spot Market',
#  'Seismic Survey',
#  'Barrels per Day',
#  'BPD']

# %%
len(keywords_lex)
# Out:
# 116

# %% [markdown]
# # Step 2- Content Retrieval Based on Bigdata

# %% [markdown]
# In this section, we perform a keyword search on the news content with the Bigdata API to retrieve documents, splitting the search over daily timeframes and multi-threading the content search on the individual keywords for speed purpose. The user can define the time range below to generate daily reports between the start and end dates.

# %%
start_query = '2025-06-21'
end_query = '2025-06-28'

# %%
from src.search_topics import search_by_keywords
results, daily_keyword_count = search_by_keywords(
    keywords=keywords_lex,
    start_date=start_query,
    end_date=end_query,
    freq='D',
    document_limit=10)
# Out:
# About to run 928 queries
# Example Query: Keyword('Brent') over date range: AbsoluteDateRange('2025-06-21T00:00:00', '2025-06-21T23:59:59')
# Querying Bigdata...:  78%|███████▊  | 724/928 [02:36<00:36,  5.55it/s]

# %%
results
# Out:
#                      timestamp                    rp_document_id  \
# 0    2025-06-21 00:00:00+00:00  B795BAAD72F92F10BA5DB89D56DBD7DD
# 1    2025-06-21 00:00:00+00:00  86E659AE53391BE3F217C0EC3B031F97
# 2    2025-06-21 00:00:00+00:00  9E72438557B0F58D96E6DAA5279BD0EF
# 3    2025-06-21 00:00:00+00:00  E2D405BFF0426528C258C62EC5773E36
# 4    2025-06-21 00:00:00+00:00  C47A2AB4D8E9C02F3720F56FC500DE76
# ...                        ...                               ...
# 9055 2025-06-28 23:37:13+00:00  99083749AA42E83A4352A4002BC9479C
# 9057 2025-06-28 23:48:49+00:00  456DB9D74C8F0B01626EE845F8FF4CA6
# 9058 2025-06-28 23:50:36+00:00  DF667772C27122819087C82C1D54C3DD
# 9059 2025-06-28 23:50:36+00:00  DF667772C27122819087C82C1D54C3DD
# 9062 2025-06-28 23:50:36+00:00  DF667772C27122819087C82C1D54C3DD
#
#                                                headline  chunk_number  \
# 0     Former Fulton County Deputy Sheriff Charged wi...           5.0
# 1     Peter Dey Announces Retirement from Gran Tierr...           3.0
# 2     Trafigura Backs Euro Sun's Rovina Valley with ...           9.0
# 3     Nine creates new executive roles as it combine...           6.0
# 4     Nine Announces New Leadership and Plans to Gro...           4.0
# ...                                                 ...           ...
# 9055  3 days after Kullu flash flood, missing teen's...           2.0
# 9057  Caught on camera: Car literally drives through...           2.0
# 9058            The Strategic Empire: Debt & the Dollar          46.0
# 9059            The Strategic Empire: Debt & the Dollar          55.0
# 9062            The Strategic Empire: Debt & the Dollar          47.0
#
#                               sentence_id source_id  \
# 0      B795BAAD72F92F10BA5DB89D56DBD7DD-5    BC923D
# 1      86E659AE53391BE3F217C0EC3B031F97-3    346656
# 2      9E72438557B0F58D96E6DAA5279BD0EF-9    923B93
# 3      E2D405BFF0426528C258C62EC5773E36-6    346656
# 4      C47A2AB4D8E9C02F3720F56FC500DE76-4    346656
# ...                                   ...       ...
# 9055   99083749AA42E83A4352A4002BC9479C-2    80FC03
# 9057   456DB9D74C8F0B01626EE845F8FF4CA6-2    E54C73
# 9058  DF667772C27122819087C82C1D54C3DD-46    EC0C87
# 9059  DF667772C27122819087C82C1D54C3DD-55    EC0C87
# 9062  DF667772C27122819087C82C1D54C3DD-47    EC0C87
#
#                                source_name  \
# 0                  Legal Monitor Worldwide
# 1         Executive Appointments Worldwide
# 2     Financial Services Monitor Worldwide
# 3         Executive Appointments Worldwide
# 4         Executive Appointments Worldwide
# ...                                    ...
# 9055                    The Times Of India
# 9057                              ABC News
# 9058                        Michael Hudson
# 9059                        Michael Hudson
# 9062                        Michael Hudson
#
#                                                    text  \
# 0     She was indicted by a federal grand jury seate...
# 1     About Gran Tierra Energy Inc.\nGran Tierra Ene...
# 2     Shares in Euro Sun have tripled this year to C...
# 3     The company is recruiting for new positions in...
# 4     Sport is still a key part of Nine and the bigg...
# ...                                                 ...
# 9055  They were swept away from a hydropower project...
# 9057  "This is like a movie or something," Patel sai...
# 9058  The United States is unwilling to annul Global...
# 9059  Yes, someday the United States cannot get a fr...
# 9062  However, the condition for letting OPEC countr...
#
#                          keyword        date
# 0                          Brent  2025-06-21
# 1     Exploration and Production  2025-06-21
# 2                       Upstream  2025-06-21
# 3                          Brent  2025-06-21
# 4                          Brent  2025-06-21
# ...                          ...         ...
# 9055                  Downstream  2025-06-28
# 9057                      Barrel  2025-06-28
# 9058                       OPEC+  2025-06-28
# 9059                       OPEC+  2025-06-28
# 9062                        OPEC  2025-06-28
#
# [7478 rows x 10 columns]

# %% [markdown]
# # Step 3- Topic Clustering and Selection

# %% [markdown]
# In this step, we perform topic modelling using a large language model to verify and cluster the news. Then, the summarization ensures topic selection identifying the top trending news for crude oil, while deriving advanced analytics to quantify the trendiness (based on news volume), novelty (based on daily changes in summaries), impact and magnitude (based on the financial materiality on crude oil prices) of the trending topics.

# %% [markdown]
# Before performing the topic clustering, we apply a verification layer to remove the news that are not relative to the oil market

# %%
model = "gpt-4o-mini" 
api_key = os.getenv("OPENAI_API_KEY")

# %%
from src.topics_extractor import process_all_reports
semaphore_size = 1000

# Assuming unique_reports is your DataFrame
filtered_reports = process_all_reports(results, model, api_key, main_theme, semaphore_size)
# Out:
# Filtering News:   0%|          | 0/7478 [00:00<?, ?it/s]

# %% [markdown]
# In this cell, we leverage a LLM to perform topic modeling, identifying and clustering the key topics from the news reports.

# %%
filtered_reports
# Out:
#                      timestamp                    rp_document_id  \
# 0    2025-06-21 00:00:00+00:00  B795BAAD72F92F10BA5DB89D56DBD7DD
# 1    2025-06-21 00:00:00+00:00  86E659AE53391BE3F217C0EC3B031F97
# 2    2025-06-21 00:00:00+00:00  9E72438557B0F58D96E6DAA5279BD0EF
# 3    2025-06-21 00:00:00+00:00  E2D405BFF0426528C258C62EC5773E36
# 4    2025-06-21 00:00:00+00:00  C47A2AB4D8E9C02F3720F56FC500DE76
# ...                        ...                               ...
# 3847 2025-06-28 23:33:44+00:00  42F7600A56C081D0A03B719DAF6A339A
# 3848 2025-06-28 23:33:44+00:00  42F7600A56C081D0A03B719DAF6A339A
# 3849 2025-06-28 23:33:44+00:00  4C596AE14BED3F44AB5D9442B44F1F5F
# 3850 2025-06-28 23:37:13+00:00  99083749AA42E83A4352A4002BC9479C
# 3851 2025-06-28 23:48:49+00:00  456DB9D74C8F0B01626EE845F8FF4CA6
#
#                                                headline  chunk_number  \
# 0     Former Fulton County Deputy Sheriff Charged wi...           5.0
# 1     Peter Dey Announces Retirement from Gran Tierr...           3.0
# 2     Trafigura Backs Euro Sun's Rovina Valley with ...           9.0
# 3     Nine creates new executive roles as it combine...           6.0
# 4     Nine Announces New Leadership and Plans to Gro...           4.0
# ...                                                 ...           ...
# 3847  3 Magnificent S&P 500 Dividend Stocks Down 25%...           5.0
# 3848  3 Magnificent S&P 500 Dividend Stocks Down 25%...           6.0
# 3849  Better Dividend Stock: Kinder Morgan vs. Enter...           1.0
# 3850  3 days after Kullu flash flood, missing teen's...           2.0
# 3851  Caught on camera: Car literally drives through...           2.0
#
#                              sentence_id source_id  \
# 0     B795BAAD72F92F10BA5DB89D56DBD7DD-5    BC923D
# 1     86E659AE53391BE3F217C0EC3B031F97-3    346656
# 2     9E72438557B0F58D96E6DAA5279BD0EF-9    923B93
# 3     E2D405BFF0426528C258C62EC5773E36-6    346656
# 4     C47A2AB4D8E9C02F3720F56FC500DE76-4    346656
# ...                                  ...       ...
# 3847  42F7600A56C081D0A03B719DAF6A339A-5    648085
# 3848  42F7600A56C081D0A03B719DAF6A339A-6    648085
# 3849  4C596AE14BED3F44AB5D9442B44F1F5F-1    648085
# 3850  99083749AA42E83A4352A4002BC9479C-2    80FC03
# 3851  456DB9D74C8F0B01626EE845F8FF4CA6-2    E54C73
#
#                                source_name  \
# 0                  Legal Monitor Worldwide
# 1         Executive Appointments Worldwide
# 2     Financial Services Monitor Worldwide
# 3         Executive Appointments Worldwide
# 4         Executive Appointments Worldwide
# ...                                    ...
# 3847                               AOL.com
# 3848                               AOL.com
# 3849                               AOL.com
# 3850                    The Times Of India
# 3851                              ABC News
#
#                                                    text  \
# 0     She was indicted by a federal grand jury seate...
# 1     About Gran Tierra Energy Inc.\nGran Tierra Ene...
# 2     Shares in Euro Sun have tripled this year to C...
# 3     The company is recruiting for new positions in...
# 4     Sport is still a key part of Nine and the bigg...
# ...                                                 ...
# 3847  A lot of fuel to continue growing\nOneok's sto...
# 3848  Oneok's durable midstream business model has e...
# 3849  If you are looking at Kinder Morgan (NYSE: KMI...
# 3850  They were swept away from a hydropower project...
# 3851  "This is like a movie or something," Patel sai...
#
#                          keyword        date
# 0                          Brent  2025-06-21
# 1     Exploration and Production  2025-06-21
# 2                       Upstream  2025-06-21
# 3                          Brent  2025-06-21
# 4                          Brent  2025-06-21
# ...                          ...         ...
# 3847                   Midstream  2025-06-28
# 3848                   Midstream  2025-06-28
# 3849                   Midstream  2025-06-28
# 3850                  Downstream  2025-06-28
# 3851                      Barrel  2025-06-28
#
# [3852 rows x 10 columns]

# %%
from src.topics_extractor import run_process_all_trending_topics
flattened_trending_topics_df = run_process_all_trending_topics(
    unique_reports=filtered_reports,
    model=model,
    start_query=start_query,
    end_query=end_query,
    api_key=os.environ['OPENAI_API_KEY'],
    main_theme = main_theme,
    batches = 20
)
# Out:
# Extracting Topics for 2025-06-21:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-22:   0%|          | 0/20 [00:00<?, ?it/s]
# Consolidating topic batches:   0%|          | 0/9 [25:21<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-22580' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22581' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22582' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22583' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22584' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22585' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22586' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-22587' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'json' referenced before assignment")>
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 631, in consolidate_trending_topics
#     }
# UnboundLocalError: local variable 'json' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-28001' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-28002' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-27997' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-27995' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-27994' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-27999' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-27996' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Task exception was never retrieved
# future: <Task finished name='Task-27998' coro=<tqdm_asyncio.gather.<locals>.wrap_awaitable() done, defined at /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:75> exception=UnboundLocalError("local variable 'content' referenced before assignment")>
# Traceback (most recent call last):
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 646, in consolidate_trending_topics
#     consolidated_topics = content['consolidated_topics']
# TypeError: string indices must be integers
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py", line 76, in wrap_awaitable
#     return i, await f
#   File "/home/abouchs/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py", line 650, in consolidate_trending_topics
#     raise
# UnboundLocalError: local variable 'content' referenced before assignment
# Consolidating topic batches:   0%|          | 0/9 [15:04<?, ?it/s]
# Extracting Topics for 2025-06-23:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-24:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-25:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-26:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-27:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-28:   0%|          | 0/20 [00:00<?, ?it/s]
# Consolidating topics...
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "Global Oil Demand Trends": [
#             "topic_351",
#             "topic_358",
#             "topic_386",
#             "topic_390",
#             "topic_377"
#         ],
#         "Geopolitical Influence on Oil Supply": [
#             "topic_352",
#             "topic_370",
#             "topic_363",
#             "topic_376",
#             "topic_378",
#             "topic_400"
#         ],
#         "Oil Price Trends and Market Dynamics": [
#             "topic_367",
#             "topic_372",
#             "topic_395",
#             "topic_353"
#         ],
#         "US Oil Inventory and Production Trends": [
#             "topic_361",
#             "topic_374",
#             "topic_388",
#             "topic_369",
#             "topic_381"
#         ],
#         "US Strategic Petroleum Reserve Issues": [
#             "topic_356",
#             "topic_396"
#         ],
#         "Technological Advancements in Oil Production": [
#             "topic_387",
#             "topic_365"
#         ],
#         "OPEC and Market Influence": [
#             "topic_384"
#         ],
#         "Economic Policy and Oil Investment": [
#             "topic_385"
#         ],
#         "Regional Oil Production Developments": [
#             "topic_354",
#             "topic_375",
#             "topic_397",
#             "topic_392",
#             "topic_399"
#         ],
#         "Shipping and Maritime Risks": [
#             "topic_382"
#         ],
#         "US Tariff Policy Impact on Oil Prices": [
#             "topic_383"
#         ],
#         "Demand Trends in OECD vs Non-OECD Countries": [
#             "topic_373"
#         ]
#     }
# }
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 from src.topics_extractor import run_process_all_trending_topics
# ----> 2 flattened_trending_topics_df = run_process_all_trending_topics(
#       3     unique_reports=filtered_reports,
#       4     model=model,
#       5     start_query=start_query,
#       6     end_query=end_query,
#       7     api_key=os.environ['OPENAI_API_KEY'],
#       8     main_theme = main_theme,
#       9     batches = 20
#      10 )
#
# File ~/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py:1176, in run_process_all_trending_topics(unique_reports, start_query, end_query, main_theme, model, api_key, batches, freq)
#    1175 def run_process_all_trending_topics(unique_reports, start_query, end_query, main_theme, model, api_key, batches = 5, freq='D'):
# -> 1176     return asyncio.run(process_all_trending_topics(unique_reports, start_query, end_query, main_theme, model, api_key, batches, freq=freq))
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# File ~/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py:1048, in process_all_trending_topics(unique_reports, start_query, end_query, main_theme, model, api_key, batches, freq)
#    1045     batch_ranges.append(batch)
#    1047 # Run all batch consolidations with a progress bar
# -> 1048 batch_results = await tqdm_asyncio.gather(*batch_tasks, desc="Consolidating topic batches", total=len(batch_tasks))
#    1049 ## The LLM returns a list of dictionaries, each with consolidated topics and their original topic numbers
#    1050 # e.g. [{'consolidated_topic_1': ['topic_1', 'topic_2']}, {'consolidated_topic_2': ['topic_3']}]
#    1051 # these can be topic ids or topic names, depending on the LLM response
#    1052 # Helper: resolve topic ids/names to original topic ids
#    1053 def resolve_to_ids(items, mapping):
#    1054     # A hidden problem is that the LLM may return topic names or ids, so we need to ensure consistency in the dicts every time we receive a response and consolidate topics.
#    1055     # Accepts a list of topic ids or names, returns topic ids
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:79, in tqdm_asyncio.gather(cls, loop, timeout, total, *fs, **tqdm_kwargs)
#      76     return i, await f
#      78 ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79 res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                          total=total, **tqdm_kwargs)]
#      81 return [i for _, i in sorted(res)]
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:79, in <listcomp>(.0)
#      76     return i, await f
#      78 ifs = [wrap_awaitable(i, f) for i, f in enumerate(fs)]
# ---> 79 res = [await f for f in cls.as_completed(ifs, loop=loop, timeout=timeout,
#      80                                          total=total, **tqdm_kwargs)]
#      81 return [i for _, i in sorted(res)]
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py:611, in as_completed.<locals>._wait_for_one()
#     608 if f is None:
#     609     # Dummy value from _on_timeout().
#     610     raise exceptions.TimeoutError
# --> 611 return f.result()
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/tqdm/asyncio.py:76, in tqdm_asyncio.gather.<locals>.wrap_awaitable(i, f)
#      75 async def wrap_awaitable(i, f):
# ---> 76     return i, await f
#
# File ~/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/topics_extractor.py:646, in consolidate_trending_topics(batch_results, model, api_key, main_theme)
#     644 try:
#     645     content = summary['choices'][0]['message']['content']
# --> 646     consolidated_topics = content['consolidated_topics']
#     647 except Exception as e:
#     648     print("JSON decode error:", e)
#
# TypeError: string indices must be integers
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "Geopolitical Tensions Impacting Oil": [
#             "topic_301",
#             "topic_310",
#             "topic_319",
#             "topic_330",
#             "topic_336"
#         ],
#         "OPEC Production Strategies": [
#             "topic_303",
#             "topic_324",
#             "topic_328",
#             "topic_343"
#         ],
#         "US Crude Oil Inventory Dynamics": [
#             "topic_304",
#             "topic_309",
#             "topic_313",
#             "topic_331",
#             "topic_337"
#         ],
#         "China's Crude Oil Demand and Supply": [
#             "topic_306",
#             "topic_318",
#             "topic_333"
#         ],
#         "Impact of Sanctions on Oil Exports": [
#             "topic_317",
#             "topic_320",
#             "topic_338"
#         ],
#         "Market Reactions to Oil Price Movements": [
#             "topic_325",
#             "topic_342"
#         ],
#         "US Economic Indicators Affecting Oil Demand": [
#             "topic_305"
#         ],
#         "Joint Ventures and Strategic Moves in Oil Production": [
#             "topic_302",
#             "topic_326",
#             "topic_348",
#             "topic_349",
#             "topic_350"
#         ],
#         "Environmental Concerns in Oil Operations": [
#             "topic_340",
#             "topic_341",
#             "topic_347"
#         ],
#         "Supply-Demand Imbalance in Oil Market": [
#             "topic_311",
#             "topic_312"
#         ],
#         "Regional Oil Production Challenges": [
#             "topic_322",
#             "topic_346"
#         ],
#         "India's Strategic Oil Initiatives": [
#             "topic_332",
#             "topic_323"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "Iran's Threat to Close the Strait of Hormuz": [
#             "topic_1",
#             "topic_44"
#         ],
#         "Middle East Geopolitical Tensions": [
#             "topic_2",
#             "topic_4",
#             "topic_12",
#             "topic_25",
#             "topic_40"
#         ],
#         "Iran's Oil Exports and Geopolitical Tensions": [
#             "topic_7",
#             "topic_36",
#             "topic_43"
#         ],
#         "US-Iran Conflict and Oil Supply Disruption": [
#             "topic_9",
#             "topic_35",
#             "topic_38",
#             "topic_50"
#         ],
#         "Impact of OPEC+ Production Decisions": [
#             "topic_8",
#             "topic_13",
#             "topic_19",
#             "topic_34"
#         ],
#         "Geopolitical Risks Affecting Oil Prices": [
#             "topic_33",
#             "topic_20",
#             "topic_22"
#         ],
#         "China's Energy Security Concerns": [
#             "topic_37",
#             "topic_23"
#         ],
#         "Economic Factors Impacting Oil Demand": [
#             "topic_3",
#             "topic_27",
#             "topic_10",
#             "topic_46"
#         ],
#         "OPEC's Role in Oil Market Stability": [
#             "topic_11",
#             "topic_39"
#         ],
#         "Market Reactions to Geopolitical Tensions": [
#             "topic_24",
#             "topic_48"
#         ],
#         "Oil Exploration and Production Developments in Egypt": [
#             "topic_26"
#         ],
#         "Fossil Fuel Finance and Investment Trends": [
#             "topic_6",
#             "topic_42"
#         ],
#         "US Crude Oil Futures and Market Trends": [
#             "topic_29",
#             "topic_32"
#         ],
#         "Azeri Light Crude Oil Price Fluctuations": [
#             "topic_16"
#         ],
#         "Western Australian Gas Royalties": [
#             "topic_17"
#         ],
#         "Enterprise Products Partners and Midstream Energy Dynamics": [
#             "topic_30"
#         ],
#         "Hilcorp's Accounting and Compliance Issues": [
#             "topic_31"
#         ],
#         "Phillips 66's Refining Margins and Financial Performance": [
#             "topic_47"
#         ],
#         "Sinopec's Investment in Sri Lanka": [
#             "topic_41"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "Iran's Military Actions and Oil Prices": [
#             "topic_201",
#             "topic_246"
#         ],
#         "Geopolitical Stability in the Strait of Hormuz": [
#             "topic_205",
#             "topic_239"
#         ],
#         "Middle East Tensions and Oil Prices": [
#             "topic_208",
#             "topic_243"
#         ],
#         "U.S. Crude Oil Inventory Trends": [
#             "topic_207",
#             "topic_231",
#             "topic_241",
#             "topic_242"
#         ],
#         "U.S. Strategic Petroleum Reserve Considerations": [
#             "topic_209",
#             "topic_221"
#         ],
#         "Production Increases in Guyana": [
#             "topic_210",
#             "topic_214",
#             "topic_235"
#         ],
#         "Canadian Oil Sands Production Outlook": [
#             "topic_225",
#             "topic_237"
#         ],
#         "OPEC+ Production Dynamics": [
#             "topic_215",
#             "topic_223",
#             "topic_226",
#             "topic_234"
#         ],
#         "Economic Indicators Affecting Oil Demand": [
#             "topic_204",
#             "topic_217",
#             "topic_232",
#             "topic_228"
#         ],
#         "U.S. Oil Production and Rig Count Trends": [
#             "topic_222",
#             "topic_238",
#             "topic_229"
#         ],
#         "Freight Rate Increases Due to Regional Conflicts": [
#             "topic_220"
#         ],
#         "U.S. Gasoline Demand Increase": [
#             "topic_233",
#             "topic_249"
#         ],
#         "Technological Advancements in Petrochemicals": [
#             "topic_245"
#         ],
#         "Coterra's Production Cuts in the Permian Basin": [
#             "topic_212"
#         ],
#         "Market Dynamics: Gasoline and Heating Oil Crack Spreads": [
#             "topic_203",
#             "topic_224"
#         ],
#         "Venezuela's Oil Production Crisis": [
#             "topic_240"
#         ],
#         "China's Oil Imports from Iran": [
#             "topic_247"
#         ],
#         "U.S. Crude Oil Imports": [
#             "topic_248"
#         ],
#         "Ceasefire Impact on Oil Prices": [
#             "topic_218",
#             "topic_227",
#             "topic_236"
#         ],
#         "Rising Canadian Oil Production": [
#             "topic_219"
#         ],
#         "Market Reactions to Economic Indicators": [
#             "topic_232"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "US Military Actions Against Iran": [
#             "topic_101",
#             "topic_103",
#             "topic_136",
#             "topic_138",
#             "topic_120",
#             "topic_118"
#         ],
#         "Geopolitical Tensions Impacting Oil Prices": [
#             "topic_109",
#             "topic_114",
#             "topic_131",
#             "topic_145"
#         ],
#         "Iran's Threat to the Strait of Hormuz": [
#             "topic_117",
#             "topic_119",
#             "topic_137",
#             "topic_123",
#             "topic_124"
#         ],
#         "Brent Crude Oil Benchmark": [
#             "topic_102"
#         ],
#         "OPEC+ Production Capacity and Price Projections": [
#             "topic_104",
#             "topic_133",
#             "topic_146"
#         ],
#         "Declining Domestic Crude Demand": [
#             "topic_105"
#         ],
#         "Environmental Concerns and Oil Spills": [
#             "topic_106"
#         ],
#         "UAE's Strategic Oil Infrastructure": [
#             "topic_107"
#         ],
#         "ACE Energy Group's Expansion in Angola": [
#             "topic_108"
#         ],
#         "US Oil Production and Reserves": [
#             "topic_110"
#         ],
#         "China's Oil Import Dynamics": [
#             "topic_111"
#         ],
#         "Crude Oil Price Fluctuations": [
#             "topic_112",
#             "topic_116"
#         ],
#         "Chevron's Gulf of America Production Growth": [
#             "topic_113"
#         ],
#         "Impact of U.S. Strategic Petroleum Reserve": [
#             "topic_115"
#         ],
#         "Impact of U.S. Crude Oil Exports": [
#             "topic_122"
#         ],
#         "Alternative Oil Export Routes": [
#             "topic_125"
#         ],
#         "Iran-Israel Conflict Impact on Crude Oil Supply": [
#             "topic_126"
#         ],
#         "Refining Margins and Market Dynamics": [
#             "topic_121",
#             "topic_127",
#             "topic_128"
#         ],
#         "Oil Price Influences from Economic Indicators": [
#             "topic_132"
#         ],
#         "Impact of U.S. Dollar on Oil Prices": [
#             "topic_135"
#         ],
#         "US Shale Oil Production Trends": [
#             "topic_143"
#         ],
#         "U.S. Energy Exports and Market Dynamics": [
#             "topic_140"
#         ],
#         "Saudi Arabia's Oil Production and Exports": [
#             "topic_141"
#         ],
#         "Iran's Military Actions and Regional Tensions": [
#             "topic_142"
#         ],
#         "Production Developments in Norway and the North Sea": [
#             "topic_150"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "Market Reactions to Oil Price Trends": [
#             "topic_51",
#             "topic_65"
#         ],
#         "Escalation of Conflict in Iran": [
#             "topic_52",
#             "topic_66",
#             "topic_75",
#             "topic_89",
#             "topic_93"
#         ],
#         "Impact of U.S. Supply on Global Oil Market": [
#             "topic_53",
#             "topic_60",
#             "topic_91"
#         ],
#         "Strait of Hormuz and Global Oil Supply": [
#             "topic_54",
#             "topic_77",
#             "topic_82",
#             "topic_83"
#         ],
#         "Impact of U.S. Military Actions on Oil Prices": [
#             "topic_55",
#             "topic_59",
#             "topic_99"
#         ],
#         "Iran-Israel Conflict Impact on Maritime Insurance": [
#             "topic_56"
#         ],
#         "Azerbaijan's Crude Oil Exports to Indonesia": [
#             "topic_57"
#         ],
#         "OPEC+ Production Increases": [
#             "topic_58",
#             "topic_90"
#         ],
#         "Environmental Concerns from Oil Spills": [
#             "topic_61",
#             "topic_68"
#         ],
#         "India's Increased Oil Imports from Russia": [
#             "topic_62",
#             "topic_64",
#             "topic_85"
#         ],
#         "Geopolitical Tensions and Oil Prices": [
#             "topic_63",
#             "topic_92"
#         ],
#         "Record U.S. Energy Exports": [
#             "topic_69"
#         ],
#         "Labor Strikes in Norway": [
#             "topic_70"
#         ],
#         "Impact of U.S. Monetary Policy on Oil Prices": [
#             "topic_71"
#         ],
#         "Increased US Crude Oil Imports from Iraq": [
#             "topic_72"
#         ],
#         "Civitas Oil Production Challenges": [
#             "topic_73"
#         ],
#         "US Upstream Oil Outlook": [
#             "topic_74"
#         ],
#         "Economic Implications of Rising Oil Prices": [
#             "topic_76",
#             "topic_88"
#         ],
#         "Russia's Role in India's Crude Supply": [
#             "topic_81"
#         ],
#         "OPEC's Spare Capacity and US Shale Oil": [
#             "topic_80",
#             "topic_86"
#         ],
#         "Impact of U.S. Sanctions and Market Dynamics": [
#             "topic_94"
#         ],
#         "Oil Rig Count and U.S. Production Trends": [
#             "topic_95"
#         ],
#         "Chevron's Upstream Growth and Financial Projections": [
#             "topic_96"
#         ],
#         "Impact of US Treasury Yields on Oil Markets": [
#             "topic_97"
#         ],
#         "QatarEnergy's Expansion into Algeria": [
#             "topic_98"
#         ],
#         "U.S. Economic Indicators": [
#             "topic_100"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "California Refinery Closures and Regulatory Changes": [
#             "topic_401",
#             "topic_422",
#             "topic_425"
#         ],
#         "OPEC+ Production Plans and Market Reactions": [
#             "topic_402",
#             "topic_440",
#             "topic_442"
#         ],
#         "Ceasefire in the Middle East": [
#             "topic_403"
#         ],
#         "Civitas Oil and Gas Securities Fraud Allegations": [
#             "topic_404"
#         ],
#         "Oneok's Midstream Business Resilience": [
#             "topic_405"
#         ],
#         "OPEC+ Supply Increase and Economic Slowdown": [
#             "topic_406",
#             "topic_416"
#         ],
#         "Delaware Basin Development": [
#             "topic_407"
#         ],
#         "CME Group's Role in Energy Trading": [
#             "topic_408"
#         ],
#         "India's Strategic Petroleum Reserves Expansion": [
#             "topic_409"
#         ],
#         "Peak U.S. Oil Production Concerns": [
#             "topic_410"
#         ],
#         "Kuwait Oil Price Increase": [
#             "topic_411"
#         ],
#         "Global Crude Oil Market Trends": [
#             "topic_412",
#             "topic_424"
#         ],
#         "Decline in Crude Oil Prices": [
#             "topic_413",
#             "topic_420"
#         ],
#         "Surplus of Imported Re-gasified Liquefied Natural Gas (RLNG)": [
#             "topic_414"
#         ],
#         "Caspian Region Oil Supply": [
#             "topic_415"
#         ],
#         "U.S. Trade Policy and Its Effects on Oil Markets": [
#             "topic_417"
#         ],
#         "Iran's Oil Supply Dynamics": [
#             "topic_418",
#             "topic_419"
#         ],
#         "U.S. Sanctions on Iranian Oil Exports": [
#             "topic_427"
#         ],
#         "Market Fundamentals and Supply Glut": [
#             "topic_428"
#         ],
#         "Geopolitical Tensions Impacting Crude Oil Prices": [
#             "topic_429",
#             "topic_432",
#             "topic_445"
#         ],
#         "UK Oil Stock Requirements": [
#             "topic_430"
#         ],
#         "Whitecap Resources' Production Efficiency": [
#             "topic_431"
#         ],
#         "Canada's Role in U.S. Crude Oil Imports": [
#             "topic_433"
#         ],
#         "Dangote's Nigerian Crude Oil Refinery": [
#             "topic_434"
#         ],
#         "Crude Oil Price Volatility": [
#             "topic_435"
#         ],
#         "ConocoPhillips' Low-Cost Production Strategy": [
#             "topic_436"
#         ],
#         "Nigeria's Oil Production Recovery": [
#             "topic_437"
#         ],
#         "Environmental Concerns from Oil Extraction": [
#             "topic_438",
#             "topic_439"
#         ],
#         "US Oil Production Dynamics": [
#             "topic_441"
#         ],
#         "Strategic Oil Chokepoints": [
#             "topic_447"
#         ],
#         "Market Reactions to OPEC+ Decisions": [
#             "topic_442"
#         ],
#         "Canadian Natural Resources Limited": [
#             "topic_443"
#         ],
#         "Coterra Energy Inc. and Antero Midstream Corporation": [
#             "topic_444"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "North Dakota Oil Production Decline": [
#             "topic_251"
#         ],
#         "Southern Illinois Connector Pipeline Project": [
#             "topic_252"
#         ],
#         "Enhanced Oil Recovery (EOR) with CO2": [
#             "topic_253"
#         ],
#         "U.S. Oil Inventory Decline": [
#             "topic_254",
#             "topic_262",
#             "topic_269",
#             "topic_272",
#             "topic_276",
#             "topic_286",
#             "topic_292"
#         ],
#         "Expansion of Pipeline Capacity in Illinois": [
#             "topic_255"
#         ],
#         "Impact of Lower Oil Prices on Federal Reserve Policy": [
#             "topic_256"
#         ],
#         "Oil Country Tubular Goods Contract in Qatar": [
#             "topic_257"
#         ],
#         "Israel-Iran Truce and Global Supply Risks": [
#             "topic_258"
#         ],
#         "U.S. Federal Reserve's Interest Rate Policy": [
#             "topic_259"
#         ],
#         "OPEC's Influence on Oil Prices": [
#             "topic_260"
#         ],
#         "Impact of U.S. Dollar Value on Oil Prices": [
#             "topic_261"
#         ],
#         "Geopolitical Tensions in East China Sea": [
#             "topic_263"
#         ],
#         "Venezuela's Oil Production Recovery": [
#             "topic_264"
#         ],
#         "Refinery Activity and Gasoline Demand": [
#             "topic_265"
#         ],
#         "Venezuela's Oil Sector Challenges": [
#             "topic_266"
#         ],
#         "India's Diversification of Oil Imports": [
#             "topic_267"
#         ],
#         "Global Oil Supply and Demand Dynamics": [
#             "topic_268"
#         ],
#         "Market Volatility and Price Fluctuations": [
#             "topic_271"
#         ],
#         "Exxon Mobil's Strategic Investments": [
#             "topic_273"
#         ],
#         "Offshore Drilling Controversies in the US": [
#             "topic_270"
#         ],
#         "Offshore Drilling Opposition": [
#             "topic_274"
#         ],
#         "Oil Spill Response Efforts": [
#             "topic_275"
#         ],
#         "Market Reactions to Geopolitical Events": [
#             "topic_278"
#         ],
#         "Midstream Energy Infrastructure and Market Risks": [
#             "topic_279"
#         ],
#         "US Federal Reserve Interest Rate Plans": [
#             "topic_280"
#         ],
#         "Trans Mountain Pipeline and Alberta Crude Access": [
#             "topic_281"
#         ],
#         "US Gasoline Demand and Prices": [
#             "topic_283"
#         ],
#         "Impact of Inventory Data on WTI Oil Prices": [
#             "topic_284"
#         ],
#         "Global Demand Trends for Oil": [
#             "topic_285"
#         ],
#         "Geopolitical Tensions and Tariff Concerns": [
#             "topic_287"
#         ],
#         "Decline in Active U.S. Oil Rigs": [
#             "topic_288"
#         ],
#         "Global Oil Storage Trends": [
#             "topic_289"
#         ],
#         "Impact of Iranian Oil Production on Global Markets": [
#             "topic_290"
#         ],
#         "Microbial Enhanced Oil Recovery (MEOR)": [
#             "topic_291"
#         ],
#         "OPEC+ Output Hikes": [
#             "topic_294"
#         ],
#         "Asia's Crude Oil Imports": [
#             "topic_295"
#         ],
#         "Interest Rate Impact on Oil Prices": [
#             "topic_296"
#         ],
#         "Geopolitical Risks and Oil Prices": [
#             "topic_297"
#         ],
#         "Rising Demand from Asia": [
#             "topic_298"
#         ],
#         "Big Data Analytics in Oil and Gas": [
#             "topic_299"
#         ],
#         "Impact of Refinery Closures on Gas Prices": [
#             "topic_300"
#         ]
#     }
# }
# JSON decode error: string indices must be integers
# Raw content: {
#     "consolidated_topics": {
#         "Turkey's Increased Imports of Urals Crude": [
#             "topic_151"
#         ],
#         "US-Iran Tensions and Oil Supply Risks": [
#             "topic_152",
#             "topic_170"
#         ],
#         "OPEC+ Production Adjustments": [
#             "topic_153",
#             "topic_172",
#             "topic_183",
#             "topic_185"
#         ],
#         "Resistance to New Crude Oil Pipeline in Canada": [
#             "topic_154"
#         ],
#         "Decline in Russian Crude Oil Exports": [
#             "topic_155"
#         ],
#         "Impact of Oil Refinery Closures on Prices": [
#             "topic_156",
#             "topic_171"
#         ],
#         "Western Investment in Iraq's Oil Sector": [
#             "topic_157"
#         ],
#         "U.S. Oil Production Forecasts": [
#             "topic_158",
#             "topic_182"
#         ],
#         "Saudi Arabia's Oil Production Strategy": [
#             "topic_159",
#             "topic_192"
#         ],
#         "Japan's Vulnerability to Oil Price Fluctuations": [
#             "topic_160"
#         ],
#         "Technological Innovations in Oil Recovery": [
#             "topic_161"
#         ],
#         "Middle East Conflict and Oil Prices": [
#             "topic_162"
#         ],
#         "Kazakhstan's Overproduction and OPEC+ Strategy": [
#             "topic_163"
#         ],
#         "U.S. Crude Oil Inventories": [
#             "topic_164"
#         ],
#         "Impact of U.S. Economic Indicators on Oil Prices": [
#             "topic_165"
#         ],
#         "Israel-Iran Ceasefire Impact on Oil Prices": [
#             "topic_166",
#             "topic_175"
#         ],
#         "US Federal Reserve Rate Cuts and Dollar Influence": [
#             "topic_167"
#         ],
#         "India's Energy Security and Crude Oil Imports": [
#             "topic_168"
#         ],
#         "Impact of Lower Oil Prices on Refining Companies": [
#             "topic_169"
#         ],
#         "Freight Rate Surge": [
#             "topic_189"
#         ],
#         "China's Crude Oil Imports and Economic Impact": [
#             "topic_179",
#             "topic_190"
#         ],
#         "Oil Sands Production and Export Capacity Concerns": [
#             "topic_180",
#             "topic_184"
#         ],
#         "Russia's Refinery Output and Global Supply": [
#             "topic_181"
#         ],
#         "U.S. Crude Oil Exports": [
#             "topic_197"
#         ],
#         "Strait of Hormuz and Energy Security": [
#             "topic_178",
#             "topic_198"
#         ],
#         "California Refining Margins": [
#             "topic_199"
#         ],
#         "Oil Rig Count and Production Stability": [
#             "topic_200"
#         ],
#         "Geopolitical Tensions and Oil Supply": [
#             "topic_187"
#         ],
#         "Chevron's Sensitivity to Crude Oil Prices": [
#             "topic_188"
#         ],
#         "Operational Challenges and Geopolitical Risks in Oil Production": [
#             "topic_196"
#         ],
#         "Refining Margins and Gasoline Price Fluctuations": [
#             "topic_195"
#         ],
#         "Impact of U.S. Oilfield Activity on Prices": [
#             "topic_186"
#         ],
#         "U.S. Trade Policies and Oil Prices": [
#             "topic_173"
#         ],
#         "Bank of England's Monetary Policy and Oil Price Fluctuations": [
#             "topic_174"
#         ]
#     }
# }

# %%
flattened_trending_topics_df
# Out:
#             Date                                      Day_in_Review  \
# 0     2025-06-21  - Geopolitical tensions, especially between Ir...
# 1     2025-06-21  - Geopolitical tensions, especially between Ir...
# 7     2025-06-21  - Geopolitical tensions, especially between Ir...
# 8     2025-06-21  - Geopolitical tensions, especially between Ir...
# 10    2025-06-21  - Geopolitical tensions, especially between Ir...
# ...          ...                                                ...
# 1637  2025-06-28  - Geopolitical tensions, especially between Ir...
# 1638  2025-06-28  - Geopolitical tensions, especially between Ir...
# 1639  2025-06-28  - Geopolitical tensions, especially between Ir...
# 1640  2025-06-28  - Geopolitical tensions, especially between Ir...
# 1643  2025-06-28  - Geopolitical tensions, especially between Ir...
#
#                                                   Topic  \
# 0     Geopolitical Tensions Drive Oil Prices Toward ...
# 1     Geopolitical Tensions Drive Oil Prices Toward ...
# 7     Geopolitical Tensions Drive Oil Prices Toward ...
# 8     Geopolitical Tensions Drive Oil Prices Toward ...
# 10    Geopolitical Tensions Drive Oil Prices Toward ...
# ...                                                 ...
# 1637  Geopolitical Tensions Drive Oil Prices Toward ...
# 1638  Geopolitical Tensions Drive Oil Prices Toward ...
# 1639  Geopolitical Tensions Drive Oil Prices Toward ...
# 1640  Geopolitical Tensions Drive Oil Prices Toward ...
# 1643  Geopolitical Tensions Drive Oil Prices Toward ...
#
#                                                 Summary  \
# 0     The ongoing geopolitical tensions, particularl...
# 1     The ongoing geopolitical tensions, particularl...
# 7     The ongoing geopolitical tensions, particularl...
# 8     The ongoing geopolitical tensions, particularl...
# 10    The ongoing geopolitical tensions, particularl...
# ...                                                 ...
# 1637  The ongoing geopolitical tensions, particularl...
# 1638  The ongoing geopolitical tensions, particularl...
# 1639  The ongoing geopolitical tensions, particularl...
# 1640  The ongoing geopolitical tensions, particularl...
# 1643  The ongoing geopolitical tensions, particularl...
#
#                                  Source  \
# 0     Philippine Daily Inquirer via Web
# 1                    Charlotte Observer
# 7                                  MDPI
# 8                        Indian Express
# 10                       Yahoo! Finance
# ...                                 ...
# 1637                     EconoTimes.com
# 1638              Polymerupdate via Web
# 1639              Polymerupdate via Web
# 1640              Polymerupdate via Web
# 1643              Polymerupdate via Web
#
#                                                Headline  \
# 0     Next week's oil price hike seen exceeding P5 p...
# 1     Sheltering in bunker, Iran's supreme leader na...
# 7     Price Forecasting of Crude Oil Using Hybrid Ma...
# 8     World's biggest banks increased fossil fuel fi...
# 10    The Weekend: Markets on edge as Trump ponders ...
# ...                                                 ...
# 1637  California Weighs Fuel Import Boost, Pauses Re...
# 1638  Crude oil stabilizes amid diminishing geopolit...
# 1639  Crude oil stabilizes amid diminishing geopolit...
# 1640  Crude oil stabilizes amid diminishing geopolit...
# 1643  Crude oil stabilizes amid diminishing geopolit...
#
#                                                    Text  Volume_Score  \
# 0     Iran has previously threatened to close the st...             2
# 1     Iran appears to have overcome its initial shoc...             2
# 7     These future directions aim to refine the crud...             1
# 8     "This growth in fossil fuel finance is troubli...             1
# 10    Away from the Middle East bloodshed, investors...             2
# ...                                                 ...           ...
# 1637  The commission also urged Governor Gavin Newso...             1
# 1638  Meanwhile, OPEC+ members have pledged to fully...             3
# 1639  Steady demand increase\nIn its latest monthly ...             3
# 1640  Fundamental shift\nOil traders are gradually s...             3
# 1643  Fundamental shift\nOil traders are gradually s...             1
#
#              Topic_labels                                       Text_Summary
# 0     consolidated_topics  Escalating tensions between Iran and Israel ha...
# 1     consolidated_topics  Iran's escalating military actions against Isr...
# 7     consolidated_topics  Enhanced crude oil forecasting models integrat...
# 8     consolidated_topics  Increased fossil fuel financing poses a long-t...
# 10    consolidated_topics  Central banks maintain rates amid geopolitical...
# ...                   ...                                                ...
# 1637  consolidated_topics  California's declining crude oil production, f...
# 1638  consolidated_topics  OPEC+ plans to increase oil production by 411,...
# 1639  consolidated_topics  OPEC+ forecasts a steady increase in global cr...
# 1640  consolidated_topics  Oil traders are shifting focus to fundamentals...
# 1643  consolidated_topics  Oil traders are shifting focus to fundamentals...
#
# [597 rows x 10 columns]

# %% [markdown]
# **Trendiness and Novelty Scores**: We derive analytics related to the trendiness of the topic based on the news volume, and the novelty of the topic based on the changes in daily summaries, evaluating the uniqueness and freshness of each topic.

# %%
from src.generic_utils_reports import run_process_all_trending_topics_legacy
flattened_trending_topics_df_legacy = run_process_all_trending_topics_legacy(
    unique_reports=filtered_reports,
    model=model,
    start_query=start_query,
    end_query=end_query,
    api_key=os.environ['OPENAI_API_KEY'],
    main_theme = main_theme,
    batchs = 20
)
# Out:
# Creating date ranges from 2025-06-21 00:00:00 to 2025-06-28 00:00:00 with frequency 'D'
# Extracting Topics for 2025-06-21:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-22:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-23:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-24:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-25:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-26:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-27:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-28:   0%|          | 0/20 [00:00<?, ?it/s]
# Consolidating topics...
# Traceback (most recent call last):
#
#   File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3505 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[23], line 2
#     flattened_trending_topics_df_legacy = run_process_all_trending_topics_legacy(
#
#   File ~/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/generic_utils_reports.py:1229 in run_process_all_trending_topics_legacy
#     return asyncio.run(process_all_trending_topics(unique_reports, start_query, end_query, main_theme, model, api_key, batchs))
#
#   File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/nest_asyncio.py:30 in run
#     return loop.run_until_complete(task)
#
#   File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/site-packages/nest_asyncio.py:98 in run_until_complete
#     return f.result()
#
#   File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/futures.py:201 in result
#     raise self._exception
#
#   File /opt/anaconda/envs/cookbook_legacy/lib/python3.9/asyncio/tasks.py:256 in __step
#     result = coro.send(None)
#
#   File ~/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/generic_utils_reports.py:1190 in process_all_trending_topics
#     consolidated_topics_and_summaries = await consolidate_trending_topics(', '.join([f'topic_{i + 1}: "{topic}"' for i, topic in enumerate(unique_topics_and_summaries)]), model, yearmonth, api_key, main_theme)
#
#   File ~/git/bigdata-cookbook/Trending_Topics_Crude_Oil/src/generic_utils_reports.py:813 in consolidate_trending_topics
#     consolidated_topics = eval(summary['choices'][0]['message']['content'])['consolidated_topics']
#
#   File <string>:2401
#     "Geopolitical T
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
# Calculate trendiness and novelty scores, assessing the uniqueness and freshness of each topic
flattened_trending_topics_df = run_add_advanced_novelty_scores(flattened_trending_topics_df, api_key = os.environ['OPENAI_API_KEY'], main_theme = main_theme)
# Out:
# Calculating Novelty Scores:   0%|          | 0/180 [00:00<?, ?it/s]

# %% [markdown]
# **Financial Materiality**: We derive analytics related to the impact (Positive, Negative) and magnitude (High, Medium, Low) of the topics, inferring their  market impact on crude oil prices. The inference is based on the price mechanisms involving supply and demand dynamics, geopolitical factors among others.

# %%
point_of_view = "a crude oil trader, where price is influenced by supply-demand dynamics, geopolitical events, and market sentiment. \
As a trader, you focus on changes in production, inventories, and economic indicators from key markets."


flattened_trending_topics_df = add_market_impact_to_df(flattened_trending_topics_df, api_key = os.environ['OPENAI_API_KEY'], main_theme = main_theme, point_of_view = point_of_view)

# %% [markdown]
# We display the results of topic modeling and summarization. The **Topic** column represents the themes inferred through topic clustering using a LLM, which groups the news articles based on their content and underlying themes. The **Summary** provides a synthesized overview of all news articles within the same topic, offering a high-level view of the key messages for each cluster. The **Topic** is then rephrased into a concise form based on the summary. The **Text_Summary** provides a detailed summary of each individualchunk, capturing its core message.

# %%
flattened_trending_topics_df.head(5)
# Out:
#          Date                                      Day_in_Review  \
# 0  2024-07-25  - **U.S. Crude Inventories Decline**: U.S. cru...
# 3  2024-07-25  - **U.S. Crude Inventories Decline**: U.S. cru...
# 4  2024-07-25  - **U.S. Crude Inventories Decline**: U.S. cru...
# 5  2024-07-25  - **U.S. Crude Inventories Decline**: U.S. cru...
# 6  2024-07-25  - **U.S. Crude Inventories Decline**: U.S. cru...
#
#                                                Topic  \
# 0  U.S. Crude Oil Inventories Plunge 3.7 Million ...
# 3  U.S. Crude Oil Inventories Plunge 3.7 Million ...
# 4  U.S. Crude Oil Inventories Plunge 3.7 Million ...
# 5  US Crude Inventory Decline Fuels Fluctuations ...
# 6  US Crude Inventory Decline Fuels Fluctuations ...
#
#                                              Summary  \
# 0  Recent reports from the U.S. Energy Informatio...
# 3  Recent reports from the U.S. Energy Informatio...
# 4  Recent reports from the U.S. Energy Informatio...
# 5  Brent and West Texas Intermediate (WTI) crude ...
# 6  Brent and West Texas Intermediate (WTI) crude ...
#
#                       Source  \
# 0        Klse I3investor.com
# 3  Financial Express via Web
# 4            RTTNews via Web
# 5                   Livemint
# 6  Business Standard via Web
#
#                                             Headline  \
# 0      PublicInvest Research Headlines - 25 Jul 2024
# 3  Will Nifty hold 24,200 as markets see time & p...
# 4            Taiwan Shares Tipped To Open In The Red
# 5  Indian stock market: 7 key things that changed...
# 6  Market outlook July 25: Global sell-off hints ...
#
#                                                 Text  Volume_Score  \
# 0  Workers are now having a harder time finding j...             5
# 3  The US Dollar Index (DXY), which measures the ...             5
# 4  In economic news, the Commerce Department unex...             5
# 5  Oil Prices Crude oil prices traded lower. Bren...             4
# 6  The US 10-year bond yield quoted around 4.266 ...             4
#
#                                         Text_Summary  Volume_Score  \
# 0  U.S. crude oil inventories unexpectedly droppe...             5
# 3  A slight decline in the US Dollar Index coinci...             5
# 4  U.S. crude oil prices rose following a surpris...             5
# 5  Recent declines in Brent and WTI crude oil pri...             4
# 6  Recent fluctuations in Brent and WTI oil price...             4
#
#   Novelty_Score Impact_Score Magnitude_Score
# 0           New     Negative            High
# 3           New     Negative            High
# 4           New     Negative            High
# 5           New     Positive            High
# 6           New     Positive            High

# %% [markdown]
# For verification purpose, this actionable timestamped dataframe contains the granular news clustered into relevant topics, and also the advanced analytics of trendiness, novelty, impact, and magnitude scores to be potentially used for backtesting.

# %% [markdown]
# # Step 4- Customized Report Generation

# %% [markdown]
# In this step, we rank the topics, allowing the user to customize the ranking system to reindex the news, based on their trendiness, novelty, and financial materiality on crude oil prices. We finally display a daily market update, supported by the corresponding granular news and sources for verification purpose.

# %% [markdown]
# The user selects the date for the report summarizing the top trending topics, and customizes the ranking system to prioritize the topics based on volume (trendiness and media attention), novelty (based on the emergence of new daily news), impact direction (positive or negative), and magnitude (financial materiality). The ranking system prioritizes the criteria in the order specified by the user, allowing for a tailored focus on the most relevant aspects of the data.

# %% [markdown]
# The order in which the criteria are listed in user_selected_ranking determines their priority for ranking the topics within the report. The first criterion in the list has the highest priority, followed by the second, and then the third. The user can customize the ranking by choosing to prioritize impact direction (positive or negative), novelty, magnitude, or volume, and has the flexibility to select 1, 2, or all 3 criteria based on their specific needs.

# %%
specific_date = '2024-07-25'

# Applying the cleaning function to the text in your DataFrame before rendering
flattened_trending_topics_df['Summary'] = flattened_trending_topics_df['Summary'].apply(clean_text)
flattened_trending_topics_df['Day_in_Review'] = flattened_trending_topics_df['Day_in_Review'].apply(clean_text)
flattened_trending_topics_df['Text_Summary'] = flattened_trending_topics_df['Text_Summary'].apply(clean_text)
flattened_trending_topics_df['Topic'] = flattened_trending_topics_df['Topic'].apply(clean_text)

user_selected_ranking = ['novelty', 'volume', 'magnitude']  # User can modify this list to change the ranking order

#impact_filter = 'positive_impact' #User can use the impact_filter to filter out the report

prepared_reports = prepare_data_for_report(flattened_trending_topics_df, user_selected_ranking, impact_filter = None, report_date = specific_date)

# Generate and display the HTML report for each date
for report in prepared_reports:
    html_content = generate_html_report(
        report['date'],
        report['day_in_review'],
        report['topics'],
        'Daily crude oil market update'  # Pass the main theme to dynamically generate the title
    )
    display(HTML(html_content))
    print("")
    print("")
    print("")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Daily crude oil market update - 2024-07-25</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #121212;
#             color: #E0E0E0;
#             margin: 20px;
#             padding: 0;
#             line-height: 1.6;
#         }
#         h1, h2, h3 {
#             color: #0080BF; /* Darker blue color for headings */
#         }
#         .container {
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#             background-color: #1E1E1E;
#             border-radius: 10px;
#             box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.4);
#             position: relative;  /* For positioning the logo */
#         }
#         .title {
#             text-align: center;
#             font-size: 2em;
#             margin-bottom: 20px;
#             color: #00BFFF; /* Dynamic blue color for the title */
#             text-transform: uppercase;
#             letter-spacing: 2px;
#             white-space: nowrap; /* Prevent text wrapping */
#         }
#         .logo {
#             position: absolute;
#             top: 20px;
#             left: 20px; /* Positioned to the left */
#             width: 180px;  /* Adjust the size as needed */
#             height: auto;
#         }
#         .content {
#             display: flex;
#         }
#         .left-column {
#             flex: 1;
#             max-width: 300px;
#             margin-right: 20px;
#         }
#         .right-column {
#             flex: 3;
#         }
#         .separator {
#             width: 2px;
#             background-color: #00BFFF; /* Dynamic blue color for the separator */
#             margin-right: 20px;
#         }
#         .section-title {
#             font-size: 1.5em;
#             margin-bottom: 15px;
#             color: #0080BF; /* Darker blue color for section titles */
#             text-transform: uppercase;
#         }
#         .bullet-points {
#             list-style-type: disc;
#             margin-left: 20px;
#             color: #E0E0E0; /* White color for bullet points */
#         }
#         .topic-section {
#             margin-bottom: 40px;  /* Increased space between updates */
#             padding: 20px;
#             background-color: #2A2A2A;
#             border-radius: 10px;
#             box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.3);
#             position: relative;  /* To position the counters */
#         }
#         .topic-title {
#             font-size: 1.7em;
#             padding-top: 40px; /* Increase space above the title */
#             color: #0080BF; /* Darker blue color for topic titles */
#             text-transform: uppercase;
#         }
#         .counter-container {
#             position: absolute;
#             top: 20px;
#             right: 20px;
#             display: flex;
#             align-items: center;
#             justify-content: flex-start; /* Align content to the left */
#             gap: 20px; /* Space between each counter */
#             margin-bottom: 60px; /* Increased space between the title and counters */
#         }
#         .news-counter, .novelty-counter, .impact-counter, .magnitude-counter {
#             background-color: #00BFFF; /* Dynamic blue color for counters */
#             color: #121212; /* Black text color for counters */
#             padding: 5px 10px;
#             border-radius: 15px;
#             font-weight: bold;
#             font-size: 1em;
#             box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.2);
#             display: flex;
#             align-items: center;  /* Align text and icon vertically */
#         }
#         .novelty-counter {
#             background-color: transparent;
#             color: #FFA500;  /* Orange color for the flame icon and text */
#         }
#         .flame-icon {
#             vertical-align: middle;
#             margin-right: 5px;
#             width: 24px;  /* Adjusted width of the flame icon */
#             height: 24px; /* Adjusted height of the flame icon */
#         }
#         .impact-counter {
#             color: #121212; /* Black text color for impact */
#         }
#         .impact-counter.positive {
#             background-color: #4CAF50; /* Green for positive impact */
#         }
#         .impact-counter.negative {
#             background-color: #F44336; /* Red for negative impact */
#         }
#         .impact-counter.neutral {
#             background-color: transparent; /* Transparent for neutral impact */
#             color: #00BFFF; /* Dynamic blue for neutral impact text */
#         }
#         .magnitude-counter {
#             background-color: transparent; /* Transparent for the magnitude box */
#             color: #00BFFF; /* Dynamic blue for magnitude text */
#         }
#         .magnitude-counter.high {
#             color: #F44336; /* Red for high magnitude */
#         }
#         .magnitude-counter.medium {
#             color: #FFD700; /* Yellow for medium magnitude */
#         }
#         .magnitude-counter.low {
#             color: #FFFFFF; /* White for low magnitude */
#         }
#         .impact-icon, .intensity-arrow {
#             vertical-align: middle;
#             margin-right: 5px;
#             width: 24px;  /* Adjusted width of the icons */
#             height: 24px; /* Adjusted height of the icons */
#         }
#         .counter-label {
#             font-size: 0.8em;
#             color: #E0E0E0; /* White color for the counter labels */
#             margin-right: 5px;
#             text-transform: uppercase;
#             letter-spacing: 1px;
#         }
#         .description {
#             font-size: 1.1em;
#             margin-bottom: 15px;
#             color: #E0E0E0; /* White color for description */
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <!-- Logo Section -->
#         <img src="bigdata-logo-white.svg" alt="Big Data Logo" class="logo">
#
#         <!-- Title Section -->
#         <div class="title">Daily crude oil market update - 2024-07-25</div>
#
#         <!-- Content Section -->
#         <div class="content">
#             <!-- Left Column -->
#             <div class="left-column">
#                 <h2 class="section-title">The Day in Review</h2>
#                 <ul class="bullet-points">
#
#                     <li>U.S. Crude Inventories Decline: U.S. crude oil inventories fell by 3.74 million barrels, marking the fourth consecutive week of reductions, leading to upward pressure on prices (WTI at \$77.30, Brent at \$81.38).</li>
#
#                     <li>OPEC Overproduction Crisis: OPEC faces a 2.28 million barrels per day overproduction issue, complicating efforts to stabilize prices amid compliance struggles.</li>
#
#                     <li>Geopolitical Tensions: Ongoing conflicts in the Middle East and Ukraine, along with recent Israeli airstrikes on oil facilities, contribute to market volatility and supply chain disruptions.</li>
#
#                     <li>China's Economic Slowdown: China's growth rate of 4.7% raises concerns about declining oil demand, impacting global prices and refinery margins.</li>
#
#                     <li>Environmental Incident: The sinking of the MT Terra Nova in the Philippines has resulted in a significant oil spill, raising environmental concerns and highlighting vulnerabilities in maritime transport.</li>
#
#                     <li>TotalEnergies Profit Decline: TotalEnergies reported a 34% drop in refining income due to reduced demand and declining margins, reflecting broader market pressures.</li>
#
#                     <li>India's Import Shift: India is reducing oil imports from Russia in favor of U.S. sources, influenced by geopolitical factors and aiming for enhanced energy security.</li>
#
#                     <li>Federal Reserve Impact: U.S. interest rate hikes are affecting oil prices by increasing borrowing costs, leading to reduced consumer demand.</li>
#
#                     <li>Russia's Export Restrictions: Russia's gasoline export restricti
