# %% [markdown]
# <img src="https://bigdata.com/assets/notebooks/bigdata-by-ravenpack-logo.png" width="300" align="center">
# <br>
# <br>
#
# # **Daily Top Trending Topics for Crude Oil**
#
# This Jupyter notebook implements an **agentic workflow** based on the content retrieval from BigData API to **identify, verifiy, reindex, and summarize** the specialized news that are **trending topics** for the crude oil market.
#
# The workflow is structured as follows:
#
# **Step 1- Generation of the Lexicon**: Identify the specialized industry-specific jargon relevant to the crude oil market to ensure a high recall in the content retrieval.
#
# **Step 2- Content Retrieval Based on BigData**: Perform a keyword search on the news content with the Bigdata API to retrieve documents, splitting the search over daily timeframes and multi-threading the content search on the individual keywords for speed purpose.
#
# **Step 3- Topic Clustering and Selection**: Perform topic modelling using a large language model to verify and cluster the news. Then, the summarization ensures topic selection identifying the top trending news for crude oil, while deriving advanced analytics to quantify the trendiness (based on news volume), novelty (based on daily changes in summaries), impact and magnitude (based on the financial materiality on crude oil prices) of the trending topics.
#
# **Step 4- Customized Report Generation**: Customize the ranking system of the summarized topics based on their trendiness, novelty, and financial materiality on crude oil prices, and display a daily market update. For verification purpose, the reports are supported by the granular news and sources.
#
# **Output**
#
# 1. **Daily Market Reports**: A detailed and visually appealing report summarizing the top trending topics for crude oil, with a customizable ranking system to reindex the news.
# 2. **Actionable Dataframe**: A timestamped dataframe containing the granular news clustered into relevant topics, and the advanced analytics of trendiness, novelty, impact, and magnitude scores to be potentially used for backtesting purpose.
#
# **Requirements**
#
# - Credentials for the Bigdata API to perform keyword and document searches on news content.
# - Credentials for the OpenAI API used in the notebook, this could be substituted with any other LLM.
# - A `tools` folder in the same directory as this notebook, containing a Python file named `utils_reports.py` with all required functionalities.
# - A `requirements.txt` file listing all the necessary Python libraries and dependencies. We recommend installing these packages in a virtual environment.

# %% [markdown]
# # Set-Up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.lexicon_generator import LexiconGenerator

# %%
import os
from dotenv import load_dotenv

load_dotenv(os.path.abspath("/home/abouchs/.python_env_var/.env"))
# Out:
# True

# %%
BIGDATA_USERNAME = os.getenv("BIGDATA_USERNAME")
BIGDATA_PASSWORD = os.getenv("BIGDATA_PASSWORD")

# %%
from bigdata_client import Bigdata
bigdata_cred = Bigdata(BIGDATA_USERNAME, BIGDATA_PASSWORD)

# %%
output_dir = f"//home/abouchs/shared/OutputData/abouchs/Bigdata_cookbook/trending_topics/"

# %% [markdown]
# # Step 1- Generation of the Lexicon

# %% [markdown]
# In this step, we identify the specialized industry-specific jargon relevant to the crude oil market to ensure a high recall in the content retrieval.

# %%
main_theme = "Crude Oil"
system_prompt = (
    f"""You are an expert tasked with generating a lexicon of the most important and relevant keywords specific to the given main theme and its related market.

    Your goal is to compile a list of terms that are critical for understanding and analyzing the main theme's market. This lexicon should include only the most essential keywords, phrases, and abbreviations that are directly associated with trading, analysis, logistics, and industry reporting related to the main theme.

    Guidelines:

    1. **Focus on relevance:** Include only the most important and commonly used keywords that are uniquely tied to main theme and its market. These should reflect key concepts, market mechanisms, pricing benchmarks, logistical aspects, and industry-specific terminology.
    2. **Avoid redundancy:** Do not repeat the word of the main theme or its components, such as "Crude" or "Oil" in multiple phrases. Include the main theme only as a standalone term, and focus on other specific terms without redundant repetition.
    3. **Strict exclusion of generic terms:** Exclude any terms that are generic or broadly used in other markets, such as "Arbitrage," "Hedge," "Liquidity," "Spot Price," "Futures Contract," "Backwardation," or "Contango," even if they have a specific meaning in the main theme market. Only include terms that are uniquely relevant to the main theme market and cannot be applied broadly.
    4. **Include specific variations:** Where applicable, provide both the full form and common abbreviations as SEPARATE keywords (e.g., "West Texas Intermediate" and "WTI" or variations like "Brent" and "Brent Crude").
    5. **Ensure clarity:** Each keyword should be concise, clear, and directly relevant to the main theme's market, avoiding any ambiguity.
    6. **Select only the most critical:** There is no need to reach a specific number of keywords. Focus solely on the most crucial terms without padding the list. If fewer keywords meet the criteria, that is acceptable.

    The output should be a lexicon of only the most critical and uniquely relevant keywords related to the main theme market, formatted as a JSON list.
    """
)

# %%
try:
    import asyncio
    asyncio.get_running_loop()
    import nest_asyncio; nest_asyncio.apply()
    print("✅ nest_asyncio applied")
except (RuntimeError, ImportError):
    print("✅ nest_asyncio not needed")
# Out:
# ✅ nest_asyncio applied

# %%
LexiconGenerator = LexiconGenerator(openai_key=os.getenv("OPENAI_API_KEY"), model="gpt-4o", seeds=[123, 123456, 123456789, 456789, 789])

# %%
keywords_lex = LexiconGenerator.generate(theme=main_theme, system_prompt=system_prompt)
# Out:
# [LexiconGenerator] Using seeds: [123, 123456, 123456789, 456789, 789]
# [LexiconGenerator] Raw response for seed 123: {
#     "keywords": [
#         "Brent",
#         "WTI",
#         "OPEC",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Crack Spread",
#         "Refinery Throughput",
#         "Strategic Petroleum Reserve",
#         "Barrel",
#         "Tanker Rates",
#         "Seaborne Trade",
#         "Pipeline Capacity",
#         "Upstream",
#         "Downstream",
#         "Midstream",
#         "EIA",
#         "IEA",
#         "Rigs Count",
#         "Fracking",
#         "Shale Oil",
#         "Non-OPEC",
#         "Oil Sands",
#         "Offshore Drilling",
#         "Oilfield Services",
#         "Production Sharing Agreement",
#         "Exploration and Production",
#         "Hydrocarbon Reserves",
#         "Crude Assay",
#         "Spot Charter"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123: {'keywords': ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Throughput', 'Strategic Petroleum Reserve', 'Barrel', 'Tanker Rates', 'Seaborne Trade', 'Pipeline Capacity', 'Upstream', 'Downstream', 'Midstream', 'EIA', 'IEA', 'Rigs Count', 'Fracking', 'Shale Oil', 'Non-OPEC', 'Oil Sands', 'Offshore Drilling', 'Oilfield Services', 'Production Sharing Agreement', 'Exploration and Production', 'Hydrocarbon Reserves', 'Crude Assay', 'Spot Charter']}
# [LexiconGenerator] Raw response for seed 123456: {
#     "keywords": [
#         "Brent",
#         "WTI",
#         "OPEC",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Crack Spread",
#         "Refinery Margin",
#         "Light Crude",
#         "Heavy Crude",
#         "Tanker Rates",
#         "Strategic Petroleum Reserve",
#         "Barrel",
#         "EIA",
#         "NYMEX",
#         "ICE",
#         "Petrochemicals",
#         "Upstream",
#         "Midstream",
#         "Downstream",
#         "Oil Sands",
#         "Shale Oil",
#         "Fracking",
#         "Offshore Drilling",
#         "Onshore Drilling",
#         "Oil Rig",
#         "Pipeline",
#         "Seaborne Trade",
#         "Floating Storage",
#         "Crude Assay",
#         "Refinery Throughput",
#         "Distillation",
#         "Hydrocracking",
#         "Desulfurization",
#         "Oil Benchmark",
#         "Price Differential",
#         "Non-OPEC",
#         "Oilfield Services",
#         "Production Cut",
#         "Geopolitical Risk"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123456: {'keywords': ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Light Crude', 'Heavy Crude', 'Tanker Rates', 'Strategic Petroleum Reserve', 'Barrel', 'EIA', 'NYMEX', 'ICE', 'Petrochemicals', 'Upstream', 'Midstream', 'Downstream', 'Oil Sands', 'Shale Oil', 'Fracking', 'Offshore Drilling', 'Onshore Drilling', 'Oil Rig', 'Pipeline', 'Seaborne Trade', 'Floating Storage', 'Crude Assay', 'Refinery Throughput', 'Distillation', 'Hydrocracking', 'Desulfurization', 'Oil Benchmark', 'Price Differential', 'Non-OPEC', 'Oilfield Services', 'Production Cut', 'Geopolitical Risk']}
# [LexiconGenerator] Raw response for seed 123456789: {
#     "keywords": [
#         "Brent",
#         "Brent Crude",
#         "West Texas Intermediate",
#         "WTI",
#         "OPEC",
#         "OPEC+",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Light Crude",
#         "Heavy Crude",
#         "Crack Spread",
#         "Refinery Utilization",
#         "Strategic Petroleum Reserve",
#         "SPR",
#         "Barrel",
#         "Bbl",
#         "EIA",
#         "Energy Information Administration",
#         "IEA",
#         "International Energy Agency",
#         "Crude Assay",
#         "Tanker Rates",
#         "Floating Storage",
#         "Pipeline Capacity",
#         "Seaborne Crude",
#         "Offshore Drilling",
#         "Onshore Drilling",
#         "Fracking",
#         "Shale Oil",
#         "Bitumen",
#         "Tar Sands",
#         "Oil Sands",
#         "Upstream",
#         "Midstream",
#         "Downstream",
#         "Refining Margin",
#         "Petrochemicals",
#         "Oil Rig Count",
#         "Drilling Rig",
#         "Exploration and Production",
#         "E&P",
#         "Oilfield Services",
#         "Production Sharing Agreement",
#         "PSA",
#         "Oil Benchmark",
#         "Crude Differential",
#         "Cargo Nomination",
#         "Liftings",
#         "Tanker Chartering",
#         "Oil Spill",
#         "Environmental Impact Assessment",
#         "EIA Report",
#         "Geopolitical Risk"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 123456789: {'keywords': ['Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPR', 'Barrel', 'Bbl', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Crude Assay', 'Tanker Rates', 'Floating Storage', 'Pipeline Capacity', 'Seaborne Crude', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Shale Oil', 'Bitumen', 'Tar Sands', 'Oil Sands', 'Upstream', 'Midstream', 'Downstream', 'Refining Margin', 'Petrochemicals', 'Oil Rig Count', 'Drilling Rig', 'Exploration and Production', 'E&P', 'Oilfield Services', 'Production Sharing Agreement', 'PSA', 'Oil Benchmark', 'Crude Differential', 'Cargo Nomination', 'Liftings', 'Tanker Chartering', 'Oil Spill', 'Environmental Impact Assessment', 'EIA Report', 'Geopolitical Risk']}
# [LexiconGenerator] Raw response for seed 456789:
# {
#     "keywords": [
#         "Brent",
#         "WTI",
#         "OPEC",
#         "API Gravity",
#         "Sweet Crude",
#         "Sour Crude",
#         "Light Crude",
#         "Heavy Crude",
#         "Crack Spread",
#         "Refinery Margin",
#         "Barrel",
#         "Tanker",
#         "Strategic Petroleum Reserve",
#         "EIA",
#         "API Report",
#         "Non-OPEC",
#         "OPEC+",
#         "Shale Oil",
#         "Oil Sands",
#         "Upstream",
#         "Downstream",
#         "Midstream",
#         "Offshore Drilling",
#         "Onshore Drilling",
#         "Fracking",
#         "Oil Rig",
#         "Production Quota",
#         "Oilfield Services",
#         "Crude Assay",
#         "Floating Storage",
#         "Pipeline"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 456789: {'keywords': ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Tanker', 'Strategic Petroleum Reserve', 'EIA', 'API Report', 'Non-OPEC', 'OPEC+', 'Shale Oil', 'Oil Sands', 'Upstream', 'Downstream', 'Midstream', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Oil Rig', 'Production Quota', 'Oilfield Services', 'Crude Assay', 'Floating Storage', 'Pipeline']}
# [LexiconGenerator] Raw response for seed 789: {
#     "keywords": [
#         "Brent",
#         "WTI",
#         "OPEC",
#         "API Gravity",
#         "Sour Crude",
#         "Sweet Crude",
#         "Crack Spread",
#         "Refinery Margin",
#         "Barrel",
#         "Light Crude",
#         "Heavy Crude",
#         "ULSD",
#         "Middle Distillates",
#         "Tanker Rates",
#         "Strategic Petroleum Reserve",
#         "EIA",
#         "Non-OPEC",
#         "Shale Oil",
#         "Oil Sands",
#         "Offshore Drilling",
#         "Fracking",
#         "Oil Rig Count",
#         "Production Cut",
#         "Oil Benchmark",
#         "Crude Assay",
#         "Floating Storage",
#         "Pipeline Capacity",
#         "Seaborne Trade",
#         "Refining Capacity",
#         "Upstream",
#         "Downstream",
#         "Midstream",
#         "Petrochemicals",
#         "Oilfield Services",
#         "Exploration & Production",
#         "Integrated Oil Company",
#         "National Oil Company",
#         "Oil Major",
#         "Energy Information Administration",
#         "Organization of the Petroleum Exporting Countries"
#     ]
# }
# [LexiconGenerator] Parsed JSON for seed 789: {'keywords': ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sour Crude', 'Sweet Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Middle Distillates', 'Tanker Rates', 'Strategic Petroleum Reserve', 'EIA', 'Non-OPEC', 'Shale Oil', 'Oil Sands', 'Offshore Drilling', 'Fracking', 'Oil Rig Count', 'Production Cut', 'Oil Benchmark', 'Crude Assay', 'Floating Storage', 'Pipeline Capacity', 'Seaborne Trade', 'Refining Capacity', 'Upstream', 'Downstream', 'Midstream', 'Petrochemicals', 'Oilfield Services', 'Exploration & Production', 'Integrated Oil Company', 'National Oil Company', 'Oil Major', 'Energy Information Administration', 'Organization of the Petroleum Exporting Countries']}
# [LexiconGenerator] Combined keywords dict: {'keywords': ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Throughput', 'Strategic Petroleum Reserve', 'Barrel', 'Tanker Rates', 'Seaborne Trade', 'Pipeline Capacity', 'Upstream', 'Downstream', 'Midstream', 'EIA', 'IEA', 'Rigs Count', 'Fracking', 'Shale Oil', 'Non-OPEC', 'Oil Sands', 'Offshore Drilling', 'Oilfield Services', 'Production Sharing Agreement', 'Exploration and Production', 'Hydrocarbon Reserves', 'Crude Assay', 'Spot Charter', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Light Crude', 'Heavy Crude', 'Tanker Rates', 'Strategic Petroleum Reserve', 'Barrel', 'EIA', 'NYMEX', 'ICE', 'Petrochemicals', 'Upstream', 'Midstream', 'Downstream', 'Oil Sands', 'Shale Oil', 'Fracking', 'Offshore Drilling', 'Onshore Drilling', 'Oil Rig', 'Pipeline', 'Seaborne Trade', 'Floating Storage', 'Crude Assay', 'Refinery Throughput', 'Distillation', 'Hydrocracking', 'Desulfurization', 'Oil Benchmark', 'Price Differential', 'Non-OPEC', 'Oilfield Services', 'Production Cut', 'Geopolitical Risk', 'Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPR', 'Barrel', 'Bbl', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Crude Assay', 'Tanker Rates', 'Floating Storage', 'Pipeline Capacity', 'Seaborne Crude', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Shale Oil', 'Bitumen', 'Tar Sands', 'Oil Sands', 'Upstream', 'Midstream', 'Downstream', 'Refining Margin', 'Petrochemicals', 'Oil Rig Count', 'Drilling Rig', 'Exploration and Production', 'E&P', 'Oilfield Services', 'Production Sharing Agreement', 'PSA', 'Oil Benchmark', 'Crude Differential', 'Cargo Nomination', 'Liftings', 'Tanker Chartering', 'Oil Spill', 'Environmental Impact Assessment', 'EIA Report', 'Geopolitical Risk', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Tanker', 'Strategic Petroleum Reserve', 'EIA', 'API Report', 'Non-OPEC', 'OPEC+', 'Shale Oil', 'Oil Sands', 'Upstream', 'Downstream', 'Midstream', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Oil Rig', 'Production Quota', 'Oilfield Services', 'Crude Assay', 'Floating Storage', 'Pipeline', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sour Crude', 'Sweet Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Middle Distillates', 'Tanker Rates', 'Strategic Petroleum Reserve', 'EIA', 'Non-OPEC', 'Shale Oil', 'Oil Sands', 'Offshore Drilling', 'Fracking', 'Oil Rig Count', 'Production Cut', 'Oil Benchmark', 'Crude Assay', 'Floating Storage', 'Pipeline Capacity', 'Seaborne Trade', 'Refining Capacity', 'Upstream', 'Downstream', 'Midstream', 'Petrochemicals', 'Oilfield Services', 'Exploration & Production', 'Integrated Oil Company', 'National Oil Company', 'Oil Major', 'Energy Information Administration', 'Organization of the Petroleum Exporting Countries']}
# [LexiconGenerator] All keywords before deduplication: ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Throughput', 'Strategic Petroleum Reserve', 'Barrel', 'Tanker Rates', 'Seaborne Trade', 'Pipeline Capacity', 'Upstream', 'Downstream', 'Midstream', 'EIA', 'IEA', 'Rigs Count', 'Fracking', 'Shale Oil', 'Non-OPEC', 'Oil Sands', 'Offshore Drilling', 'Oilfield Services', 'Production Sharing Agreement', 'Exploration and Production', 'Hydrocarbon Reserves', 'Crude Assay', 'Spot Charter', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Margin', 'Light Crude', 'Heavy Crude', 'Tanker Rates', 'Strategic Petroleum Reserve', 'Barrel', 'EIA', 'NYMEX', 'ICE', 'Petrochemicals', 'Upstream', 'Midstream', 'Downstream', 'Oil Sands', 'Shale Oil', 'Fracking', 'Offshore Drilling', 'Onshore Drilling', 'Oil Rig', 'Pipeline', 'Seaborne Trade', 'Floating Storage', 'Crude Assay', 'Refinery Throughput', 'Distillation', 'Hydrocracking', 'Desulfurization', 'Oil Benchmark', 'Price Differential', 'Non-OPEC', 'Oilfield Services', 'Production Cut', 'Geopolitical Risk', 'Brent', 'Brent Crude', 'West Texas Intermediate', 'WTI', 'OPEC', 'OPEC+', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Utilization', 'Strategic Petroleum Reserve', 'SPR', 'Barrel', 'Bbl', 'EIA', 'Energy Information Administration', 'IEA', 'International Energy Agency', 'Crude Assay', 'Tanker Rates', 'Floating Storage', 'Pipeline Capacity', 'Seaborne Crude', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Shale Oil', 'Bitumen', 'Tar Sands', 'Oil Sands', 'Upstream', 'Midstream', 'Downstream', 'Refining Margin', 'Petrochemicals', 'Oil Rig Count', 'Drilling Rig', 'Exploration and Production', 'E&P', 'Oilfield Services', 'Production Sharing Agreement', 'PSA', 'Oil Benchmark', 'Crude Differential', 'Cargo Nomination', 'Liftings', 'Tanker Chartering', 'Oil Spill', 'Environmental Impact Assessment', 'EIA Report', 'Geopolitical Risk', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Light Crude', 'Heavy Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Tanker', 'Strategic Petroleum Reserve', 'EIA', 'API Report', 'Non-OPEC', 'OPEC+', 'Shale Oil', 'Oil Sands', 'Upstream', 'Downstream', 'Midstream', 'Offshore Drilling', 'Onshore Drilling', 'Fracking', 'Oil Rig', 'Production Quota', 'Oilfield Services', 'Crude Assay', 'Floating Storage', 'Pipeline', 'Brent', 'WTI', 'OPEC', 'API Gravity', 'Sour Crude', 'Sweet Crude', 'Crack Spread', 'Refinery Margin', 'Barrel', 'Light Crude', 'Heavy Crude', 'ULSD', 'Middle Distillates', 'Tanker Rates', 'Strategic Petroleum Reserve', 'EIA', 'Non-OPEC', 'Shale Oil', 'Oil Sands', 'Offshore Drilling', 'Fracking', 'Oil Rig Count', 'Production Cut', 'Oil Benchmark', 'Crude Assay', 'Floating Storage', 'Pipeline Capacity', 'Seaborne Trade', 'Refining Capacity', 'Upstream', 'Downstream', 'Midstream', 'Petrochemicals', 'Oilfield Services', 'Exploration & Production', 'Integrated Oil Company', 'National Oil Company', 'Oil Major', 'Energy Information Administration', 'Organization of the Petroleum Exporting Countries']
# [LexiconGenerator] Unique keywords after deduplication: ['Brent', 'WTI', 'OPEC', 'API Gravity', 'Sweet Crude', 'Sour Crude', 'Crack Spread', 'Refinery Throughput', 'Strategic Petroleum Reserve', 'Barrel', 'Tanker Rates', 'Seaborne Trade', 'Pipeline Capacity', 'Upstream', 'Downstream', 'Midstream', 'EIA', 'IEA', 'Rigs Count', 'Fracking', 'Shale Oil', 'Non-OPEC', 'Oil Sands', 'Offshore Drilling', 'Oilfield Services', 'Production Sharing Agreement', 'Exploration and Production', 'Hydrocarbon Reserves', 'Crude Assay', 'Spot Charter', 'Refinery Margin', 'Light Crude', 'Heavy Crude', 'NYMEX', 'ICE', 'Petrochemicals', 'Onshore Drilling', 'Oil Rig', 'Pipeline', 'Floating Storage', 'Distillation', 'Hydrocracking', 'Desulfurization', 'Oil Benchmark', 'Price Differential', 'Production Cut', 'Geopolitical Risk', 'Brent Crude', 'West Texas Intermediate', 'OPEC+', 'Refinery Utilization', 'SPR', 'Bbl', 'Energy Information Administration', 'International Energy Agency', 'Seaborne Crude', 'Bitumen', 'Tar Sands', 'Refining Margin', 'Oil Rig Count', 'Drilling Rig', 'E&P', 'PSA', 'Crude Differential', 'Cargo Nomination', 'Liftings', 'Tanker Chartering', 'Oil Spill', 'Environmental Impact Assessment', 'EIA Report', 'Tanker', 'API Report', 'Production Quota', 'ULSD', 'Middle Distillates', 'Refining Capacity', 'Exploration & Production', 'Integrated Oil Company', 'National Oil Company', 'Oil Major', 'Organization of the Petroleum Exporting Countries']

# %%
keywords_lex
# Out:
# ['Brent',
#  'WTI',
#  'OPEC',
#  'API Gravity',
#  'Sweet Crude',
#  'Sour Crude',
#  'Crack Spread',
#  'Refinery Throughput',
#  'Strategic Petroleum Reserve',
#  'Barrel',
#  'Tanker Rates',
#  'Seaborne Trade',
#  'Pipeline Capacity',
#  'Upstream',
#  'Downstream',
#  'Midstream',
#  'EIA',
#  'IEA',
#  'Rigs Count',
#  'Fracking',
#  'Shale Oil',
#  'Non-OPEC',
#  'Oil Sands',
#  'Offshore Drilling',
#  'Oilfield Services',
#  'Production Sharing Agreement',
#  'Exploration and Production',
#  'Hydrocarbon Reserves',
#  'Crude Assay',
#  'Spot Charter',
#  'Refinery Margin',
#  'Light Crude',
#  'Heavy Crude',
#  'NYMEX',
#  'ICE',
#  'Petrochemicals',
#  'Onshore Drilling',
#  'Oil Rig',
#  'Pipeline',
#  'Floating Storage',
#  'Distillation',
#  'Hydrocracking',
#  'Desulfurization',
#  'Oil Benchmark',
#  'Price Differential',
#  'Production Cut',
#  'Geopolitical Risk',
#  'Brent Crude',
#  'West Texas Intermediate',
#  'OPEC+',
#  'Refinery Utilization',
#  'SPR',
#  'Bbl',
#  'Energy Information Administration',
#  'International Energy Agency',
#  'Seaborne Crude',
#  'Bitumen',
#  'Tar Sands',
#  'Refining Margin',
#  'Oil Rig Count',
#  'Drilling Rig',
#  'E&P',
#  'PSA',
#  'Crude Differential',
#  'Cargo Nomination',
#  'Liftings',
#  'Tanker Chartering',
#  'Oil Spill',
#  'Environmental Impact Assessment',
#  'EIA Report',
#  'Tanker',
#  'API Report',
#  'Production Quota',
#  'ULSD',
#  'Middle Distillates',
#  'Refining Capacity',
#  'Exploration & Production',
#  'Integrated Oil Company',
#  'National Oil Company',
#  'Oil Major',
#  'Organization of the Petroleum Exporting Countries']

# %%
len(keywords_lex)
# Out:
# 81

# %% [markdown]
# # Step 2- Content Retrieval Based on Bigdata

# %% [markdown]
# In this section, we perform a keyword search on the news content with the Bigdata API to retrieve documents, splitting the search over daily timeframes and multi-threading the content search on the individual keywords for speed purpose. The user can define the time range below to generate daily reports between the start and end dates.

# %%
start_query = '2025-06-21'
end_query = '2025-06-28'

# %%
from src.search_topics import search_by_keywords
results, daily_keyword_count = search_by_keywords(
    keywords=keywords_lex,
    start_date=start_query,
    end_date=end_query,
    freq='D',
    document_limit=10)
# Out:
# About to run 648 queries
# Example Query: Keyword('Brent') over date range: AbsoluteDateRange('2025-06-21T00:00:00', '2025-06-21T23:59:59')
# Querying Bigdata...: 100%|██████████| 648/648 [02:15<00:00,  4.77it/s]

# %%
results
# Out:
#                      timestamp                    rp_document_id  \
# 0    2025-06-21 00:00:00+00:00  96EC510A80FAD37155CD1543681E8CC1
# 1    2025-06-21 00:00:00+00:00  0B4844B85EA092ED4AB50AB3534AB360
# 2    2025-06-21 00:00:00+00:00  45A5868267C8A445F6B696C495AA8673
# 3    2025-06-21 00:00:00+00:00  45A5868267C8A445F6B696C495AA8673
# 4    2025-06-21 00:00:00+00:00  96EC510A80FAD37155CD1543681E8CC1
# ...                        ...                               ...
# 9432 2025-06-28 23:50:36+00:00  DF667772C27122819087C82C1D54C3DD
# 9433 2025-06-28 23:50:36+00:00  DF667772C27122819087C82C1D54C3DD
# 9434 2025-06-28 23:50:36+00:00  DF667772C27122819087C82C1D54C3DD
# 9435 2025-06-28 23:54:30+00:00  83B358B6C8498F0C6A4F19F9F88A07A6
# 9436 2025-06-28 23:56:09+00:00  9751F4AA465A1FE2BD4304D69A9D6A0D
#
#                                                headline  chunk_number  \
# 0                       Morning Briefing: June 21, 2025           9.0
# 1     BW Energy: Update on Fixed Income Investor Mee...           3.0
# 2     Aduro Clean Technologies Announces Closing of ...           7.0
# 3     Aduro Clean Technologies Announces Closing of ...           1.0
# 4                       Morning Briefing: June 21, 2025          11.0
# ...                                                 ...           ...
# 9432            The Strategic Empire: Debt & the Dollar          55.0
# 9433            The Strategic Empire: Debt & the Dollar          46.0
# 9434            The Strategic Empire: Debt & the Dollar          47.0
# 9435  An animated example of ice-core drilling in An...           1.0
# 9436  Japan launches climate change monitoring satel...           1.0
#
#                               sentence_id source_id  \
# 0      96EC510A80FAD37155CD1543681E8CC1-9    CE1ADC
# 1      0B4844B85EA092ED4AB50AB3534AB360-3    923B93
# 2      45A5868267C8A445F6B696C495AA8673-7    D051D6
# 3      45A5868267C8A445F6B696C495AA8673-1    D051D6
# 4     96EC510A80FAD37155CD1543681E8CC1-11    CE1ADC
# ...                                   ...       ...
# 9432  DF667772C27122819087C82C1D54C3DD-55    EC0C87
# 9433  DF667772C27122819087C82C1D54C3DD-46    EC0C87
# 9434  DF667772C27122819087C82C1D54C3DD-47    EC0C87
# 9435   83B358B6C8498F0C6A4F19F9F88A07A6-1    905C54
# 9436   9751F4AA465A1FE2BD4304D69A9D6A0D-1    80E7CF
#
#                                source_name  \
# 0                           Anadolu Agency
# 1     Financial Services Monitor Worldwide
# 2                        Global Data Point
# 3                        Global Data Point
# 4                           Anadolu Agency
# ...                                    ...
# 9432                        Michael Hudson
# 9433                        Michael Hudson
# 9434                        Michael Hudson
# 9435                            ABC Online
# 9436                           Japan Today
#
#                                                    text  \
# 0     - Top European diplomats emphasized the urgenc...
# 1     BW Energy is a growth E&P company with a diffe...
# 2     About Aduro Clean Technologies\nAduro Clean Te...
# 3     (GlobeNewswire) - Aduro Clean Technologies Inc...
# 4     China is the world's largest oil importer. In ...
# ...                                                 ...
# 9432  Yes, someday the United States cannot get a fr...
# 9433  The United States is unwilling to annul Global...
# 9434  However, the condition for letting OPEC countr...
# 9435  An animated example of ice-core drilling in An...
# 9436  Japan on Sunday successfully launched a climat...
#
#                                 keyword        date
# 0                     Geopolitical Risk  2025-06-21
# 1                                   E&P  2025-06-21
# 2                               Bitumen  2025-06-21
# 3                               Bitumen  2025-06-21
# 4     Energy Information Administration  2025-06-21
# ...                                 ...         ...
# 9432                              OPEC+  2025-06-28
# 9433                              OPEC+  2025-06-28
# 9434                              OPEC+  2025-06-28
# 9435                                ICE  2025-06-28
# 9436                           Liftings  2025-06-28
#
# [9437 rows x 10 columns]

# %% [markdown]
# # Step 3- Topic Clustering and Selection

# %% [markdown]
# In this step, we perform topic modelling using a large language model to verify and cluster the news. Then, the summarization ensures topic selection identifying the top trending news for crude oil, while deriving advanced analytics to quantify the trendiness (based on news volume), novelty (based on daily changes in summaries), impact and magnitude (based on the financial materiality on crude oil prices) of the trending topics.

# %% [markdown]
# Before performing the topic clustering, we apply a verification layer to remove the news that are not relative to the oil market

# %%
model = "gpt-4o-mini" 
api_key = os.getenv("OPENAI_API_KEY")

# %%
from src.topics_extractor import process_all_reports
semaphore_size = 1000

# Assuming unique_reports is your DataFrame
filtered_reports = process_all_reports(results, model, api_key, main_theme, semaphore_size)
# Out:
# Filtering News:   0%|          | 0/9437 [00:00<?, ?it/s]

# %% [markdown]
# In this cell, we leverage a LLM to perform topic modeling, identifying and clustering the key topics from the news reports.

# %%
filtered_reports
# Out:
#                      timestamp                    rp_document_id  \
# 0    2025-06-21 00:00:00+00:00  45A5868267C8A445F6B696C495AA8673
# 1    2025-06-21 00:00:00+00:00  45A5868267C8A445F6B696C495AA8673
# 2    2025-06-21 00:00:00+00:00  E2D405BFF0426528C258C62EC5773E36
# 3    2025-06-21 00:00:00+00:00  C47A2AB4D8E9C02F3720F56FC500DE76
# 4    2025-06-21 00:00:00+00:00  5DB7156ACE3425F4F61B3BE3E882AF0D
# ...                        ...                               ...
# 3749 2025-06-28 23:33:44+00:00  4C596AE14BED3F44AB5D9442B44F1F5F
# 3750 2025-06-28 23:37:13+00:00  99083749AA42E83A4352A4002BC9479C
# 3751 2025-06-28 23:42:59+00:00  EF9DB0616299C83C5CF64CE5B32D2744
# 3752 2025-06-28 23:48:49+00:00  456DB9D74C8F0B01626EE845F8FF4CA6
# 3753 2025-06-28 23:54:30+00:00  83B358B6C8498F0C6A4F19F9F88A07A6
#
#                                                headline  chunk_number  \
# 0     Aduro Clean Technologies Announces Closing of ...           7.0
# 1     Aduro Clean Technologies Announces Closing of ...           1.0
# 2     Nine creates new executive roles as it combine...           6.0
# 3     Nine Announces New Leadership and Plans to Gro...           4.0
# 4     Premium Alcohol Market Forecasts Report 2025-2...           3.0
# ...                                                 ...           ...
# 3749  Better Dividend Stock: Kinder Morgan vs. Enter...           1.0
# 3750  3 days after Kullu flash flood, missing teen's...           2.0
# 3751  Iran signals openness to transfers of enriched...           3.0
# 3752  Caught on camera: Car literally drives through...           2.0
# 3753  An animated example of ice-core drilling in An...           1.0
#
#                              sentence_id source_id  \
# 0     45A5868267C8A445F6B696C495AA8673-7    D051D6
# 1     45A5868267C8A445F6B696C495AA8673-1    D051D6
# 2     E2D405BFF0426528C258C62EC5773E36-6    346656
# 3     C47A2AB4D8E9C02F3720F56FC500DE76-4    346656
# 4     5DB7156ACE3425F4F61B3BE3E882AF0D-3    923B93
# ...                                  ...       ...
# 3749  4C596AE14BED3F44AB5D9442B44F1F5F-1    648085
# 3750  99083749AA42E83A4352A4002BC9479C-2    80FC03
# 3751  EF9DB0616299C83C5CF64CE5B32D2744-3    7018D1
# 3752  456DB9D74C8F0B01626EE845F8FF4CA6-2    E54C73
# 3753  83B358B6C8498F0C6A4F19F9F88A07A6-1    905C54
#
#                                source_name  \
# 0                        Global Data Point
# 1                        Global Data Point
# 2         Executive Appointments Worldwide
# 3         Executive Appointments Worldwide
# 4     Financial Services Monitor Worldwide
# ...                                    ...
# 3749                               AOL.com
# 3750                    The Times Of India
# 3751                    Charlotte Observer
# 3752                              ABC News
# 3753                            ABC Online
#
#                                                    text  \
# 0     About Aduro Clean Technologies\nAduro Clean Te...
# 1     (GlobeNewswire) - Aduro Clean Technologies Inc...
# 2     The company is recruiting for new positions in...
# 3     Sport is still a key part of Nine and the bigg...
# 4     Market Trends Growing Disposable Income and Ur...
# ...                                                 ...
# 3749  If you are looking at Kinder Morgan (NYSE: KMI...
# 3750  They were swept away from a hydropower project...
# 3751  However, he stressed that Iran would not renou...
# 3752  "This is like a movie or something," Patel sai...
# 3753  An animated example of ice-core drilling in An...
#
#                                 keyword        date
# 0                               Bitumen  2025-06-21
# 1                               Bitumen  2025-06-21
# 2                                 Brent  2025-06-21
# 3                                 Brent  2025-06-21
# 4     Energy Information Administration  2025-06-21
# ...                                 ...         ...
# 3749                          Midstream  2025-06-28
# 3750                         Downstream  2025-06-28
# 3751                           Liftings  2025-06-28
# 3752                             Barrel  2025-06-28
# 3753                                ICE  2025-06-28
#
# [3754 rows x 10 columns]

# %%
from src.topics_extractor import run_process_all_trending_topics
flattened_trending_topics_df = run_process_all_trending_topics(
    unique_reports=filtered_reports,
    model=model,
    start_query=start_query,
    end_query=end_query,
    api_key=os.environ['OPENAI_API_KEY'],
    main_theme = main_theme,
    batches = 20
)
# Out:
# Extracting Topics for 2025-06-21:   0%|          | 0/19 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-22:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-23:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-24:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-25:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-26:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-27:   0%|          | 0/20 [00:00<?, ?it/s]
# Extracting Topics for 2025-06-28:   0%|          | 0/20 [00:00<?, ?it/s]
# Consolidating topics...
# Consolidating topic batches: 100%|██████████| 9/9 [00:19<00:00,  2.12s/it]
# {'Geopolitical Tensions Impacting Oil Prices': ['topic_1', 'topic_5', 'topic_14', 'topic_40', 'topic_50', 'topic_265', 'topic_277', 'topic_278', 'topic_287', 'topic_309', 'topic_312', 'topic_322', 'topic_330', 'topic_335', 'topic_339'], 'Geopolitical Risks Impacting Oil Supply': ['topic_4', 'topic_15', 'topic_48'], 'Iran-Israel Conflict and Geopolitical Risks': ['topic_7', 'topic_20', 'topic_39'], 'OPEC+ Production Decisions': ['topic_3', 'topic_13', 'topic_28', 'topic_22', 'topic_215', 'topic_218', 'topic_222', 'topic_238', 'topic_246'], 'Impact of Sanctions on Oil Markets': ['topic_8'], 'Market Recovery and Oil Price Trends': ['topic_6', 'topic_16', 'topic_23', 'topic_49'], 'Climate Change and Fossil Fuel Exploration': ['topic_2'], "Brazil's Fossil Fuel Development Plans": ['topic_9'], "OPEC's Role in Global Oil Markets": ['topic_10', 'topic_30'], 'Challenges Facing Major Refiners': ['topic_12', 'topic_34', 'topic_46'], 'U.S. Military Involvement in Middle East Conflicts': ['topic_26', 'topic_33', 'topic_45'], 'Asian Demand for Crude Oil': ['topic_27'], 'Norwegian and Algerian Oil Exports': ['topic_29'], 'ConocoPhillips Production Insights': ['topic_18'], 'Midstream Energy Sector Stability': ['topic_21'], 'EIA Forecasts on Oil Consumption and Production': ['topic_36'], "Iran's Threats to the Strait of Hormuz": ['topic_25', 'topic_37'], 'Escalating Tensions in the Middle East': ['topic_40'], 'U.S. Crude Oil Market Dynamics': ['topic_41'], 'Enterprise Products Partners and U.S. Hydrocarbon Demand': ['topic_42'], 'Brent Crude Price Surge': ['topic_47'], 'Middle East Tensions Impact on Oil': [], 'Iranian Oil Exports and Production': [], 'U.S. Military Actions and Iranian Response': [], 'Strait of Hormuz Shipping and Security': [], 'Geopolitical Tensions and Oil Prices': [], "China's Role in Oil Demand": [], 'OPEC+ Production Cuts': [], 'Oil Price Movements and Predictions': [], 'Economic Indicators and Oil Demand': [], 'Investment and Market Challenges': [], 'Production Trends in Oil-Producing Countries': [], 'Import Price Variations': [], "India's Oil Import Diversification": [], 'Russian Oil Price Cap Proposal': [], "Mexico's Oil Production Decline": [], 'Employment Trends in Oil Sector': [], 'Refining Margins and Challenges': [], "Empire Energy's Engagement": [], 'OPEC+ Production Cuts and Global Oil Supply': ['topic_101', 'topic_123'], 'Refining Margins and Economic Policies': ['topic_102', 'topic_120'], 'Brent Crude Price Forecasts': ['topic_103'], 'Geopolitical Risks in the Middle East': ['topic_104', 'topic_128'], 'Environmental Impact of Oil Spills': ['topic_105'], 'Market Dynamics and Price Resistance': ['topic_106', 'topic_130'], 'Record Production by Canadian Natural Resources': ['topic_107', 'topic_144'], 'Technological Innovations in Oil Recovery': ['topic_108'], 'Weak Global Oil Demand Growth': ['topic_109', 'topic_139'], 'Impact of Iranian Oil Production': ['topic_110', 'topic_146'], 'Closure of the Strait of Hormuz': ['topic_111', 'topic_133'], 'Impact of U.S. Airstrikes on Oil Prices': ['topic_112', 'topic_114'], 'Security Concerns Affecting Oil Transportation': ['topic_113'], 'Escalating Tensions in the Strait of Hormuz': ['topic_116', 'topic_127'], "China's Dominance in Iranian Oil Imports": ['topic_117'], 'Market Reactions to Geopolitical Events': ['topic_118', 'topic_148'], 'Middle Eastern Oil Production and Pricing Power': ['topic_119', 'topic_135'], 'U.S. Energy Production and Export Trends': ['topic_121', 'topic_132'], 'Venezuelan Oil Production Challenges': ['topic_124'], 'Impact of U.S. Energy Policy': ['topic_125'], 'U.S. Strategic Petroleum Reserve Management': ['topic_126'], 'US Dollar Weakness': ['topic_134'], 'US Production Stagnation': ['topic_138'], "Iran's Retaliatory Actions and Geopolitical Tensions": ['topic_140'], "US Federal Reserve's Monetary Policy and Oil Prices": ['topic_141'], "Saudi Arabia and UAE's Export Capabilities": ['topic_142'], 'Ceasefire Agreement Between Israel and Iran': [' ...
# {'Geopolitical Tensions Impacting Oil Prices': ['topic_1', 'topic_26', 'topic_157', 'topic_179'], 'Geopolitical Risks Impacting Oil Supply': ['topic_2', 'topic_70', 'topic_43'], 'Iran-Israel Conflict and Geopolitical Risks': ['topic_3', 'topic_66', 'topic_85', 'topic_174'], 'OPEC+ Production Decisions': ['topic_4', 'topic_28', 'topic_112', 'topic_137', 'topic_153'], 'Impact of Sanctions on Oil Markets': ['topic_5', 'topic_141'], 'Market Recovery and Oil Price Trends': ['topic_6', 'topic_29', 'topic_140'], 'Climate Change and Fossil Fuel Exploration': ['topic_7', 'topic_115'], "Brazil's Fossil Fuel Development Plans": ['topic_8'], "OPEC's Role in Global Oil Markets": ['topic_9', 'topic_56'], 'Challenges Facing Major Refiners': ['topic_10', 'topic_38'], 'U.S. Military Involvement in Middle East Conflicts': ['topic_11', 'topic_51', 'topic_24'], 'Asian Demand for Crude Oil': ['topic_12', 'topic_27', 'topic_54'], 'Norwegian and Algerian Oil Exports': ['topic_13'], 'ConocoPhillips Production Insights': ['topic_14'], 'Midstream Energy Sector Stability': ['topic_15', 'topic_75'], 'EIA Forecasts on Oil Consumption and Production': ['topic_16', 'topic_139'], "Iran's Threats to the Strait of Hormuz": ['topic_17', 'topic_72'], 'Escalating Tensions in the Middle East': ['topic_18', 'topic_22', 'topic_84', 'topic_175'], 'U.S. Crude Oil Market Dynamics': ['topic_19', 'topic_94', 'topic_99'], 'Enterprise Products Partners and U.S. Hydrocarbon Demand': ['topic_20'], 'Brent Crude Price Surge': ['topic_21', 'topic_164'], "China's Role in Oil Demand": ['topic_27', 'topic_154', 'topic_165'], 'OPEC+ Production Cuts': ['topic_28', 'topic_40'], 'Oil Price Movements and Predictions': ['topic_29', 'topic_140'], 'Economic Indicators and Oil Demand': ['topic_30', 'topic_93'], 'Investment and Market Challenges': ['topic_31', 'topic_102'], 'Production Trends in Oil-Producing Countries': ['topic_32', 'topic_136'], 'Import Price Variations': ['topic_33'], "India's Oil Import Diversification": ['topic_34', 'topic_144'], 'Russian Oil Price Cap Proposal': ['topic_35'], "Mexico's Oil Production Decline": ['topic_36'], 'Employment Trends in Oil Sector': ['topic_37'], 'Refining Margins and Challenges': ['topic_38', 'topic_78'], "Empire Energy's Engagement": ['topic_39'], 'OPEC+ Production Levels': ['topic_71'], 'Impact of U.S. Tariffs on Oilfield Activity': ['topic_77'], 'Canadian Oil Sands Production Growth': ['topic_79', 'topic_124'], 'US Domestic Production Forecasts': ['topic_80'], 'Oil Production and Personnel Evacuations in Iraq': ['topic_81'], 'U.S. Strategic Petroleum Reserve Considerations': ['topic_82', 'topic_152'], 'Market Reactions to Oil Price Fluctuations': ['topic_83', 'topic_100'], 'Global Demand Trends': ['topic_101', 'topic_178'], 'Geothermal Energy Investment by Oil Companies': ['topic_103'], 'U.S. Gasoline Demand Surge': ['topic_104'], "Libya's National Oil Company Collaboration": ['topic_105'], 'Pipeline Capacity and LNG Supply': ['topic_106'], 'Drilling Activity Trends': ['topic_107'], 'Acquisition Talks in the Oil Industry': ['topic_108'], 'US Crude Oil Inventory Changes': ['topic_97', 'topic_134', 'topic_109'], 'Market Dynamics in Crude Oil': ['topic_110'], 'US Dollar Influence on Oil Prices': ['topic_111', 'topic_61'], "OPEC's Declining Market Share": ['topic_169'], 'Demand Premium and Inventory Draws': ['topic_170'], 'Middle East Ceasefire Impact on Oil Prices': ['topic_171'], 'U.S. Oil Price Trends': ['topic_172'], "Ecopetrol's Market Position and Economic Factors": ['topic_173'], 'Rising Conflict in West Asia': ['topic_175'], 'Environmental Impact of Hydrocarbon Extraction': ['topic_160'], "TotalEnergies' Strategic Moves": ['topic_162'], 'Pipeline Developments and Shutdowns': ['topic_163'], 'Geopolitical Importance of the Strait of Hormuz': ['topic_91'], 'Navigational Issues Near the Strait of Hormuz': ['topic_121'], 'Speculative Trading in Crude Oil Futures': ['topic_122'], "North Dakota's Natural Gas and Oil Production Dynamics": ['t ...
# Geopolitical Tensions Impacting Oil Prices ['topic_1', 'topic_26', 'topic_157', 'topic_179']
# topic_1
# topic_26
# topic_157
# topic_179
# Geopolitical Risks Impacting Oil Supply ['topic_2', 'topic_70', 'topic_43']
# topic_2
# topic_70
# topic_43
# Iran-Israel Conflict and Geopolitical Risks ['topic_3', 'topic_66', 'topic_85', 'topic_174']
# topic_3
# topic_66
# topic_85
# topic_174
# OPEC+ Production Decisions ['topic_4', 'topic_28', 'topic_112', 'topic_137', 'topic_153']
# topic_4
# topic_28
# topic_112
# topic_137
# topic_153
# Impact of Sanctions on Oil Markets ['topic_5', 'topic_141']
# topic_5
# topic_141
# Market Recovery and Oil Price Trends ['topic_6', 'topic_29', 'topic_140']
# topic_6
# topic_29
# topic_140
# Climate Change and Fossil Fuel Exploration ['topic_7', 'topic_115']
# topic_7
# topic_115
# Brazil's Fossil Fuel Development Plans ['topic_8']
# topic_8
# OPEC's Role in Global Oil Markets ['topic_9', 'topic_56']
# topic_9
# topic_56
# Challenges Facing Major Refiners ['topic_10', 'topic_38']
# topic_10
# topic_38
# U.S. Military Involvement in Middle East Conflicts ['topic_11', 'topic_51', 'topic_24']
# topic_11
# topic_51
# topic_24
# Asian Demand for Crude Oil ['topic_12', 'topic_27', 'topic_54']
# topic_12
# topic_27
# topic_54
# Norwegian and Algerian Oil Exports ['topic_13']
# topic_13
# ConocoPhillips Production Insights ['topic_14']
# topic_14
# Midstream Energy Sector Stability ['topic_15', 'topic_75']
# topic_15
# topic_75
# EIA Forecasts on Oil Consumption and Production ['topic_16', 'topic_139']
# topic_16
# topic_139
# Iran's Threats to the Strait of Hormuz ['topic_17', 'topic_72']
# topic_17
# topic_72
# Escalating Tensions in the Middle East ['topic_18', 'topic_22', 'topic_84', 'topic_175']
# topic_18
# topic_22
# topic_84
# topic_175
# U.S. Crude Oil Market Dynamics ['topic_19', 'topic_94', 'topic_99']
# topic_19
# topic_94
# topic_99
# Enterprise Products Partners and U.S. Hydrocarbon Demand ['topic_20']
# topic_20
# Brent Crude Price Surge ['topic_21', 'topic_164']
# topic_21
# topic_164
# China's Role in Oil Demand ['topic_27', 'topic_154', 'topic_165']
# topic_27
# topic_154
# topic_165
# OPEC+ Production Cuts ['topic_28', 'topic_40']
# topic_28
# topic_40
# Oil Price Movements and Predictions ['topic_29', 'topic_140']
# topic_29
# topic_140
# Economic Indicators and Oil Demand ['topic_30', 'topic_93']
# topic_30
# topic_93
# Investment and Market Challenges ['topic_31', 'topic_102']
# topic_31
# topic_102
# Production Trends in Oil-Producing Countries ['topic_32', 'topic_136']
# topic_32
# topic_136
# Import Price Variations ['topic_33']
# topic_33
# India's Oil Import Diversification ['topic_34', 'topic_144']
# topic_34
# topic_144
# Russian Oil Price Cap Proposal ['topic_35']
# topic_35
# Mexico's Oil Production Decline ['topic_36']
# topic_36
# Employment Trends in Oil Sector ['topic_37']
# topic_37
# Refining Margins and Challenges ['topic_38', 'topic_78']
# topic_38
# topic_78
# Empire Energy's Engagement ['topic_39']
# topic_39
# OPEC+ Production Levels ['topic_71']
# topic_71
# Impact of U.S. Tariffs on Oilfield Activity ['topic_77']
# topic_77
# Canadian Oil Sands Production Growth ['topic_79', 'topic_124']
# topic_79
# topic_124
# US Domestic Production Forecasts ['topic_80']
# topic_80
# Oil Production and Personnel Evacuations in Iraq ['topic_81']
# topic_81
# U.S. Strategic Petroleum Reserve Considerations ['topic_82', 'topic_152']
# topic_82
# topic_152
# Market Reactions to Oil Price Fluctuations ['topic_83', 'topic_100']
# topic_83
# topic_100
# Global Demand Trends ['topic_101', 'topic_178']
# topic_101
# topic_178
# Geothermal Energy Investment by Oil Companies ['topic_103']
# topic_103
# U.S. Gasoline Demand Surge ['topic_104']
# topic_104
# Libya's National Oil Company Collaboration ['topic_105']
# topic_105
# Pipeline Capacity and LNG Supply ['topic_106']
# topic_106
# Drilling Activity Trends ['topic_107']
# topic_107
# Acquisition Talks in the Oil Industry ['topic_108']
# topic_108
# US Crude Oil Inventory Changes ['topic_97', 'topic_134', 'topic_109']
# topic_97
# topic_134
# topic_109
# Market Dynamics in Crude Oil ['topic_110']
# topic_110
# US Dollar Influence on Oil Prices ['topic_111', 'topic_61']
# topic_111
# topic_61
# OPEC's Declining Market Share ['topic_169']
# topic_169
# Demand Premium and Inventory Draws ['topic_170']
# topic_170
# Middle East Ceasefire Impact on Oil Prices ['topic_171']
# topic_171
# U.S. Oil Price Trends ['topic_172']
# topic_172
# Ecopetrol's Market Position and Economic Factors ['topic_173']
# topic_173
# Rising Conflict in West Asia ['topic_175']
# topic_175
# Environmental Impact of Hydrocarbon Extraction ['topic_160']
# topic_160
# TotalEnergies' Strategic Moves ['topic_162']
# topic_162
# Pipeline Developments and Shutdowns ['topic_163']
# topic_163
# Geopolitical Importance of the Strait of Hormuz ['topic_91']
# topic_91
# Navigational Issues Near the Strait of Hormuz ['topic_121']
# topic_121
# Speculative Trading in Crude Oil Futures ['topic_122']
# topic_122
# North Dakota's Natural Gas and Oil Production Dynamics ['topic_123']
# topic_123
# Saudi Arabia's Economic Growth and Oil Exports ['topic_125']
# topic_125
# India's Vulnerability to Crude Oil Price Shocks ['topic_126']
# topic_126
# Rising Oil Import Costs in ASEAN ['topic_145']
# topic_145
# Enbridge Pipeline Capacity Expansion ['topic_146']
# topic_146
# Medco's Strategic Acquisition in Indonesia ['topic_147']
# topic_147
# Civitas Exploration and Production Challenges ['topic_148']
# topic_148
# Kuwait Crude Oil Price Movements ['topic_149']
# topic_149
# Peak Oil Demand Concerns ['topic_150']
# topic_150
# Supply Outpacing Demand Amid Macro Uncertainty ['topic_151']
# topic_151
# US Strategic Petroleum Reserve Delays ['topic_156']
# topic_156
# Environmental and Regulatory Challenges ['topic_142']
# topic_142
# Market Dynamics of Oil Majors ['topic_143']
# topic_143
# International Cooperation in Oil Production ['topic_119']
# topic_119
# US Offshore Drilling Policy ['topic_166']
# topic_166
# CME Group's Role in Oil Futures Trading ['topic_168']
# topic_168
# Impact of U.S. Political Decisions on Oil Prices ['topic_87']
# topic_87
# Iran's Military Actions and Market Reactions ['topic_86']
# topic_86
# Weak Global Oil Demand Growth ['topic_48']
# topic_48
# Impact of Iranian Oil Production ['topic_49']
# topic_49
# Closure of the Strait of Hormuz ['topic_50']
# topic_50
# Security Concerns Affecting Oil Transportation ['topic_52']
# topic_52
# Escalating Tensions in the Strait of Hormuz ['topic_53']
# topic_53
# Freight Rate Increases ['topic_73']
# topic_73
# Refining Margins and Profitability Challenges ['topic_78']
# topic_78
# Technological Innovations in Oil Recovery ['topic_47']
# topic_47
# Record Production by Canadian Natural Resources ['topic_46']
# topic_46
# Challenges in Oil Sectors ['topic_102']
# topic_102
# US Rig Count Trends ['topic_135']
# topic_135
# US Crude Oil Production Trends ['topic_136']
# topic_136
# US Energy Companies and Libyan Oil Reserves ['topic_113']
# topic_113
# US Refinery Utilization Rates ['topic_116']
# topic_116
# India's Strategic Petroleum Reserves Expansion ['topic_117']
# topic_117
# US Dollar Weakness ['topic_61']
# topic_61
# US Production Stagnation ['topic_62']
# topic_62
# U.S. Crude Oil Inventory Trends ['topic_134']
# topic_134
# US Energy Production and Export Trends ['topic_57']
# topic_57
# Technological Advancements in Oil Exploration ['topic_176']
# topic_176
# China's Increased Drilling Activities ['topic_95']
# topic_95
# OPEC Decisions ['topic_131']
# topic_131
# US Demand Indicators ['topic_132']
# topic_132
# Impact of Decommissioning Regulations on Environmental Sustainability ['topic_133']
# topic_133
# Global Petroleum Bitumen Market Trends ['topic_127']
# topic_127
# Jack-Up Rig Market Growth ['topic_128']
# topic_128
# {'Geopolitical Tensions Impacting Oil Prices': ['topic_1', 'topic_2', 'topic_3', 'topic_11', 'topic_17', 'topic_18', 'topic_61', 'topic_84', 'topic_85', 'topic_86'], 'OPEC+ Production Decisions': ['topic_4', 'topic_9', 'topic_23', 'topic_35', 'topic_103'], 'Impact of Sanctions on Oil Markets': ['topic_5', 'topic_30', 'topic_83'], 'Market Recovery and Oil Price Trends': ['topic_6', 'topic_24', 'topic_41'], 'Asian Demand for Crude Oil': ['topic_12', 'topic_22', 'topic_66', 'topic_67'], 'U.S. Crude Oil Market Dynamics': ['topic_19', 'topic_20', 'topic_49', 'topic_93', 'topic_100'], 'Brent Crude Price Surge': ['topic_21'], 'Economic Indicators and Oil Demand': ['topic_25', 'topic_56', 'topic_66', 'topic_82'], 'Challenges Facing Major Refiners': ['topic_10', 'topic_33', 'topic_88'], 'US Strategic Petroleum Reserve Considerations': ['topic_40', 'topic_74', 'topic_96'], 'Technological Innovations in Oil Recovery': ['topic_89', 'topic_101'], 'US Dollar Influence on Oil Prices': ['topic_51', 'topic_97'], 'Environmental and Regulatory Challenges': ['topic_75', 'topic_105'], 'Rising Conflict in West Asia': ['topic_57'], 'US Energy Companies and Libyan Oil Reserves': ['topic_94'], 'Freight Rate Increases': ['topic_87'], 'US Rig Count Trends': ['topic_92'], 'US Refinery Utilization Rates': ['topic_95'], 'US Production Stagnation': ['topic_98'], 'US Domestic Production Forecasts': ['topic_38'], 'Production Trends in Oil-Producing Countries': ['topic_27'], 'Midstream Energy Sector Stability': ['topic_15'], 'Geothermal Energy Investment by Oil Companies': ['topic_43'], 'Navigational Issues Near the Strait of Hormuz': ['topic_62'], 'Escalating Tensions in the Middle East': ['topic_18'], 'Oil Production and Personnel Evacuations in Iraq': ['topic_39'], 'Impact of U.S. Political Decisions on Oil Prices': ['topic_80'], "CME Group's Role in Oil Futures Trading": ['topic_79'], 'Speculative Trading in Crude Oil Futures': ['topic_63'], 'Investment and Market Challenges': ['topic_26'], 'Oil Price Movements and Predictions': ['topic_24'], "OPEC's Declining Market Share": ['topic_52'], 'Global Demand Trends': ['topic_42'], "Iran's Military Actions and Market Reactions": ['topic_81'], "Iran's Threats to the Strait of Hormuz": ['topic_17'], 'Pipeline Developments and Shutdowns': ['topic_60'], 'ConocoPhillips Production Insights': ['topic_14'], "TotalEnergies' Strategic Moves": ['topic_59'], 'Challenges in Oil Sectors': ['topic_91'], 'Drilling Activity Trends': ['topic_47'], 'Record Production by Canadian Natural Resources': ['topic_90'], 'Norwegian and Algerian Oil Exports': ['topic_13'], 'Kuwait Crude Oil Price Movements': ['topic_71'], "Brazil's Fossil Fuel Development Plans": ['topic_8'], 'Enterprise Products Partners and U.S. Hydrocarbon Demand': ['topic_20'], 'Escalating Tensions in the Strait of Hormuz': ['topic_86'], 'Impact of U.S. Tariffs on Oilfield Activity': ['topic_36'], "China's Increased Drilling Activities": ['topic_102'], 'U.S. Oil Price Trends': ['topic_55'], 'Supply Outpacing Demand Amid Macro Uncertainty': ['topic_73'], 'U.S. Crude Oil Inventory Trends': ['topic_99'], 'International Cooperation in Oil Production': ['topic_77'], 'U.S. Gasoline Demand Surge': ['topic_44'], 'Impact of Decommissioning Regulations on Environmental Sustainability': ['topic_105'], 'Environmental Impact of Hydrocarbon Extraction': ['topic_58'], "Mexico's Oil Production Decline": ['topic_31'], 'US Energy Production and Export Trends': ['topic_100'], 'US Dollar Weakness': ['topic_97'], 'US Offshore Drilling Policy': ['topic_78']}
# Geopolitical Tensions Impacting Oil Prices ['topic_1', 'topic_2', 'topic_3', 'topic_11', 'topic_17', 'topic_18', 'topic_61', 'topic_84', 'topic_85', 'topic_86']
# topic_1
# topic_2
# topic_3
# topic_11
# topic_17
# topic_18
# topic_61
# topic_84
# topic_85
# topic_86
# OPEC+ Production Decisions ['topic_4', 'topic_9', 'topic_23', 'topic_35', 'topic_103']
# topic_4
# topic_9
# topic_23
# topic_35
# topic_103
# Impact of Sanctions on Oil Markets ['topic_5', 'topic_30', 'topic_83']
# topic_5
# topic_30
# topic_83
# Market Recovery and Oil Price Trends ['topic_6', 'topic_24', 'topic_41']
# topic_6
# topic_24
# topic_41
# Asian Demand for Crude Oil ['topic_12', 'topic_22', 'topic_66', 'topic_67']
# topic_12
# topic_22
# topic_66
# topic_67
# U.S. Crude Oil Market Dynamics ['topic_19', 'topic_20', 'topic_49', 'topic_93', 'topic_100']
# topic_19
# topic_20
# topic_49
# topic_93
# topic_100
# Brent Crude Price Surge ['topic_21']
# topic_21
# Economic Indicators and Oil Demand ['topic_25', 'topic_56', 'topic_66', 'topic_82']
# topic_25
# topic_56
# topic_66
# topic_82
# Challenges Facing Major Refiners ['topic_10', 'topic_33', 'topic_88']
# topic_10
# topic_33
# topic_88
# US Strategic Petroleum Reserve Considerations ['topic_40', 'topic_74', 'topic_96']
# topic_40
# topic_74
# topic_96
# Technological Innovations in Oil Recovery ['topic_89', 'topic_101']
# topic_89
# topic_101
# US Dollar Influence on Oil Prices ['topic_51', 'topic_97']
# topic_51
# topic_97
# Environmental and Regulatory Challenges ['topic_75', 'topic_105']
# topic_75
# topic_105
# Rising Conflict in West Asia ['topic_57']
# topic_57
# US Energy Companies and Libyan Oil Reserves ['topic_94']
# topic_94
# Freight Rate Increases ['topic_87']
# topic_87
# US Rig Count Trends ['topic_92']
# topic_92
# US Refinery Utilization Rates ['topic_95']
# topic_95
# US Production Stagnation ['topic_98']
# topic_98
# US Domestic Production Forecasts ['topic_38']
# topic_38
# Production Trends in Oil-Producing Countries ['topic_27']
# topic_27
# Midstream Energy Sector Stability ['topic_15']
# topic_15
# Geothermal Energy Investment by Oil Companies ['topic_43']
# topic_43
# Navigational Issues Near the Strait of Hormuz ['topic_62']
# topic_62
# Escalating Tensions in the Middle East ['topic_18']
# topic_18
# Oil Production and Personnel Evacuations in Iraq ['topic_39']
# topic_39
# Impact of U.S. Political Decisions on Oil Prices ['topic_80']
# topic_80
# CME Group's Role in Oil Futures Trading ['topic_79']
# topic_79
# Speculative Trading in Crude Oil Futures ['topic_63']
# topic_63
# Investment and Market Challenges ['topic_26']
# topic_26
# Oil Price Movements and Predictions ['topic_24']
# topic_24
# OPEC's Declining Market Share ['topic_52']
# topic_52
# Global Demand Trends ['topic_42']
# topic_42
# Iran's Military Actions and Market Reactions ['topic_81']
# topic_81
# Iran's Threats to the Strait of Hormuz ['topic_17']
# topic_17
# Pipeline Developments and Shutdowns ['topic_60']
# topic_60
# ConocoPhillips Production Insights ['topic_14']
# topic_14
# TotalEnergies' Strategic Moves ['topic_59']
# topic_59
# Challenges in Oil Sectors ['topic_91']
# topic_91
# Drilling Activity Trends ['topic_47']
# topic_47
# Record Production by Canadian Natural Resources ['topic_90']
# topic_90
# Norwegian and Algerian Oil Exports ['topic_13']
# topic_13
# Kuwait Crude Oil Price Movements ['topic_71']
# topic_71
# Brazil's Fossil Fuel Development Plans ['topic_8']
# topic_8
# Enterprise Products Partners and U.S. Hydrocarbon Demand ['topic_20']
# topic_20
# Escalating Tensions in the Strait of Hormuz ['topic_86']
# topic_86
# Impact of U.S. Tariffs on Oilfield Activity ['topic_36']
# topic_36
# China's Increased Drilling Activities ['topic_102']
# topic_102
# U.S. Oil Price Trends ['topic_55']
# topic_55
# Supply Outpacing Demand Amid Macro Uncertainty ['topic_73']
# topic_73
# U.S. Crude Oil Inventory Trends ['topic_99']
# topic_99
# International Cooperation in Oil Production ['topic_77']
# topic_77
# U.S. Gasoline Demand Surge ['topic_44']
# topic_44
# Impact of Decommissioning Regulations on Environmental Sustainability ['topic_105']
# topic_105
# Environmental Impact of Hydrocarbon Extraction ['topic_58']
# topic_58
# Mexico's Oil Production Decline ['topic_31']
# topic_31
# US Energy Production and Export Trends ['topic_100']
# topic_100
# US Dollar Weakness ['topic_97']
# topic_97
# US Offshore Drilling Policy ['topic_78']
# topic_78
# {'Geopolitical Tensions Impacting Oil Prices': ['topic_1', 'topic_14', 'topic_25', 'topic_24', 'topic_34', 'topic_35', 'topic_46'], 'OPEC+ Production Decisions': ['topic_2', 'topic_32'], 'Impact of Sanctions on Oil Markets': ['topic_3', 'topic_27'], 'Market Recovery and Oil Price Trends': ['topic_4', 'topic_31'], 'Asian Demand for Crude Oil': ['topic_5'], 'U.S. Crude Oil Market Dynamics': ['topic_6', 'topic_19', 'topic_20', 'topic_49', 'topic_51', 'topic_53', 'topic_57'], 'Brent Crude Price Surge': ['topic_7'], 'Economic Indicators and Oil Demand': ['topic_8', 'topic_50'], 'Challenges Facing Major Refiners': ['topic_9', 'topic_39'], 'US Strategic Petroleum Reserve Considerations': ['topic_10'], 'Technological Innovations in Oil Recovery': ['topic_11'], 'US Dollar Influence on Oil Prices': ['topic_12', 'topic_58'], 'Environmental and Regulatory Challenges': ['topic_13', 'topic_54', 'topic_55'], 'US Energy Companies and Libyan Oil Reserves': ['topic_15'], 'Freight Rate Increases': ['topic_16'], 'US Rig Count Trends': ['topic_17'], 'US Refinery Utilization Rates': ['topic_18'], 'Production Trends in Oil-Producing Countries': ['topic_21', 'topic_41', 'topic_42'], 'Midstream Energy Sector Stability': ['topic_22'], 'Geothermal Energy Investment by Oil Companies': ['topic_23'], "CME Group's Role in Oil Futures Trading": ['topic_28'], 'Speculative Trading in Crude Oil Futures': ['topic_29'], 'Investment and Market Challenges': ['topic_30'], 'Oil Production and Personnel Evacuations in Iraq': ['topic_26'], 'Impact of U.S. Tariffs on Oilfield Activity': ['topic_47'], "China's Increased Drilling Activities": ['topic_48'], 'Pipeline Developments and Shutdowns': ['topic_36'], "TotalEnergies' Strategic Moves": ['topic_38'], 'Kuwait Crude Oil Price Movements': ['topic_43'], "Brazil's Fossil Fuel Development Plans": ['topic_44'], 'Enterprise Products Partners and U.S. Hydrocarbon Demand': ['topic_45']}
# Geopolitical Tensions Impacting Oil Prices ['topic_1', 'topic_14', 'topic_25', 'topic_24', 'topic_34', 'topic_35', 'topic_46']
# topic_1
# topic_14
# topic_25
# topic_24
# topic_34
# topic_35
# topic_46
# OPEC+ Production Decisions ['topic_2', 'topic_32']
# topic_2
# topic_32
# Impact of Sanctions on Oil Markets ['topic_3', 'topic_27']
# topic_3
# topic_27
# Market Recovery and Oil Price Trends ['topic_4', 'topic_31']
# topic_4
# topic_31
# Asian Demand for Crude Oil ['topic_5']
# topic_5
# U.S. Crude Oil Market Dynamics ['topic_6', 'topic_19', 'topic_20', 'topic_49', 'topic_51', 'topic_53', 'topic_57']
# topic_6
# topic_19
# topic_20
# topic_49
# topic_51
# topic_53
# topic_57
# Brent Crude Price Surge ['topic_7']
# topic_7
# Economic Indicators and Oil Demand ['topic_8', 'topic_50']
# topic_8
# topic_50
# Challenges Facing Major Refiners ['topic_9', 'topic_39']
# topic_9
# topic_39
# US Strategic Petroleum Reserve Considerations ['topic_10']
# topic_10
# Technological Innovations in Oil Recovery ['topic_11']
# topic_11
# US Dollar Influence on Oil Prices ['topic_12', 'topic_58']
# topic_12
# topic_58
# Environmental and Regulatory Challenges ['topic_13', 'topic_54', 'topic_55']
# topic_13
# topic_54
# topic_55
# US Energy Companies and Libyan Oil Reserves ['topic_15']
# topic_15
# Freight Rate Increases ['topic_16']
# topic_16
# US Rig Count Trends ['topic_17']
# topic_17
# US Refinery Utilization Rates ['topic_18']
# topic_18
# Production Trends in Oil-Producing Countries ['topic_21', 'topic_41', 'topic_42']
# topic_21
# topic_41
# topic_42
# Midstream Energy Sector Stability ['topic_22']
# topic_22
# Geothermal Energy Investment by Oil Companies ['topic_23']
# topic_23
# CME Group's Role in Oil Futures Trading ['topic_28']
# topic_28
# Speculative Trading in Crude Oil Futures ['topic_29']
# topic_29
# Investment and Market Challenges ['topic_30']
# topic_30
# Oil Production and Personnel Evacuations in Iraq ['topic_26']
# topic_26
# Impact of U.S. Tariffs on Oilfield Activity ['topic_47']
# topic_47
# China's Increased Drilling Activities ['topic_48']
# topic_48
# Pipeline Developments and Shutdowns ['topic_36']
# topic_36
# TotalEnergies' Strategic Moves ['topic_38']
# topic_38
# Kuwait Crude Oil Price Movements ['topic_43']
# topic_43
# Brazil's Fossil Fuel Development Plans ['topic_44']
# topic_44
# Enterprise Products Partners and U.S. Hydrocarbon Demand ['topic_45']
# topic_45
# Summarizing text for each topic...
# Summarizing topics: 100%|██████████| 31/31 [00:06<00:00,  5.15it/s]
# Generating titles: 100%|██████████| 32/32 [00:05<00:00,  5.53it/s]
# Generating Day in Review summaries...
# Adding one-line summaries to DataFrame...
# Generating text summaries: 100%|██████████| 1274/1274 [00:13<00:00, 91.05it/s]

# %%
flattened_trending_topics_df
# Out:
#             Date                                      Day_in_Review  \
# 0     2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 1     2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 2     2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 3     2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 4     2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# ...          ...                                                ...
# 1132  2025-06-27  - OPEC+ increased oil production by 411,000 ba...
# 1142  2025-06-27  - OPEC+ increased oil production by 411,000 ba...
# 1143  2025-06-27  - OPEC+ increased oil production by 411,000 ba...
# 1225  2025-06-28  - OPEC+ increased oil production by 411,000 ba...
# 1226  2025-06-28  - OPEC+ increased oil production by 411,000 ba...
#
#                                                   Topic  \
# 0     Israel-Iran Tensions Drive Oil Price Volatilit...
# 1     OPEC+ Adjusts Production Strategies Amid Clima...
# 2     OPEC+ Adjusts Production Strategies Amid Clima...
# 3     OPEC+ Boosts Oil Production by 411,000 Barrels...
# 4     OPEC+ Boosts Oil Production by 411,000 Barrels...
# ...                                                 ...
# 1132  OPEC+ Boosts Oil Production by 411,000 Barrels...
# 1142  OPEC+ Output Hikes Drive Oil Market Volatility...
# 1143  OPEC+ Output Hikes Drive Oil Market Volatility...
# 1225  OPEC+ Boosts Oil Production by 411,000 Barrels...
# 1226  OPEC+ Boosts Oil Production by 411,000 Barrels...
#
#                                                 Summary  \
# 0     Geopolitical tensions, particularly between Is...
# 1     OPEC+ production decisions are increasingly in...
# 2     OPEC+ production decisions are increasingly in...
# 3     The impact of sanctions on oil markets is sign...
# 4     The impact of sanctions on oil markets is sign...
# ...                                                 ...
# 1132  The impact of sanctions on oil markets is sign...
# 1142  CME Group plays a pivotal role in oil futures ...
# 1143  CME Group plays a pivotal role in oil futures ...
# 1225  The impact of sanctions on oil markets is sign...
# 1226  The impact of sanctions on oil markets is sign...
#
#                           Source  \
# 0                       Livemint
# 1             InsideClimate News
# 2             InsideClimate News
# 3                 Yahoo! Finance
# 4                 Yahoo! Finance
# ...                          ...
# 1132  Business Times (Singapore)
# 1142       Investing.com via Web
# 1143                MT Newswires
# 1225                FOX Business
# 1226              Yahoo! Finance
#
#                                                Headline  \
# 0     Russia's Top Oil Executive Says OPEC  Was Astu...
# 1     Scientists' Letter Urges Brazil's President Lu...
# 2     Scientists' Letter Urges Brazil's President Lu...
# 3     Russia's Top Oil Executive Says OPEC+ Was Astu...
# 4     Russia's Top Oil Executive Says OPEC+ Was Astu...
# ...                                                 ...
# 1132  Oil steadies after report of planned Opec+ Aug...
# 1142  Oil steadies after report of planned OPEC+ Aug...
# 1143  Oil Rig Count Falls by 6; Crude Set for Sharp ...
# 1225  Why summer gas prices are at a four-year low d...
# 1226  The Decline of Oil Power in Middle East Geopol...
#
#                                                    Text  Volume_Score  \
# 0     It's been a turbulent week in the global oil m...             1
# 1     "Our two main tasks are to eliminate fossil fu...             2
# 2     "I took the letter to the head of the Brazilia...             2
# 3     "The decision by OPEC+ leaders to raise produc...             2
# 4     (Bloomberg) -- Steps taken by the OPEC+ group ...             2
# ...                                                 ...           ...
# 1132  "The report about an Opec increase came out an...             3
# 1142  Oil steadies after report of planned OPEC+ Aug...             2
# 1143  "This supply expansion comes at a time when th...             2
# 1225  Since there was no disruption to oil supply, o...             2
# 1226  Historical Oil Price Shocks That Benefited M.E...             2
#
#                                     Topic_labels  \
# 0     Geopolitical Tensions Impacting Oil Prices
# 1                     OPEC+ Production Decisions
# 2                     OPEC+ Production Decisions
# 3             Impact of Sanctions on Oil Markets
# 4             Impact of Sanctions on Oil Markets
# ...                                          ...
# 1132          Impact of Sanctions on Oil Markets
# 1142     CME Group's Role in Oil Futures Trading
# 1143     CME Group's Role in Oil Futures Trading
# 1225          Impact of Sanctions on Oil Markets
# 1226          Impact of Sanctions on Oil Markets
#
#                                            Text_Summary
# 0     Recent military exchanges between Israel and I...
# 1     A call to halt fossil fuel exploration and use...
# 2     Australian climate scientist Bill Hare engages...
# 3     OPEC+ leaders' decision to increase oil produc...
# 4     OPEC+'s decision to increase oil production by...
# ...                                                 ...
# 1132  OPEC+'s decision to increase oil production by...
# 1142  OPEC+'s planned output hike for August contrib...
# 1143  OPEC+ output hikes amid a challenging global m...
# 1225  OPEC+'s decision to boost oil production by 41...
# 1226  The historical use of oil as a political tool,...
#
# [274 rows x 10 columns]

# %% [markdown]
# **Trendiness and Novelty Scores**: We derive analytics related to the trendiness of the topic based on the news volume, and the novelty of the topic based on the changes in daily summaries, evaluating the uniqueness and freshness of each topic.

# %%
from src.topics_extractor import run_add_advanced_novelty_scores
# Calculate trendiness and novelty scores, assessing the uniqueness and freshness of each topic
flattened_trending_topics_df = run_add_advanced_novelty_scores(flattened_trending_topics_df, api_key = os.environ['OPENAI_API_KEY'], main_theme = main_theme)
# Out:
# Calculating Novelty Scores:   0%|          | 0/56 [00:00<?, ?it/s]

# %%
flattened_trending_topics_df
# Out:
#             Date                                      Day_in_Review  \
# 0     2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 79    2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 78    2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 77    2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 76    2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# ...          ...                                                ...
# 1142  2025-06-27  - OPEC+ increased oil production by 411,000 ba...
# 1027  2025-06-27  - OPEC+ increased oil production by 411,000 ba...
# 1143  2025-06-27  - OPEC+ increased oil production by 411,000 ba...
# 1225  2025-06-28  - OPEC+ increased oil production by 411,000 ba...
# 1226  2025-06-28  - OPEC+ increased oil production by 411,000 ba...
#
#                                                   Topic  \
# 0     Israel-Iran Tensions Drive Oil Price Volatilit...
# 79    Israel-Iran Tensions Drive Oil Price Volatilit...
# 78    Israel-Iran Tensions Drive Oil Price Volatilit...
# 77    OPEC+ Output Hikes Drive Oil Market Volatility...
# 76    OPEC+ Output Hikes Drive Oil Market Volatility...
# ...                                                 ...
# 1142  OPEC+ Output Hikes Drive Oil Market Volatility...
# 1027  Geopolitical Tensions Drive Oil Price Volatili...
# 1143  OPEC+ Output Hikes Drive Oil Market Volatility...
# 1225  OPEC+ Boosts Oil Production by 411,000 Barrels...
# 1226  OPEC+ Boosts Oil Production by 411,000 Barrels...
#
#                                                 Summary  \
# 0     Geopolitical tensions, particularly between Is...
# 79    Geopolitical tensions, particularly between Is...
# 78    Geopolitical tensions, particularly between Is...
# 77    CME Group plays a pivotal role in oil futures ...
# 76    CME Group plays a pivotal role in oil futures ...
# ...                                                 ...
# 1142  CME Group plays a pivotal role in oil futures ...
# 1027  The recent geopolitical tensions, particularly...
# 1143  CME Group plays a pivotal role in oil futures ...
# 1225  The impact of sanctions on oil markets is sign...
# 1226  The impact of sanctions on oil markets is sign...
#
#                      Source  \
# 0                  Livemint
# 79       The Economic Times
# 78       The Economic Times
# 77                 Sharenet
# 76       The Economic Times
# ...                     ...
# 1142  Investing.com via Web
# 1027         EconoTimes.com
# 1143           MT Newswires
# 1225           FOX Business
# 1226         Yahoo! Finance
#
#                                                Headline  \
# 0     Russia's Top Oil Executive Says OPEC  Was Astu...
# 79    Oil prices fall as US delays decision on direc...
# 78    Oil prices fall as US delays decision on direc...
# 77    Russia's Sechin: OPEC+ oil output rise justifi...
# 76    Oil prices fall as US delays decision on direc...
# ...                                                 ...
# 1142  Oil steadies after report of planned OPEC+ Aug...
# 1027  Oil Prices Steady as Markets See Low Risk of S...
# 1143  Oil Rig Count Falls by 6; Crude Set for Sharp ...
# 1225  Why summer gas prices are at a four-year low d...
# 1226  The Decline of Oil Power in Middle East Geopol...
#
#                                                    Text  Volume_Score  \
# 0     It's been a turbulent week in the global oil m...             1
# 79    Oil prices fell on Friday after the White Hous...             2
# 78    Iran is OPEC's third-largest producer.\nBrent ...             2
# 77    Russia's Sechin: OPEC+ oil output rise justifi...             3
# 76    Iran is OPEC's third-largest producer.\nBrent ...             3
# ...                                                 ...           ...
# 1142  Oil steadies after report of planned OPEC+ Aug...             2
# 1027  Despite the initial oil price surge, traders a...             5
# 1143  "This supply expansion comes at a time when th...             2
# 1225  Since there was no disruption to oil supply, o...             2
# 1226  Historical Oil Price Shocks That Benefited M.E...             2
#
#                                     Topic_labels  \
# 0     Geopolitical Tensions Impacting Oil Prices
# 79    Geopolitical Tensions Impacting Oil Prices
# 78    Geopolitical Tensions Impacting Oil Prices
# 77       CME Group's Role in Oil Futures Trading
# 76       CME Group's Role in Oil Futures Trading
# ...                                          ...
# 1142     CME Group's Role in Oil Futures Trading
# 1027   Technological Innovations in Oil Recovery
# 1143     CME Group's Role in Oil Futures Trading
# 1225          Impact of Sanctions on Oil Markets
# 1226          Impact of Sanctions on Oil Markets
#
#                                            Text_Summary Novelty_Score
# 0     Recent military exchanges between Israel and I...           New
# 79    Oil prices declined due to the White House's p...           New
# 78    Iran's position as OPEC's third-largest produc...           New
# 77    Russia's Sechin defends OPEC+ output increases...           New
# 76    Iran's position as OPEC's third-largest produc...           New
# ...                                                 ...           ...
# 1142  OPEC+'s planned output hike for August contrib...           New
# 1027  Traders' confidence in stable global oil suppl...           Old
# 1143  OPEC+ output hikes amid a challenging global m...           New
# 1225  OPEC+'s decision to boost oil production by 41...           New
# 1226  The historical use of oil as a political tool,...           New
#
# [274 rows x 11 columns]

# %% [markdown]
# **Financial Materiality**: We derive analytics related to the impact (Positive, Negative) and magnitude (High, Medium, Low) of the topics, inferring their  market impact on crude oil prices. The inference is based on the price mechanisms involving supply and demand dynamics, geopolitical factors among others.

# %%
from src.topics_extractor import add_market_impact_to_df

point_of_view = "a crude oil trader, where price is influenced by supply-demand dynamics, geopolitical events, and market sentiment. \
As a trader, you focus on changes in production, inventories, and economic indicators from key markets."


flattened_trending_topics_df = add_market_impact_to_df(flattened_trending_topics_df, api_key = os.environ['OPENAI_API_KEY'], main_theme = main_theme, point_of_view = point_of_view)

# %% [markdown]
# We display the results of topic modeling and summarization. The **Topic** column represents the themes inferred through topic clustering using a LLM, which groups the news articles based on their content and underlying themes. The **Summary** provides a synthesized overview of all news articles within the same topic, offering a high-level view of the key messages for each cluster. The **Topic** is then rephrased into a concise form based on the summary. The **Text_Summary** provides a detailed summary of each individualchunk, capturing its core message.

# %%
flattened_trending_topics_df.head(5)
# Out:
#          Date                                      Day_in_Review  \
# 0  2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 1  2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 2  2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 3  2025-06-21  - **Geopolitical Tensions**: Escalating confli...
# 4  2025-06-21  - **Geopolitical Tensions**: Escalating confli...
#
#                                                Topic  \
# 0  Israel-Iran Tensions Drive Oil Price Volatilit...
# 1  OPEC+ Adjusts Production Strategies Amid Clima...
# 2  OPEC+ Adjusts Production Strategies Amid Clima...
# 3  OPEC+ Boosts Oil Production by 411,000 Barrels...
# 4  OPEC+ Boosts Oil Production by 411,000 Barrels...
#
#                                              Summary              Source  \
# 0  Geopolitical tensions, particularly between Is...            Livemint
# 1  OPEC+ production decisions are increasingly in...  InsideClimate News
# 2  OPEC+ production decisions are increasingly in...  InsideClimate News
# 3  The impact of sanctions on oil markets is sign...      Yahoo! Finance
# 4  The impact of sanctions on oil markets is sign...      Yahoo! Finance
#
#                                             Headline  \
# 0  Russia's Top Oil Executive Says OPEC  Was Astu...
# 1  Scientists' Letter Urges Brazil's President Lu...
# 2  Scientists' Letter Urges Brazil's President Lu...
# 3  Russia's Top Oil Executive Says OPEC+ Was Astu...
# 4  Russia's Top Oil Executive Says OPEC+ Was Astu...
#
#                                                 Text  Volume_Score  \
# 0  It's been a turbulent week in the global oil m...             1
# 1  "Our two main tasks are to eliminate fossil fu...             2
# 2  "I took the letter to the head of the Brazilia...             2
# 3  "The decision by OPEC+ leaders to raise produc...             2
# 4  (Bloomberg) -- Steps taken by the OPEC+ group ...             2
#
#                                         Text_Summary  Volume_Score  \
# 0  Recent military exchanges between Israel and I...             1
# 1  A call to halt fossil fuel exploration and use...             2
# 2  Australian climate scientist Bill Hare engages...             2
# 3  OPEC+ leaders' decision to increase oil produc...             2
# 4  OPEC+'s decision to increase oil production by...             2
#
#   Novelty_Score Impact_Score Magnitude_Score
# 0           New     Positive            High
# 1           New     Negative            High
# 2           New     Negative            High
# 3           New     Negative            High
# 4           New     Negative            High

# %% [markdown]
# For verification purpose, this actionable timestamped dataframe contains the granular news clustered into relevant topics, and also the advanced analytics of trendiness, novelty, impact, and magnitude scores to be potentially used for backtesting.

# %% [markdown]
# # Step 4- Customized Report Generation

# %% [markdown]
# In this step, we rank the topics, allowing the user to customize the ranking system to reindex the news, based on their trendiness, novelty, and financial materiality on crude oil prices. We finally display a daily market update, supported by the corresponding granular news and sources for verification purpose.

# %% [markdown]
# The user selects the date for the report summarizing the top trending topics, and customizes the ranking system to prioritize the topics based on volume (trendiness and media attention), novelty (based on the emergence of new daily news), impact direction (positive or negative), and magnitude (financial materiality). The ranking system prioritizes the criteria in the order specified by the user, allowing for a tailored focus on the most relevant aspects of the data.

# %% [markdown]
# The order in which the criteria are listed in user_selected_ranking determines their priority for ranking the topics within the report. The first criterion in the list has the highest priority, followed by the second, and then the third. The user can customize the ranking by choosing to prioritize impact direction (positive or negative), novelty, magnitude, or volume, and has the flexibility to select 1, 2, or all 3 criteria based on their specific needs.

# %%
from src.topics_extractor import clean_text
from IPython.display import display
from IPython.core.display import HTML
specific_date = '2025-06-23'  # Example date, can be modified as needed

# Applying the cleaning function to the text in your DataFrame before rendering
flattened_trending_topics_df['Summary'] = flattened_trending_topics_df['Summary'].apply(clean_text)
flattened_trending_topics_df['Day_in_Review'] = flattened_trending_topics_df['Day_in_Review'].apply(clean_text)
flattened_trending_topics_df['Text_Summary'] = flattened_trending_topics_df['Text_Summary'].apply(clean_text)
flattened_trending_topics_df['Topic'] = flattened_trending_topics_df['Topic'].apply(clean_text)

user_selected_ranking = ['novelty', 'volume', 'magnitude']  # User can modify this list to change the ranking order

#impact_filter = 'positive_impact' #User can use the impact_filter to filter out the report
from src.topics_extractor import prepare_data_for_report, generate_html_report
prepared_reports = prepare_data_for_report(flattened_trending_topics_df, user_selected_ranking, impact_filter = None, report_date = specific_date)

# Generate and display the HTML report for each date
for report in prepared_reports:
    html_content = generate_html_report(
        report['date'],
        report['day_in_review'],
        report['topics'],
        'Daily crude oil market update'  # Pass the main theme to dynamically generate the title
    )
    display(HTML(html_content))
    print("")
    print("")
    print("")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Daily crude oil market update - 2025-06-23</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             background-color: #121212;
#             color: #E0E0E0;
#             margin: 20px;
#             padding: 0;
#             line-height: 1.6;
#         }
#         h1, h2, h3 {
#             color: #0080BF; /* Darker blue color for headings */
#         }
#         .container {
#             max-width: 1200px;
#             margin: 0 auto;
#             padding: 20px;
#             background-color: #1E1E1E;
#             border-radius: 10px;
#             box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.4);
#             position: relative;  /* For positioning the logo */
#         }
#         .title {
#             text-align: center;
#             font-size: 2em;
#             margin-bottom: 20px;
#             color: #00BFFF; /* Dynamic blue color for the title */
#             text-transform: uppercase;
#             letter-spacing: 2px;
#             white-space: nowrap; /* Prevent text wrapping */
#         }
#         .logo {
#             position: absolute;
#             top: 20px;
#             left: 20px; /* Positioned to the left */
#             width: 180px;  /* Adjust the size as needed */
#             height: auto;
#         }
#         .content {
#             display: flex;
#         }
#         .left-column {
#             flex: 1;
#             max-width: 300px;
#             margin-right: 20px;
#         }
#         .right-column {
#             flex: 3;
#         }
#         .separator {
#             width: 2px;
#             background-color: #00BFFF; /* Dynamic blue color for the separator */
#             margin-right: 20px;
#         }
#         .section-title {
#             font-size: 1.5em;
#             margin-bottom: 15px;
#             color: #0080BF; /* Darker blue color for section titles */
#             text-transform: uppercase;
#         }
#         .bullet-points {
#             list-style-type: disc;
#             margin-left: 20px;
#             color: #E0E0E0; /* White color for bullet points */
#         }
#         .topic-section {
#             margin-bottom: 40px;  /* Increased space between updates */
#             padding: 20px;
#             background-color: #2A2A2A;
#             border-radius: 10px;
#             box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.3);
#             position: relative;  /* To position the counters */
#         }
#         .topic-title {
#             font-size: 1.7em;
#             padding-top: 40px; /* Increase space above the title */
#             color: #0080BF; /* Darker blue color for topic titles */
#             text-transform: uppercase;
#         }
#         .counter-container {
#             position: absolute;
#             top: 20px;
#             right: 20px;
#             display: flex;
#             align-items: center;
#             justify-content: flex-start; /* Align content to the left */
#             gap: 20px; /* Space between each counter */
#             margin-bottom: 60px; /* Increased space between the title and counters */
#         }
#         .news-counter, .novelty-counter, .impact-counter, .magnitude-counter {
#             background-color: #00BFFF; /* Dynamic blue color for counters */
#             color: #121212; /* Black text color for counters */
#             padding: 5px 10px;
#             border-radius: 15px;
#             font-weight: bold;
#             font-size: 1em;
#             box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.2);
#             display: flex;
#             align-items: center;  /* Align text and icon vertically */
#         }
#         .novelty-counter {
#             background-color: transparent;
#             color: #FFA500;  /* Orange color for the flame icon and text */
#         }
#         .flame-icon {
#             vertical-align: middle;
#             margin-right: 5px;
#             width: 24px;  /* Adjusted width of the flame icon */
#             height: 24px; /* Adjusted height of the flame icon */
#         }
#         .impact-counter {
#             color: #121212; /* Black text color for impact */
#         }
#         .impact-counter.positive {
#             background-color: #4CAF50; /* Green for positive impact */
#         }
#         .impact-counter.negative {
#             background-color: #F44336; /* Red for negative impact */
#         }
#         .impact-counter.neutral {
#             background-color: transparent; /* Transparent for neutral impact */
#             color: #00BFFF; /* Dynamic blue for neutral impact text */
#         }
#         .magnitude-counter {
#             background-color: transparent; /* Transparent for the magnitude box */
#             color: #00BFFF; /* Dynamic blue for magnitude text */
#         }
#         .magnitude-counter.high {
#             color: #F44336; /* Red for high magnitude */
#         }
#         .magnitude-counter.medium {
#             color: #FFD700; /* Yellow for medium magnitude */
#         }
#         .magnitude-counter.low {
#             color: #FFFFFF; /* White for low magnitude */
#         }
#         .impact-icon, .intensity-arrow {
#             vertical-align: middle;
#             margin-right: 5px;
#             width: 24px;  /* Adjusted width of the icons */
#             height: 24px; /* Adjusted height of the icons */
#         }
#         .counter-label {
#             font-size: 0.8em;
#             color: #E0E0E0; /* White color for the counter labels */
#             margin-right: 5px;
#             text-transform: uppercase;
#             letter-spacing: 1px;
#         }
#         .description {
#             font-size: 1.1em;
#             margin-bottom: 15px;
#             color: #E0E0E0; /* White color for description */
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <!-- Logo Section -->
#         <img src="assets/bigdata-logo-white.svg" alt="Big Data Logo" class="logo">
#
#         <!-- Title Section -->
#         <div class="title">Daily crude oil market update - 2025-06-23</div>
#
#         <!-- Content Section -->
#         <div class="content">
#             <!-- Left Column -->
#             <div class="left-column">
#                 <h2 class="section-title">The Day in Review</h2>
#                 <ul class="bullet-points">
#
#                     <li><b>Geopolitical Tensions</b>: Escalating conflicts between Israel and Iran have led to significant volatility in crude oil prices, with fluctuations of up to $8 in futures.</li>
#
#                     <li><b>Supply Disruption Fears</b>: Concerns over potential disruptions in critical shipping routes, particularly the Strait of Hormuz, are driving market instability.</li>
#
#                     <li><b>OPEC+ Production Increase</b>: OPEC+ has raised oil production by 411,000 barrels per day to stabilize prices amid geopolitical tensions and fluctuating demand.</li>
#
#                     <li><b>U.S. Strategic Measures</b>: The U.S. is considering releasing oil from the Strategic Petroleum Reserve to counteract price spikes caused by geopolitical instability.</li>
#
#                     <li><b>Demand Dynamics</b>: Growing demand for petrochemicals in the Asia Pacific, particularly from China and India, complicates the market landscape and influences global oil consumption.</li>
#
#                     <li><b>Refining Challenges</b>: U.S. refining operations are facing declines in margins and capacity utilization, which could further impact crude oil prices.</li>
#
#                     <li><b>Technological Innovations</b>: Advancements in oil recovery technologies are becoming increasingly vital for enhancing production efficiency and mitigating risks associated with geopolitical events.</li>
#
#                 </ul>
#             </div>
#
#             <!-- Separator -->
#             <div class="separator"></div>
#
#             <!-- Right Column -->
#             <div class="right-column">
#
#                 <div class="topic-section">
#                     <div class="counter-container">
